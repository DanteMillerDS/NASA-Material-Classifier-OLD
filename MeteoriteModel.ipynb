# %% [markdown]
# # IMPORTS

# %%
# Clone the Git repository and navigate to the project directory
# !git clone https://github.com/DanteMillerDS/NASA-Material-Classifier.git
# %cd NASA-Material-Classifier

# Install required packages
# !pip install xgboost
# !pip install pytorch-tabnet
# !pip install torch

# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.io
import torch
import xgboost as xgb
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import mean_absolute_error
from tensorflow.keras.callbacks import ReduceLROnPlateau
from sklearn.preprocessing import PowerTransformer, QuantileTransformer
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, KFold
from keras.layers import Bidirectional, LSTM, Dense
from sklearn.model_selection import train_test_split
from pytorch_tabnet.tab_model import TabNetRegressor
import uuid

# Set random seeds for reproducibility
np.random.seed(1000)
tf.random.set_seed(1000)
# Out:
# Cloning into 'NASA-Material-Classifier'...
# remote: Enumerating objects: 169, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 169 (delta 3), reused 17 (delta 2), pack-reused 150
# Receiving objects: 100% (169/169), 231.02 MiB | 15.56 MiB/s, done.
# Resolving deltas: 100% (43/43), done.
# Updating files: 100% (67/67), done.
# /content/NASA-Material-Classifier
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.0.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.11.3)
# Collecting pytorch-tabnet
#   Downloading pytorch_tabnet-4.1.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from pytorch-tabnet) (1.23.5)
# Requirement already satisfied: scikit_learn>0.21 in /usr/local/lib/python3.10/dist-packages (from pytorch-tabnet) (1.2.2)
# Requirement already satisfied: scipy>1.4 in /usr/local/lib/python3.10/dist-packages (from pytorch-tabnet) (1.11.3)
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.10/dist-packages (from pytorch-tabnet) (2.1.0+cu118)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.10/dist-packages (from pytorch-tabnet) (4.66.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit_learn>0.21->pytorch-tabnet) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit_learn>0.21->pytorch-tabnet) (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch-tabnet) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch-tabnet) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch-tabnet) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch-tabnet) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch-tabnet) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch-tabnet) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch-tabnet) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3->pytorch-tabnet) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3->pytorch-tabnet) (1.3.0)
# Installing collected packages: pytorch-tabnet
# Successfully installed pytorch-tabnet-4.1.0
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %% [markdown]
# # PREPROCESSING

# %%
# Read training files
file_paths = dict()
for i in range(1, 21):
    file_path = [f"data/meteorite/simulated/sau_orientation{i}.txt"]
    file_paths[i] = file_path
def process_file(file_path,orientation):
    datasets = []
    with open(file_path, 'r') as file:
        current_dataset = []
        for line in file:

            if line.startswith("#Parameters"):
                if current_dataset:
                    datasets.append(current_dataset)
                    current_dataset = []
                params_str = line[line.index("{") + 1:line.index("}")]
                params = dict(param.split('=') for param in params_str.split(';'))
                current_dataset.append(params)
            elif "Frequency" in line:
              parts = line.split()
              s_number = parts[3][1:].replace(',', '')
              current_dataset.append(s_number)
            elif line.startswith("#"):
                continue
            else:
                data = line.strip().split('\t')
                current_dataset.append(data)
        if current_dataset:
            datasets.append(current_dataset)

    data = []
    for index, dataset in enumerate(datasets):
        permittivity_values = dataset[0]
        s_parameter_name = dataset[1]
        df_data = dataset[2:]
        df = pd.DataFrame(df_data, columns=["Frequency", f"{s_parameter_name}_Real", f"{s_parameter_name}_Imaginary"])
        df["Orientation"] = orientation
        df["ID"] = str(uuid.uuid4())[:8]
        for key, value in permittivity_values.items():
            if "er1" in key or "er11" in key:
                df[key] = value
        data.append(df)
    return data
all_combined_data = []
for index in file_paths:
    for file in file_paths[index]:
        combined_data = process_file(file,index)
        all_combined_data.append(combined_data)
array = []
for combined_data in all_combined_data:
  num_of_data = 4
  dataframes_length = int(len(combined_data)/num_of_data)
  for x in range(dataframes_length):
    concatenated_df = pd.DataFrame()
    for y in range(num_of_data):
      index = y * dataframes_length + x
      concatenated_df = pd.concat([concatenated_df, combined_data[index]], axis=1)
    concatenated_df = concatenated_df.loc[:,~concatenated_df.columns.duplicated()]
    array.append(concatenated_df)
training_dataframe = pd.concat(array, axis=0)
training_dataframe = training_dataframe.loc[:, ~training_dataframe.columns.duplicated()]

# %%
# Read testing files
file_paths = dict()
file_paths[0] = ["data/meteorite/actual/mea_sau008_0_orientation.txt"]
file_paths[1] = ["data/meteorite/actual/mea_sau008_90_oreintation.txt"]
file_paths[2] = ["data/meteorite/actual/mea_sau008_180_orientation.txt"]
file_paths[3] = ["data/meteorite/actual/mea_sau008_270_orientation.txt"]

def process_file(file_path,orientation):
    datasets = []
    with open(file_path, 'r') as file:
        current_dataset = []
        for line in file:

            if line.startswith("#Parameters"):
                if current_dataset:
                    datasets.append(current_dataset)
                    current_dataset = []
                params_str = line[line.index("{") + 1:line.index("}")]
                params = dict(param.split('=') for param in params_str.split(';'))
                current_dataset.append(params)
            elif "Frequency" in line:
              parts = line.split()
              s_number = parts[3][1:].replace(',', '')
              current_dataset.append(s_number)
            elif line.startswith("#"):
                continue
            else:
                data = line.strip().split('\t')
                current_dataset.append(data)
        if current_dataset:
            datasets.append(current_dataset)

    data = []
    for index, dataset in enumerate(datasets):
        permittivity_values = dataset[0]
        s_parameter_name = dataset[1]
        df_data = dataset[2:]
        df = pd.DataFrame(df_data, columns=["Frequency", f"{s_parameter_name}_Real", f"{s_parameter_name}_Imaginary"])
        df["Orientation"] = orientation
        df["ID"] = str(uuid.uuid4())[:8]
        for key, value in permittivity_values.items():
            if "er1" in key or "er11" in key:
                df[key] = value
        data.append(df)
    return data
all_combined_data = []
for index in file_paths:
    for file in file_paths[index]:
        combined_data = process_file(file,index)
        all_combined_data.append(combined_data)
array = []
for combined_data in all_combined_data:
  num_of_data = 4
  dataframes_length = int(len(combined_data)/num_of_data)
  for x in range(dataframes_length):
    concatenated_df = pd.DataFrame()
    for y in range(num_of_data):
      index = y * dataframes_length + x
      concatenated_df = pd.concat([concatenated_df, combined_data[index]], axis=1)
    concatenated_df = concatenated_df.loc[:,~concatenated_df.columns.duplicated()]
    array.append(concatenated_df)
testing_dataframe = pd.concat(array, axis=0)

# %%
# Print columns
print(training_dataframe.columns)
print(testing_dataframe.columns)
# Out:
# Index(['Frequency', 'S11_Real', 'S11_Imaginary', 'Orientation', 'ID', ' er1',
#        ' er11', 'S21_Real', 'S21_Imaginary', 'S12_Real', 'S12_Imaginary',
#        'S22_Real', 'S22_Imaginary'],
#       dtype='object')
# Index(['Frequency', 'S55_Real', 'S55_Imaginary', 'Orientation', 'ID', ' er1',
#        ' er11', 'S65_Real', 'S65_Imaginary', 'S56_Real', 'S56_Imaginary',
#        'S66_Real', 'S66_Imaginary'],
#       dtype='object')

# %%
# Define variable names
training_dataframe.columns = ['Frequency', 'S11_Real', 'S11_Imaginary', 'Orientation', 'ID','Permittivity_Real', 'Permittivity_Imaginary', 'S21_Real',
       'S21_Imaginary', 'S12_Real', 'S12_Imaginary', 'S22_Real',
       'S22_Imaginary']
training_dataframe = training_dataframe[['ID','Frequency', 'Orientation', 'Permittivity_Real', 'Permittivity_Imaginary','S11_Real', 'S11_Imaginary', 'S12_Real',
       'S12_Imaginary', 'S21_Real', 'S21_Imaginary', 'S22_Real',
       'S22_Imaginary']]
testing_dataframe.columns = ['Frequency', 'S11_Real', 'S11_Imaginary', 'Orientation', 'ID','Permittivity_Real', 'Permittivity_Imaginary', 'S21_Real',
       'S21_Imaginary', 'S12_Real', 'S12_Imaginary', 'S22_Real',
       'S22_Imaginary']
testing_dataframe = testing_dataframe[['ID','Frequency', 'Orientation',  'Permittivity_Real', 'Permittivity_Imaginary','S11_Real', 'S11_Imaginary', 'S12_Real',
       'S12_Imaginary', 'S21_Real', 'S21_Imaginary', 'S22_Real',
       'S22_Imaginary']]

# %%
# Print variable names
training_dataframe.columns
testing_dataframe.columns
# Out:
# Index(['ID', 'Frequency', 'Orientation', 'Permittivity_Real',
#        'Permittivity_Imaginary', 'S11_Real', 'S11_Imaginary', 'S12_Real',
#        'S12_Imaginary', 'S21_Real', 'S21_Imaginary', 'S22_Real',
#        'S22_Imaginary'],
#       dtype='object')

# %%
# Drop na and applying numeric
training_dataframe.dropna(inplace=True)
columns = training_dataframe.columns[1:]
training_dataframe[columns] = training_dataframe[columns].apply(pd.to_numeric)
testing_dataframe.dropna(inplace=True)
testing_dataframe[columns] = testing_dataframe[columns].apply(pd.to_numeric)

# %%
# Remove id
training_dataframe = training_dataframe.iloc[:,1:]
testing_dataframe = testing_dataframe.iloc[:,1:]

# %%
# Set to 0.1
# testing_dataframe['Permittivity_Imaginary'][testing_dataframe['Permittivity_Imaginary'] == 0.4] = 0.1

# %%
# Describe training dataframe
training_dataframe.describe()
# Out:
#           Frequency   Orientation  Permittivity_Real  Permittivity_Imaginary  \
# count  2.003001e+06  2.003001e+06       2.003001e+06            2.003001e+06
# mean   1.350000e+00  1.049725e+01       4.945907e+00            4.963151e-02
# std    2.022746e-01  5.766152e+00       2.278568e+00            2.886687e-02
# min    1.000000e+00  1.000000e+00       1.000150e+00            1.707944e-04
# 25%    1.175000e+00  5.000000e+00       2.930578e+00            2.427854e-02
# 50%    1.350000e+00  1.000000e+01       4.984754e+00            4.901814e-02
# 75%    1.525000e+00  1.500000e+01       6.829293e+00            7.525355e-02
# max    1.700000e+00  2.000000e+01       8.997784e+00            9.994916e-02
#
#            S11_Real  S11_Imaginary      S12_Real  S12_Imaginary      S21_Real  \
# count  2.003001e+06   2.003001e+06  2.003001e+06   2.003001e+06  2.003001e+06
# mean  -2.652006e-03   2.650201e-03 -5.381296e-02  -4.580618e-02 -5.381295e-02
# std    1.036674e-01   1.060097e-01  7.054999e-01   6.794501e-01  7.054999e-01
# min   -2.180810e-01  -2.549406e-01 -9.986315e-01  -9.962784e-01 -9.986316e-01
# 25%   -8.970921e-02  -8.798371e-02 -7.518066e-01  -7.213721e-01 -7.518066e-01
# 50%   -4.014916e-03   1.737387e-02 -1.561098e-01  -7.297147e-02 -1.561098e-01
# 75%    8.478236e-02   8.872819e-02  6.688859e-01   6.198645e-01  6.688859e-01
# max    2.371261e-01   2.112861e-01  9.993030e-01   9.949554e-01  9.993030e-01
#
#        S21_Imaginary      S22_Real  S22_Imaginary
# count   2.003001e+06  2.003001e+06   2.003001e+06
# mean   -4.580618e-02 -8.480080e-03   4.908043e-04
# std     6.794501e-01  1.009686e-01   1.083329e-01
# min    -9.962784e-01 -2.144937e-01  -2.509244e-01
# 25%    -7.213721e-01 -9.131249e-02  -9.317510e-02
# 50%    -7.297142e-02 -1.472770e-02   1.168782e-02
# 75%     6.198645e-01  7.616111e-02   9.174016e-02
# max     9.949554e-01  2.533520e-01   2.136576e-01

# %%
# Describe testing dataframe
testing_dataframe.describe()
# Out:
#        Frequency  Orientation  Permittivity_Real  Permittivity_Imaginary  \
# count  4004.0000  4004.000000        4004.000000             4004.000000
# mean      1.3500     1.500000           7.750000                0.430000
# std       0.2023     1.118174           0.433067                0.337236
# min       1.0000     0.000000           7.000000                0.120000
# 25%       1.1750     0.750000           7.750000                0.255000
# 50%       1.3500     1.500000           8.000000                0.300000
# 75%       1.5250     2.250000           8.000000                0.475000
# max       1.7000     3.000000           8.000000                1.000000
#
#           S11_Real  S11_Imaginary     S12_Real  S12_Imaginary     S21_Real  \
# count  4004.000000    4004.000000  4004.000000    4004.000000  4004.000000
# mean     -0.008501       0.003331     0.959131      -0.202523     0.959105
# std       0.126175       0.122927     0.004006       0.013707     0.004028
# min      -0.229152      -0.201646     0.938142      -0.241066     0.937925
# 25%      -0.130663      -0.112173     0.957734      -0.210479     0.957669
# 50%      -0.013226       0.008739     0.960785      -0.200370     0.960799
# 75%       0.116752       0.121954     0.961649      -0.191734     0.961592
# max       0.183352       0.187130     0.963593      -0.181735     0.963461
#
#        S21_Imaginary     S22_Real  S22_Imaginary
# count    4004.000000  4004.000000    4004.000000
# mean       -0.202242     0.008399      -0.001808
# std         0.013621     0.124165       0.124577
# min        -0.240152    -0.185532      -0.211750
# 25%        -0.210197    -0.115633      -0.119994
# 50%        -0.200090     0.020150       0.001122
# 75%        -0.191449     0.128447       0.119894
# max        -0.181764     0.192772       0.184867

# %%
# Print training dataframe head
training_dataframe.head(5)
# Out:
#    Frequency  Orientation  Permittivity_Real  Permittivity_Imaginary  \
# 0     1.0000            1           1.092605                0.001191
# 1     1.0007            1           1.092605                0.001191
# 2     1.0014            1           1.092605                0.001191
# 3     1.0021            1           1.092605                0.001191
# 4     1.0028            1           1.092605                0.001191
#
#    S11_Real  S11_Imaginary  S12_Real  S12_Imaginary  S21_Real  S21_Imaginary  \
# 0  0.099731      -0.037289  0.291348       0.942274  0.291348       0.942274
# 1  0.098817      -0.039333  0.310043       0.937010  0.310043       0.937010
# 2  0.097860      -0.041347  0.328585       0.931373  0.328586       0.931373
# 3  0.096864      -0.043331  0.346970       0.925367  0.346970       0.925367
# 4  0.095828      -0.045284  0.365189       0.919000  0.365189       0.919000
#
#    S22_Real  S22_Imaginary
# 0  0.103373      -0.025510
# 1  0.102775      -0.027371
# 2  0.102141      -0.029213
# 3  0.101474      -0.031036
# 4  0.100772      -0.032841

# %%
# Print testing dataframe head
training_dataframe.head(5)
# Out:
#    Frequency  Orientation  Permittivity_Real  Permittivity_Imaginary  \
# 0     1.0000            1           1.092605                0.001191
# 1     1.0007            1           1.092605                0.001191
# 2     1.0014            1           1.092605                0.001191
# 3     1.0021            1           1.092605                0.001191
# 4     1.0028            1           1.092605                0.001191
#
#    S11_Real  S11_Imaginary  S12_Real  S12_Imaginary  S21_Real  S21_Imaginary  \
# 0  0.099731      -0.037289  0.291348       0.942274  0.291348       0.942274
# 1  0.098817      -0.039333  0.310043       0.937010  0.310043       0.937010
# 2  0.097860      -0.041347  0.328585       0.931373  0.328586       0.931373
# 3  0.096864      -0.043331  0.346970       0.925367  0.346970       0.925367
# 4  0.095828      -0.045284  0.365189       0.919000  0.365189       0.919000
#
#    S22_Real  S22_Imaginary
# 0  0.103373      -0.025510
# 1  0.102775      -0.027371
# 2  0.102141      -0.029213
# 3  0.101474      -0.031036
# 4  0.100772      -0.032841

# %% [markdown]
# # DATA VISUALIZATION

# %%
# Plot training dataframe columns
plt.figure(figsize=(24, 8))
for i, column in enumerate(training_dataframe.columns):
    plt.subplot(2,6 , i+1)
    plt.hist(training_dataframe[column], bins=20, edgecolor='black')
    plt.title(column)
    plt.xlabel('Value')
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
# Print testing dataframe columns
plt.figure(figsize=(24, 8))
for i, column in enumerate(testing_dataframe.columns):
    plt.subplot(2,6 , i+1)
    plt.hist(testing_dataframe[column], bins=20, edgecolor='black')
    plt.title(column)
    plt.xlabel('Value')
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
# Grabbing column means
columns = training_dataframe.columns[3:]
training_mean_predicted_values = training_dataframe.groupby('Frequency')[columns].mean()
testing_mean_predicted_values = testing_dataframe.groupby('Frequency')[columns].mean()

# %%
# Showing mean for the permittivity real training dataframe
q25 = np.percentile(training_dataframe["Permittivity_Real"], 25)
q50 = np.percentile(training_dataframe["Permittivity_Real"], 50)
q75 = np.percentile(training_dataframe["Permittivity_Real"], 75)
plt.hist(training_dataframe["Permittivity_Real"])
plt.xlabel("Permittivity Real Values")
plt.ylabel("Frequency")
plt.title("Training: Histogram of Permittivity Real Values")
plt.axvline(q25, color='red', linestyle='dashed', linewidth=2, label='25th Percentile (Q1)')
plt.axvline(q50, color='green', linestyle='dashed', linewidth=2, label='50th Percentile (Median)')
plt.axvline(q75, color='blue', linestyle='dashed', linewidth=2, label='75th Percentile (Q3)')
plt.legend()
plt.show()

# %%
# Showing mean for the permittivity imaginary for training dataframe
q25 = np.percentile(training_dataframe["Permittivity_Imaginary"], 25)
q50 = np.percentile(training_dataframe["Permittivity_Imaginary"], 50)
q75 = np.percentile(training_dataframe["Permittivity_Imaginary"], 75)
plt.hist(training_dataframe["Permittivity_Imaginary"])
plt.xlabel("Permittivity Imaginary Values")
plt.ylabel("Frequency")
plt.title("Training: Histogram of Permittivity Imaginary Values")
plt.axvline(q25, color='red', linestyle='dashed', linewidth=2, label='25th Percentile (Q1)')
plt.axvline(q50, color='green', linestyle='dashed', linewidth=2, label='50th Percentile (Median)')
plt.axvline(q75, color='blue', linestyle='dashed', linewidth=2, label='75th Percentile (Q3)')
plt.legend()
plt.show()

# %%
# Showing mean for the permittivity real for testing dataframe
plt.hist(testing_dataframe["Permittivity_Real"])
plt.xlabel("Permittivity Real Values")
plt.ylabel("Frequency")
plt.title("Testing: Histogram of Permittivity Real Values")
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Showing mean for the permittivity real for training dataframe
plt.hist(testing_dataframe["Permittivity_Imaginary"])
plt.xlabel("Permittivity Imaginary Values")
plt.ylabel("Frequency")
plt.title("Testing: Histogram of Permittivity Imaginary Values")
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Plot mean over frequencies for testing dataframe
plt.figure(figsize=(12, 6))
for col in training_mean_predicted_values.columns:
    plt.plot(training_mean_predicted_values.index, training_mean_predicted_values[col], label=col)
plt.xlabel('Frequency')
plt.ylabel('Mean Value')
plt.title('Training: Mean Values of Variables over Different Frequencies')
plt.legend()
plt.show()

# %%
# Plot mean over frequencies for training dataframe
plt.figure(figsize=(12, 6))
for col in testing_mean_predicted_values.columns:
    plt.plot(testing_mean_predicted_values.index, testing_mean_predicted_values[col], label=col)
plt.xlabel('Frequency')
plt.ylabel('Mean Value')
plt.title('Training: Mean Values of Variables over Different Frequencies')
plt.legend()
plt.show()

# %%
# Heatmap for global
plt.figure(figsize=(12, 6))
sns.heatmap(training_dataframe[['Permittivity_Real', 'Permittivity_Imaginary', 'S11_Real', 'S11_Imaginary', 'S21_Real','S21_Imaginary', 'S12_Real', 'S12_Imaginary', 'S22_Real','S22_Imaginary']].corr(), annot=True, cmap='coolwarm')
plt.title('Meteorite Global Correlation Matrix Heatmap')
plt.show()

# %%
# Heatmap for various frequencies
unique_frequencies = np.unique(training_dataframe["Frequency"])
count = 0
for i in range(0, len(unique_frequencies), 300):
    if count < 2:
        plt.figure(figsize=(12, 6))
        sample = training_dataframe[training_dataframe["Frequency"] == unique_frequencies[i]]
        sns.heatmap(sample[['Permittivity_Real', 'Permittivity_Imaginary', 'S11_Real', 'S11_Imaginary', 'S21_Real', 'S21_Imaginary', 'S12_Real', 'S12_Imaginary', 'S22_Real', 'S22_Imaginary']].corr(), annot=True, cmap='coolwarm')
        plt.title(f'Meteorite Correlation Matrix Heatmap at Frequency {np.round(unique_frequencies[i],3)}')
        plt.figure(figsize=(12, 6))
        count += 1
    else:
        break

# %% [markdown]
# # DATA MANIPULATION

# %%
# Normalize
training_dataframe["Permittivity_Real"] /= 100
testing_dataframe["Permittivity_Real"] /= 100

# %%
# Power transform
no_id = [
 'S11_Real',
 'S11_Imaginary',
 'S12_Real',
 'S12_Imaginary',
 'S21_Real',
 'S21_Imaginary',
 'S22_Real',
 'S22_Imaginary']
bc = QuantileTransformer(random_state=42)
bc.fit(training_dataframe[no_id])
training_dataframe[training_dataframe[no_id].columns] = bc.transform(training_dataframe[no_id])
testing_dataframe[testing_dataframe[no_id].columns]  = bc.transform(testing_dataframe[no_id])

# %%
# Plot training histogram
plt.figure(figsize=(24, 8))
for i, column in enumerate(training_dataframe.columns):
    plt.subplot(2,6 , i+1)
    plt.hist(training_dataframe[column], bins=20, edgecolor='black')
    plt.title(column)
    plt.xlabel('Value')
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
# Plot testing histogram
plt.figure(figsize=(24, 8))
for i, column in enumerate(testing_dataframe.columns):
    plt.subplot(2,6 , i+1)
    plt.hist(testing_dataframe[column], bins=20, edgecolor='black')
    plt.title(column)
    plt.xlabel('Value')
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# # MODELS

# %%
# Hyperparameters
LR = 0.0001
L2 = 0.00001
WD = 0.000001

# %%
# Column names
columns = []
for column in training_dataframe.columns:
    if column not in ["Permittivity_Real","Permittivity_Imaginary","ID","Orientation","Frequency"]:
        columns.append(column)
columns
# Out:
# ['S11_Real',
#  'S11_Imaginary',
#  'S12_Real',
#  'S12_Imaginary',
#  'S21_Real',
#  'S21_Imaginary',
#  'S22_Real',
#  'S22_Imaginary']

# %%
# K fold
k_fold_value = 10
X_train = training_dataframe[columns].values
y_train = training_dataframe[['Permittivity_Real', 'Permittivity_Imaginary']].values
selected_indices = np.arange(len(training_dataframe))
grouped_indices = {}
for idx in selected_indices:
    row = training_dataframe.iloc[idx]
    orientation = row['Orientation']
    frequency = row['Frequency']
    key = (orientation, frequency)
    if key not in grouped_indices:
        grouped_indices[key] = []
    grouped_indices[key].append(idx)

X_train_indices = []
X_test_indices = []
for key, indices in grouped_indices.items():
    train_indices, test_indices = train_test_split(indices, test_size=0.1, random_state=42)
    X_train_indices.extend(train_indices)
    X_test_indices.extend(test_indices)
    grouped_indices[key] = train_indices
X_test_indices.sort()

X_selected = X_train
y_selected = y_train

# grouped_indices = {}
# for idx in selected_indices:
#     row = training_dataframe.iloc[idx]
#     orientation = row['Orientation']
#     frequency = row['Frequency']
#     key = (orientation, frequency)
#     if key not in grouped_indices:
#         grouped_indices[key] = []
#     grouped_indices[key].append(idx)
# kf = KFold(n_splits=5)
X_train_indices_dict = dict()
X_val_indices_dict = dict()
X_test_indices_dict = dict()
for i in range(k_fold_value):
  X_train_indices_dict[i] = []
  X_val_indices_dict[i] = []
  X_test_indices_dict[i] = X_test_indices

# for key, indices in grouped_indices.items():
#     for index, (train_indice_x, val_indice_x) in enumerate(kf.split(indices)):
#       train_indices = train_indice_x
#       val_indices = val_indice_x
#       X_train_indices_dict[index].extend(train_indices)
#       X_val_indices_dict[index].extend(val_indices)

# for i in range(5):
#   X_test_indices_dict[i].sort()

X_train_indices = []
X_val_indices = []
kf = KFold(n_splits=k_fold_value,shuffle=True,random_state=42)
for ind in range(k_fold_value):
  for key, indices in grouped_indices.items():
    train_indices,val_indices = list(kf.split(indices))[ind]
    train_indices = [indices[i] for i in train_indices]
    val_indices = [indices[i] for i in val_indices]
    X_train_indices_dict[ind].extend(train_indices)
    X_val_indices_dict[ind].extend(val_indices)
    # for index, (train_indices, val_indices) in enumerate(kf.split(indices)):
    #   #train_indices, val_indices = train_test_split(indices, test_size=0.1, random_state=100)
    #   X_train_indices.extend(train_indices)
    #   X_val_indices.extend(val_indices)

# %%
# Showing number of observations
num_obs_train = len(X_selected[X_train_indices_dict[0]])
num_obs_val = len(X_selected[X_val_indices_dict[0]])
num_obs_test = len(X_train[X_test_indices_dict[0]])
total_obs = num_obs_train + num_obs_val + num_obs_test
data = {'Dataset': ['Training', 'Validation', 'Test', 'Total'],
            'Number of Observations': [num_obs_train, num_obs_val, num_obs_test, total_obs]}
observations_table = pd.DataFrame(data)
print(observations_table)
# Out:
#       Dataset  Number of Observations
# 0    Training                 1621620
# 1  Validation                  180180
# 2        Test                  201201
# 3       Total                 2003001

# %%
# # Showing uniform orientations and frequencies
# selected_orientations = training_dataframe.loc[X_train_indices_dict[0], 'Orientation']
# selected_frequencies = training_dataframe.loc[X_train_indices_dict[0], 'Frequency']

# plt.figure(figsize=(15, 10))

# plt.subplot(2, 2, 1)
# plt.hist(selected_orientations, bins=10, color='blue', edgecolor='black')
# plt.title('Training: Histogram of Selected Orientations')
# plt.xlabel('Orientation')
# plt.ylabel('Frequency')

# plt.subplot(2, 2, 2)
# plt.hist(selected_frequencies, bins=20, color='green', edgecolor='black')
# plt.title('Training: Histogram of Selected Frequencies')
# plt.xlabel('Frequency')
# plt.ylabel('Frequency')

# plt.tight_layout()
# plt.show()

# selected_orientations = training_dataframe.loc[X_val_indices_dict[0], 'Orientation']
# selected_frequencies = training_dataframe.loc[X_val_indices_dict[0], 'Frequency']

# plt.figure(figsize=(15, 10))

# plt.subplot(2, 2, 1)
# plt.hist(selected_orientations, bins=10, color='blue', edgecolor='black')
# plt.title('Validation: Histogram of Selected Orientations')
# plt.xlabel('Orientation')
# plt.ylabel('Frequency')

# plt.subplot(2, 2, 2)
# plt.hist(selected_frequencies, bins=20, color='green', edgecolor='black')
# plt.title('Validation: Histogram of Selected Frequencies')
# plt.xlabel('Frequency')
# plt.ylabel('Frequency')

# plt.tight_layout()
# plt.show()

# selected_orientations = training_dataframe.loc[X_test_indices_dict[0], 'Orientation']
# selected_frequencies = training_dataframe.loc[X_test_indices_dict[0], 'Frequency']

# plt.figure(figsize=(15, 10))
# plt.subplot(2, 2, 1)
# plt.hist(selected_orientations, bins=10, color='blue', edgecolor='black')
# plt.title('Testing: Histogram of Selected Orientations')
# plt.xlabel('Orientation')
# plt.ylabel('Frequency')

# plt.subplot(2, 2, 2)
# plt.hist(selected_frequencies, bins=20, color='green', edgecolor='black')
# plt.title('Testing: Histogram of Selected Frequencies')
# plt.xlabel('Frequency')
# plt.ylabel('Frequency')

# plt.tight_layout()
# plt.show()

# %%
# Train models
def train_models(X_train,y_train,X_val,y_val):

    def rmse_loss(y_true, y_pred):
      squared_error = tf.square(y_true - y_pred)
      mean_squared_error = tf.reduce_mean(squared_error)
      root_mean_squared_error = tf.sqrt(mean_squared_error)
      return root_mean_squared_error

    nn_model = keras.Sequential([
        keras.layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],),kernel_initializer='he_uniform', kernel_regularizer=tf.keras.regularizers.l2(L2)),
        keras.layers.Dense(64, activation='relu', kernel_initializer='he_uniform',kernel_regularizer=tf.keras.regularizers.l2(L2)),
        keras.layers.Dense(32, activation='relu', kernel_initializer='he_uniform',kernel_regularizer=tf.keras.regularizers.l2(L2)),
        keras.layers.Dense(16, activation='relu', kernel_initializer='he_uniform',kernel_regularizer=tf.keras.regularizers.l2(L2)),
        keras.layers.Dense(y_train.shape[1], activation='linear')
    ])


    nn_model.compile(optimizer=tf.optimizers.Adam(learning_rate=L2,weight_decay=WD),
                  loss=[rmse_loss],
                  metrics=[tf.metrics.MeanAbsoluteError(), tf.metrics.MeanSquaredError()])
    nn_model.summary()
    history = nn_model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50,shuffle=True,batch_size=1001)
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['mean_absolute_error'])
    plt.plot(history.history['val_mean_absolute_error'])
    plt.title('FNN: Mean Absolute Error')
    plt.xlabel('Epoch')
    plt.ylabel('Mean Absolute Error')
    plt.legend(['Train', 'Validation'])
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('FNN: Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['Train', 'Validation'])
    plt.tight_layout()
    plt.show()

    xgb_model = xgb.XGBRegressor(n_jobs=-1,device="gpu",n_estimators=250,eval_metric="rmse",verbosity=3,max_depth=5)
    xgb_model.fit(X_train, y_train)

    X_train_tensor = torch.tensor(X_train , dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
    X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
    y_val_tensor = torch.tensor(y_val, dtype=torch.float32)
    tabnet_model = TabNetRegressor(
    device_name="cuda"
    )
    tabnet_model.fit(
        X_train, y_train,
        eval_set=[(X_val, y_val)],
        max_epochs=10,
        batch_size=1001,
        eval_metric=["rmse"]
    )
    return nn_model, xgb_model, tabnet_model
    #    optimizer_params={
   #         "lr": LR,  # Set your desired learning rate here
     #       "weight_decay": WD,  # Set your desired weight decay here
    #    }  # Use RMSE as the evaluation metric

# %%
# Call train models function on each k fold
model_dictionary = dict()
for i in range(index+1):
  X_train_index = X_train_indices_dict[i]
  X_val_index = X_val_indices_dict[i]
  X_test_index = X_test_indices_dict[i]
  X_train = X_selected[X_train_index]
  y_train = y_selected[X_train_index]
  X_val = X_selected[X_val_index]
  y_val = y_selected[X_val_index]
  X_test = X_selected[X_test_index]
  y_test = y_selected[X_test_index]
  X_train = X_train.astype(float)
  y_train = y_train.astype(float)
  X_val = X_val.astype(float)
  y_val = y_val.astype(float)
  X_test = X_test.astype(float)
  y_test = y_test.astype(float)

  nn_model, xgb_model, tabnet_model = train_models(X_train,y_train,X_val,y_val)
  model_dictionary[i] = [nn_model,xgb_model,tabnet_model]
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1152
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 16)                528
#
#  dense_4 (Dense)             (None, 2)                 34
#
# =================================================================
# Total params: 12050 (47.07 KB)
# Trainable params: 12050 (47.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 1620/1620 [==============================] - 19s 8ms/step - loss: 0.0749 - mean_absolute_error: 0.0589 - mean_squared_error: 0.0122 - val_loss: 0.0294 - val_mean_absolute_error: 0.0196 - val_mean_squared_error: 6.1558e-04
# Epoch 2/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0273 - mean_absolute_error: 0.0173 - mean_squared_error: 5.1455e-04 - val_loss: 0.0262 - val_mean_absolute_error: 0.0168 - val_mean_squared_error: 4.7682e-04
# Epoch 3/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0256 - mean_absolute_error: 0.0158 - mean_squared_error: 4.4703e-04 - val_loss: 0.0252 - val_mean_absolute_error: 0.0158 - val_mean_squared_error: 4.3887e-04
# Epoch 4/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0248 - mean_absolute_error: 0.0150 - mean_squared_error: 4.2065e-04 - val_loss: 0.0246 - val_mean_absolute_error: 0.0152 - val_mean_squared_error: 4.2098e-04
# Epoch 5/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0244 - mean_absolute_error: 0.0146 - mean_squared_error: 4.0683e-04 - val_loss: 0.0243 - val_mean_absolute_error: 0.0149 - val_mean_squared_error: 4.1116e-04
# Epoch 6/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0241 - mean_absolute_error: 0.0143 - mean_squared_error: 3.9859e-04 - val_loss: 0.0240 - val_mean_absolute_error: 0.0147 - val_mean_squared_error: 4.0369e-04
# Epoch 7/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0238 - mean_absolute_error: 0.0141 - mean_squared_error: 3.9323e-04 - val_loss: 0.0238 - val_mean_absolute_error: 0.0145 - val_mean_squared_error: 3.9918e-04
# Epoch 8/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0236 - mean_absolute_error: 0.0140 - mean_squared_error: 3.8909e-04 - val_loss: 0.0236 - val_mean_absolute_error: 0.0144 - val_mean_squared_error: 3.9704e-04
# Epoch 9/50
# 1620/1620 [==============================] - 12s 8ms/step - loss: 0.0235 - mean_absolute_error: 0.0139 - mean_squared_error: 3.8575e-04 - val_loss: 0.0234 - val_mean_absolute_error: 0.0143 - val_mean_squared_error: 3.9165e-04
# Epoch 10/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0233 - mean_absolute_error: 0.0138 - mean_squared_error: 3.8279e-04 - val_loss: 0.0233 - val_mean_absolute_error: 0.0142 - val_mean_squared_error: 3.8905e-04
# Epoch 11/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0232 - mean_absolute_error: 0.0137 - mean_squared_error: 3.8012e-04 - val_loss: 0.0232 - val_mean_absolute_error: 0.0142 - val_mean_squared_error: 3.8797e-04
# Epoch 12/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0231 - mean_absolute_error: 0.0137 - mean_squared_error: 3.7780e-04 - val_loss: 0.0230 - val_mean_absolute_error: 0.0140 - val_mean_squared_error: 3.8321e-04
# Epoch 13/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0230 - mean_absolute_error: 0.0136 - mean_squared_error: 3.7562e-04 - val_loss: 0.0230 - val_mean_absolute_error: 0.0140 - val_mean_squared_error: 3.8180e-04
# Epoch 14/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0229 - mean_absolute_error: 0.0135 - mean_squared_error: 3.7348e-04 - val_loss: 0.0229 - val_mean_absolute_error: 0.0140 - val_mean_squared_error: 3.8051e-04
# Epoch 15/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0228 - mean_absolute_error: 0.0135 - mean_squared_error: 3.7125e-04 - val_loss: 0.0228 - val_mean_absolute_error: 0.0139 - val_mean_squared_error: 3.7783e-04
# Epoch 16/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0227 - mean_absolute_error: 0.0134 - mean_squared_error: 3.6910e-04 - val_loss: 0.0227 - val_mean_absolute_error: 0.0138 - val_mean_squared_error: 3.7428e-04
# Epoch 17/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0227 - mean_absolute_error: 0.0134 - mean_squared_error: 3.6720e-04 - val_loss: 0.0226 - val_mean_absolute_error: 0.0137 - val_mean_squared_error: 3.7188e-04
# Epoch 18/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0226 - mean_absolute_error: 0.0133 - mean_squared_error: 3.6553e-04 - val_loss: 0.0225 - val_mean_absolute_error: 0.0137 - val_mean_squared_error: 3.7107e-04
# Epoch 19/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0225 - mean_absolute_error: 0.0133 - mean_squared_error: 3.6396e-04 - val_loss: 0.0225 - val_mean_absolute_error: 0.0137 - val_mean_squared_error: 3.6893e-04
# Epoch 20/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0225 - mean_absolute_error: 0.0133 - mean_squared_error: 3.6246e-04 - val_loss: 0.0224 - val_mean_absolute_error: 0.0136 - val_mean_squared_error: 3.6880e-04
# Epoch 21/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0224 - mean_absolute_error: 0.0132 - mean_squared_error: 3.6107e-04 - val_loss: 0.0223 - val_mean_absolute_error: 0.0136 - val_mean_squared_error: 3.6556e-04
# Epoch 22/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0224 - mean_absolute_error: 0.0132 - mean_squared_error: 3.5975e-04 - val_loss: 0.0223 - val_mean_absolute_error: 0.0136 - val_mean_squared_error: 3.6561e-04
# Epoch 23/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0223 - mean_absolute_error: 0.0131 - mean_squared_error: 3.5833e-04 - val_loss: 0.0222 - val_mean_absolute_error: 0.0135 - val_mean_squared_error: 3.6269e-04
# Epoch 24/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0223 - mean_absolute_error: 0.0131 - mean_squared_error: 3.5700e-04 - val_loss: 0.0222 - val_mean_absolute_error: 0.0135 - val_mean_squared_error: 3.6254e-04
# Epoch 25/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0222 - mean_absolute_error: 0.0131 - mean_squared_error: 3.5557e-04 - val_loss: 0.0221 - val_mean_absolute_error: 0.0134 - val_mean_squared_error: 3.5981e-04
# Epoch 26/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0222 - mean_absolute_error: 0.0130 - mean_squared_error: 3.5433e-04 - val_loss: 0.0221 - val_mean_absolute_error: 0.0134 - val_mean_squared_error: 3.5916e-04
# Epoch 27/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0221 - mean_absolute_error: 0.0130 - mean_squared_error: 3.5307e-04 - val_loss: 0.0220 - val_mean_absolute_error: 0.0133 - val_mean_squared_error: 3.5727e-04
# Epoch 28/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0221 - mean_absolute_error: 0.0130 - mean_squared_error: 3.5185e-04 - val_loss: 0.0220 - val_mean_absolute_error: 0.0133 - val_mean_squared_error: 3.5613e-04
# Epoch 29/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0221 - mean_absolute_error: 0.0129 - mean_squared_error: 3.5074e-04 - val_loss: 0.0219 - val_mean_absolute_error: 0.0133 - val_mean_squared_error: 3.5454e-04
# Epoch 30/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0220 - mean_absolute_error: 0.0129 - mean_squared_error: 3.4949e-04 - val_loss: 0.0219 - val_mean_absolute_error: 0.0132 - val_mean_squared_error: 3.5368e-04
# Epoch 31/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0220 - mean_absolute_error: 0.0129 - mean_squared_error: 3.4843e-04 - val_loss: 0.0219 - val_mean_absolute_error: 0.0132 - val_mean_squared_error: 3.5199e-04
# Epoch 32/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0219 - mean_absolute_error: 0.0129 - mean_squared_error: 3.4726e-04 - val_loss: 0.0219 - val_mean_absolute_error: 0.0132 - val_mean_squared_error: 3.5185e-04
# Epoch 33/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0219 - mean_absolute_error: 0.0128 - mean_squared_error: 3.4615e-04 - val_loss: 0.0218 - val_mean_absolute_error: 0.0131 - val_mean_squared_error: 3.4968e-04
# Epoch 34/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0219 - mean_absolute_error: 0.0128 - mean_squared_error: 3.4511e-04 - val_loss: 0.0217 - val_mean_absolute_error: 0.0131 - val_mean_squared_error: 3.4850e-04
# Epoch 35/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0218 - mean_absolute_error: 0.0128 - mean_squared_error: 3.4396e-04 - val_loss: 0.0217 - val_mean_absolute_error: 0.0131 - val_mean_squared_error: 3.4780e-04
# Epoch 36/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0218 - mean_absolute_error: 0.0127 - mean_squared_error: 3.4287e-04 - val_loss: 0.0217 - val_mean_absolute_error: 0.0131 - val_mean_squared_error: 3.4662e-04
# Epoch 37/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0218 - mean_absolute_error: 0.0127 - mean_squared_error: 3.4186e-04 - val_loss: 0.0217 - val_mean_absolute_error: 0.0131 - val_mean_squared_error: 3.4823e-04
# Epoch 38/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0217 - mean_absolute_error: 0.0127 - mean_squared_error: 3.4077e-04 - val_loss: 0.0216 - val_mean_absolute_error: 0.0130 - val_mean_squared_error: 3.4362e-04
# Epoch 39/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0217 - mean_absolute_error: 0.0127 - mean_squared_error: 3.3986e-04 - val_loss: 0.0216 - val_mean_absolute_error: 0.0130 - val_mean_squared_error: 3.4327e-04
# Epoch 40/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0217 - mean_absolute_error: 0.0126 - mean_squared_error: 3.3891e-04 - val_loss: 0.0215 - val_mean_absolute_error: 0.0130 - val_mean_squared_error: 3.4173e-04
# Epoch 41/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0216 - mean_absolute_error: 0.0126 - mean_squared_error: 3.3795e-04 - val_loss: 0.0215 - val_mean_absolute_error: 0.0129 - val_mean_squared_error: 3.4129e-04
# Epoch 42/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0216 - mean_absolute_error: 0.0126 - mean_squared_error: 3.3702e-04 - val_loss: 0.0215 - val_mean_absolute_error: 0.0129 - val_mean_squared_error: 3.3966e-04
# Epoch 43/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0216 - mean_absolute_error: 0.0126 - mean_squared_error: 3.3609e-04 - val_loss: 0.0214 - val_mean_absolute_error: 0.0129 - val_mean_squared_error: 3.3887e-04
# Epoch 44/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0216 - mean_absolute_error: 0.0126 - mean_squared_error: 3.3511e-04 - val_loss: 0.0215 - val_mean_absolute_error: 0.0129 - val_mean_squared_error: 3.3977e-04
# Epoch 45/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0215 - mean_absolute_error: 0.0125 - mean_squared_error: 3.3416e-04 - val_loss: 0.0214 - val_mean_absolute_error: 0.0129 - val_mean_squared_error: 3.3868e-04
# Epoch 46/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0215 - mean_absolute_error: 0.0125 - mean_squared_error: 3.3329e-04 - val_loss: 0.0214 - val_mean_absolute_error: 0.0129 - val_mean_squared_error: 3.3832e-04
# Epoch 47/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0215 - mean_absolute_error: 0.0125 - mean_squared_error: 3.3238e-04 - val_loss: 0.0213 - val_mean_absolute_error: 0.0128 - val_mean_squared_error: 3.3532e-04
# Epoch 48/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0214 - mean_absolute_error: 0.0125 - mean_squared_error: 3.3148e-04 - val_loss: 0.0213 - val_mean_absolute_error: 0.0128 - val_mean_squared_error: 3.3480e-04
# Epoch 49/50
# 1620/1620 [==============================] - 12s 8ms/step - loss: 0.0214 - mean_absolute_error: 0.0124 - mean_squared_error: 3.3067e-04 - val_loss: 0.0213 - val_mean_absolute_error: 0.0128 - val_mean_squared_error: 3.3622e-04
# Epoch 50/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0214 - mean_absolute_error: 0.0124 - mean_squared_error: 3.2975e-04 - val_loss: 0.0213 - val_mean_absolute_error: 0.0127 - val_mean_squared_error: 3.3295e-04
# [19:50:51] ======== Monitor (0): HostSketchContainer ========
# [19:50:51] AllReduce: 0.004891s, 1 calls @ 4891us
#
# [19:50:51] MakeCuts: 0.004925s, 1 calls @ 4925us
#
# [19:50:51] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [19:50:51] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# [19:50:52] ======== Monitor (0):  ========
# [19:50:52] InitCompressedData: 0.000828s, 1 calls @ 828us
#
# [19:50:58] ======== Monitor (0): Learner ========
# [19:50:58] Configure: 0.951061s, 1 calls @ 951061us
#
# [19:50:58] EvalOneIter: 0.002059s, 250 calls @ 2059us
#
# [19:50:58] GetGradient: 2.76983s, 250 calls @ 2769828us
#
# [19:50:58] PredictRaw: 0.000728s, 250 calls @ 728us
#
# [19:50:58] UpdateOneIter: 6.3954s, 250 calls @ 6395399us
#
# [19:50:58] ======== Monitor (0): GBTree ========
# [19:50:58] BoostNewTrees: 2.56867s, 250 calls @ 2568672us
#
# [19:50:58] CommitModel: 0.000213s, 250 calls @ 213us
#
# [19:50:58] ======== Device 0 Memory Allocations:  ========
# [19:50:58] Peak memory usage: 149MiB
# [19:50:58] Number of allocations: 23778
# [19:50:58] ======== Monitor (0): updater_gpu_hist ========
# [19:50:58] InitData: 0.000644s, 500 calls @ 644us
#
# [19:50:58] InitDataOnce: 0.000542s, 1 calls @ 542us
#
# [19:50:58] Update: 2.21165s, 500 calls @ 2211651us
#
# [19:50:58] UpdatePredictionCache: 0.245452s, 500 calls @ 245452us
#
# [19:50:58] ======== Monitor (0): gradient_based_sampler ========
# [19:50:58] Sample: 0.015648s, 500 calls @ 15648us
#
# [19:50:58] ======== Monitor (0): GPUHistMakerDevice0 ========
# [19:50:58] AllReduce: 0.001384s, 2500 calls @ 1384us
#
# [19:50:58] BuildHist: 0.05731s, 2500 calls @ 57310us
#
# [19:50:58] EvaluateSplits: 0.503644s, 2500 calls @ 503644us
#
# [19:50:58] FinalisePosition: 0.107352s, 500 calls @ 107352us
#
# [19:50:58] InitRoot: 0.528633s, 500 calls @ 528633us
#
# [19:50:58] Reset: 0.259949s, 500 calls @ 259949us
#
# [19:50:58] UpdatePosition: 0.737404s, 2500 calls @ 737404us
# /usr/local/lib/python3.10/dist-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cuda
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 0.00572 | val_0_rmse: 0.02278 |  0:01:25s
# epoch 1  | loss: 0.00058 | val_0_rmse: 0.02193 |  0:02:52s
# epoch 2  | loss: 0.00053 | val_0_rmse: 0.0219  |  0:04:17s
# epoch 3  | loss: 0.00051 | val_0_rmse: 0.02181 |  0:05:44s
# epoch 4  | loss: 0.0005  | val_0_rmse: 0.02187 |  0:07:10s
# epoch 5  | loss: 0.0005  | val_0_rmse: 0.02173 |  0:08:36s
# epoch 6  | loss: 0.00047 | val_0_rmse: 0.02219 |  0:10:01s
# epoch 7  | loss: 0.00047 | val_0_rmse: 0.02151 |  0:11:26s
# epoch 8  | loss: 0.00047 | val_0_rmse: 0.0215  |  0:12:51s
# epoch 9  | loss: 0.00046 | val_0_rmse: 0.02133 |  0:14:16s
# Stop training because you reached max_epochs = 10 with best_epoch = 9 and best_val_0_rmse = 0.02133
# /usr/local/lib/python3.10/dist-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 128)               1152
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dense_7 (Dense)             (None, 32)                2080
#
#  dense_8 (Dense)             (None, 16)                528
#
#  dense_9 (Dense)             (None, 2)                 34
#
# =================================================================
# Total params: 12050 (47.07 KB)
# Trainable params: 12050 (47.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 1620/1620 [==============================] - 11s 6ms/step - loss: 0.1982 - mean_absolute_error: 0.1506 - mean_squared_error: 0.1068 - val_loss: 0.0322 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 7.7993e-04
# Epoch 2/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0300 - mean_absolute_error: 0.0201 - mean_squared_error: 6.5564e-04 - val_loss: 0.0264 - val_mean_absolute_error: 0.0170 - val_mean_squared_error: 4.9590e-04
# Epoch 3/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0269 - mean_absolute_error: 0.0170 - mean_squared_error: 5.0809e-04 - val_loss: 0.0247 - val_mean_absolute_error: 0.0154 - val_mean_squared_error: 4.2957e-04
# Epoch 4/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0256 - mean_absolute_error: 0.0159 - mean_squared_error: 4.5919e-04 - val_loss: 0.0237 - val_mean_absolute_error: 0.0146 - val_mean_squared_error: 3.9501e-04
# Epoch 5/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0249 - mean_absolute_error: 0.0153 - mean_squared_error: 4.3547e-04 - val_loss: 0.0231 - val_mean_absolute_error: 0.0141 - val_mean_squared_error: 3.7863e-04
# Epoch 6/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0245 - mean_absolute_error: 0.0149 - mean_squared_error: 4.2138e-04 - val_loss: 0.0228 - val_mean_absolute_error: 0.0139 - val_mean_squared_error: 3.7140e-04
# Epoch 7/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0242 - mean_absolute_error: 0.0147 - mean_squared_error: 4.1176e-04 - val_loss: 0.0226 - val_mean_absolute_error: 0.0137 - val_mean_squared_error: 3.6756e-04
# Epoch 8/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0239 - mean_absolute_error: 0.0144 - mean_squared_error: 4.0465e-04 - val_loss: 0.0222 - val_mean_absolute_error: 0.0134 - val_mean_squared_error: 3.5456e-04
# Epoch 9/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0237 - mean_absolute_error: 0.0143 - mean_squared_error: 3.9926e-04 - val_loss: 0.0221 - val_mean_absolute_error: 0.0134 - val_mean_squared_error: 3.5346e-04
# Epoch 10/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0235 - mean_absolute_error: 0.0142 - mean_squared_error: 3.9492e-04 - val_loss: 0.0219 - val_mean_absolute_error: 0.0133 - val_mean_squared_error: 3.5032e-04
# Epoch 11/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0234 - mean_absolute_error: 0.0141 - mean_squared_error: 3.9107e-04 - val_loss: 0.0218 - val_mean_absolute_error: 0.0131 - val_mean_squared_error: 3.4515e-04
# Epoch 12/50
# 1620/1620 [==============================] - 13s 8ms/step - loss: 0.0233 - mean_absolute_error: 0.0140 - mean_squared_error: 3.8766e-04 - val_loss: 0.0217 - val_mean_absolute_error: 0.0131 - val_mean_squared_error: 3.4577e-04
# Epoch 13/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0231 - mean_absolute_error: 0.0139 - mean_squared_error: 3.8466e-04 - val_loss: 0.0216 - val_mean_absolute_error: 0.0130 - val_mean_squared_error: 3.4028e-04
# Epoch 14/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0230 - mean_absolute_error: 0.0138 - mean_squared_error: 3.8209e-04 - val_loss: 0.0213 - val_mean_absolute_error: 0.0128 - val_mean_squared_error: 3.3226e-04
# Epoch 15/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0230 - mean_absolute_error: 0.0137 - mean_squared_error: 3.7967e-04 - val_loss: 0.0214 - val_mean_absolute_error: 0.0128 - val_mean_squared_error: 3.3386e-04
# Epoch 16/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0229 - mean_absolute_error: 0.0137 - mean_squared_error: 3.7750e-04 - val_loss: 0.0212 - val_mean_absolute_error: 0.0127 - val_mean_squared_error: 3.2919e-04
# Epoch 17/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0228 - mean_absolute_error: 0.0136 - mean_squared_error: 3.7551e-04 - val_loss: 0.0212 - val_mean_absolute_error: 0.0128 - val_mean_squared_error: 3.3311e-04
# Epoch 18/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0227 - mean_absolute_error: 0.0136 - mean_squared_error: 3.7372e-04 - val_loss: 0.0211 - val_mean_absolute_error: 0.0126 - val_mean_squared_error: 3.2712e-04
# Epoch 19/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0227 - mean_absolute_error: 0.0135 - mean_squared_error: 3.7200e-04 - val_loss: 0.0210 - val_mean_absolute_error: 0.0126 - val_mean_squared_error: 3.2612e-04
# Epoch 20/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0226 - mean_absolute_error: 0.0135 - mean_squared_error: 3.7033e-04 - val_loss: 0.0210 - val_mean_absolute_error: 0.0126 - val_mean_squared_error: 3.2446e-04
# Epoch 21/50
# 1620/1620 [==============================] - 14s 8ms/step - loss: 0.0226 - mean_absolute_error: 0.0135 - mean_squared_error: 3.6889e-04 - val_loss: 0.0209 - val_mean_absolute_error: 0.0125 - val_mean_squared_error: 3.2172e-04
# Epoch 22/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0225 - mean_absolute_error: 0.0134 - mean_squared_error: 3.6759e-04 - val_loss: 0.0209 - val_mean_absolute_error: 0.0125 - val_mean_squared_error: 3.2354e-04
# Epoch 23/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0225 - mean_absolute_error: 0.0134 - mean_squared_error: 3.6623e-04 - val_loss: 0.0209 - val_mean_absolute_error: 0.0125 - val_mean_squared_error: 3.2114e-04
# Epoch 24/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0224 - mean_absolute_error: 0.0134 - mean_squared_error: 3.6505e-04 - val_loss: 0.0209 - val_mean_absolute_error: 0.0126 - val_mean_squared_error: 3.2368e-04
# Epoch 25/50
# 1620/1620 [==============================] - 13s 8ms/step - loss: 0.0224 - mean_absolute_error: 0.0133 - mean_squared_error: 3.6392e-04 - val_loss: 0.0208 - val_mean_absolute_error: 0.0125 - val_mean_squared_error: 3.2059e-04
# Epoch 26/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0224 - mean_absolute_error: 0.0133 - mean_squared_error: 3.6270e-04 - val_loss: 0.0208 - val_mean_absolute_error: 0.0125 - val_mean_squared_error: 3.2023e-04
# Epoch 27/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0223 - mean_absolute_error: 0.0133 - mean_squared_error: 3.6165e-04 - val_loss: 0.0208 - val_mean_absolute_error: 0.0124 - val_mean_squared_error: 3.1989e-04
# Epoch 28/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0223 - mean_absolute_error: 0.0133 - mean_squared_error: 3.6062e-04 - val_loss: 0.0207 - val_mean_absolute_error: 0.0124 - val_mean_squared_error: 3.1805e-04
# Epoch 29/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0223 - mean_absolute_error: 0.0132 - mean_squared_error: 3.5971e-04 - val_loss: 0.0208 - val_mean_absolute_error: 0.0125 - val_mean_squared_error: 3.2248e-04
# Epoch 30/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0222 - mean_absolute_error: 0.0132 - mean_squared_error: 3.5863e-04 - val_loss: 0.0208 - val_mean_absolute_error: 0.0126 - val_mean_squared_error: 3.2173e-04
# Epoch 31/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0222 - mean_absolute_error: 0.0132 - mean_squared_error: 3.5773e-04 - val_loss: 0.0207 - val_mean_absolute_error: 0.0124 - val_mean_squared_error: 3.1819e-04
# Epoch 32/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0222 - mean_absolute_error: 0.0132 - mean_squared_error: 3.5682e-04 - val_loss: 0.0206 - val_mean_absolute_error: 0.0123 - val_mean_squared_error: 3.1301e-04
# Epoch 33/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0221 - mean_absolute_error: 0.0131 - mean_squared_error: 3.5585e-04 - val_loss: 0.0206 - val_mean_absolute_error: 0.0123 - val_mean_squared_error: 3.1306e-04
# Epoch 34/50
# 1620/1620 [==============================] - 13s 8ms/step - loss: 0.0221 - mean_absolute_error: 0.0131 - mean_squared_error: 3.5503e-04 - val_loss: 0.0206 - val_mean_absolute_error: 0.0123 - val_mean_squared_error: 3.1554e-04
# Epoch 35/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0221 - mean_absolute_error: 0.0131 - mean_squared_error: 3.5419e-04 - val_loss: 0.0205 - val_mean_absolute_error: 0.0122 - val_mean_squared_error: 3.1024e-04
# Epoch 36/50
# 1620/1620 [==============================] - 13s 8ms/step - loss: 0.0220 - mean_absolute_error: 0.0131 - mean_squared_error: 3.5333e-04 - val_loss: 0.0205 - val_mean_absolute_error: 0.0123 - val_mean_squared_error: 3.1248e-04
# Epoch 37/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0220 - mean_absolute_error: 0.0131 - mean_squared_error: 3.5253e-04 - val_loss: 0.0205 - val_mean_absolute_error: 0.0123 - val_mean_squared_error: 3.1093e-04
# Epoch 38/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0220 - mean_absolute_error: 0.0130 - mean_squared_error: 3.5165e-04 - val_loss: 0.0204 - val_mean_absolute_error: 0.0122 - val_mean_squared_error: 3.0832e-04
# Epoch 39/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0220 - mean_absolute_error: 0.0130 - mean_squared_error: 3.5083e-04 - val_loss: 0.0204 - val_mean_absolute_error: 0.0122 - val_mean_squared_error: 3.0870e-04
# Epoch 40/50
# 1620/1620 [==============================] - 12s 8ms/step - loss: 0.0219 - mean_absolute_error: 0.0130 - mean_squared_error: 3.5004e-04 - val_loss: 0.0204 - val_mean_absolute_error: 0.0122 - val_mean_squared_error: 3.1092e-04
# Epoch 41/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0219 - mean_absolute_error: 0.0130 - mean_squared_error: 3.4917e-04 - val_loss: 0.0204 - val_mean_absolute_error: 0.0122 - val_mean_squared_error: 3.0842e-04
# Epoch 42/50
# 1620/1620 [==============================] - 12s 8ms/step - loss: 0.0219 - mean_absolute_error: 0.0130 - mean_squared_error: 3.4845e-04 - val_loss: 0.0205 - val_mean_absolute_error: 0.0123 - val_mean_squared_error: 3.1343e-04
# Epoch 43/50
# 1620/1620 [==============================] - 12s 8ms/step - loss: 0.0219 - mean_absolute_error: 0.0129 - mean_squared_error: 3.4764e-04 - val_loss: 0.0204 - val_mean_absolute_error: 0.0122 - val_mean_squared_error: 3.0813e-04
# Epoch 44/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0218 - mean_absolute_error: 0.0129 - mean_squared_error: 3.4687e-04 - val_loss: 0.0203 - val_mean_absolute_error: 0.0122 - val_mean_squared_error: 3.0618e-04
# Epoch 45/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0218 - mean_absolute_error: 0.0129 - mean_squared_error: 3.4614e-04 - val_loss: 0.0203 - val_mean_absolute_error: 0.0121 - val_mean_squared_error: 3.0659e-04
# Epoch 46/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0218 - mean_absolute_error: 0.0129 - mean_squared_error: 3.4545e-04 - val_loss: 0.0202 - val_mean_absolute_error: 0.0121 - val_mean_squared_error: 3.0290e-04
# Epoch 47/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0218 - mean_absolute_error: 0.0129 - mean_squared_error: 3.4466e-04 - val_loss: 0.0202 - val_mean_absolute_error: 0.0121 - val_mean_squared_error: 3.0254e-04
# Epoch 48/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0218 - mean_absolute_error: 0.0128 - mean_squared_error: 3.4382e-04 - val_loss: 0.0203 - val_mean_absolute_error: 0.0121 - val_mean_squared_error: 3.0669e-04
# Epoch 49/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0217 - mean_absolute_error: 0.0128 - mean_squared_error: 3.4319e-04 - val_loss: 0.0201 - val_mean_absolute_error: 0.0119 - val_mean_squared_error: 2.9791e-04
# Epoch 50/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0217 - mean_absolute_error: 0.0128 - mean_squared_error: 3.4240e-04 - val_loss: 0.0202 - val_mean_absolute_error: 0.0120 - val_mean_squared_error: 3.0313e-04
# [20:17:12] ======== Monitor (0): HostSketchContainer ========
# [20:17:12] AllReduce: 0.004982s, 1 calls @ 4982us
#
# [20:17:12] MakeCuts: 0.005016s, 1 calls @ 5016us
#
# [20:17:12] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [20:17:12] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# [20:17:12] ======== Monitor (0):  ========
# [20:17:12] InitCompressedData: 0.000356s, 1 calls @ 356us
#
# [20:17:18] ======== Monitor (0): Learner ========
# [20:17:18] Configure: 0.000812s, 1 calls @ 812us
#
# [20:17:18] EvalOneIter: 0.001642s, 250 calls @ 1642us
#
# [20:17:18] GetGradient: 2.86508s, 250 calls @ 2865083us
#
# [20:17:18] PredictRaw: 0.000486s, 250 calls @ 486us
#
# [20:17:18] UpdateOneIter: 5.53356s, 250 calls @ 5533560us
#
# [20:17:18] ======== Monitor (0): GBTree ========
# [20:17:18] BoostNewTrees: 2.56352s, 250 calls @ 2563525us
#
# [20:17:18] CommitModel: 0.000154s, 250 calls @ 154us
#
# [20:17:18] ======== Device 0 Memory Allocations:  ========
# [20:17:18] Peak memory usage: 180MiB
# [20:17:18] Number of allocations: 47556
# [20:17:18] ======== Monitor (0): updater_gpu_hist ========
# [20:17:18] InitData: 0.000816s, 500 calls @ 816us
#
# [20:17:18] InitDataOnce: 0.0007s, 1 calls @ 700us
#
# [20:17:18] Update: 2.19628s, 500 calls @ 2196277us
#
# [20:17:18] UpdatePredictionCache: 0.245683s, 500 calls @ 245683us
#
# [20:17:18] ======== Monitor (0): gradient_based_sampler ========
# [20:17:18] Sample: 0.011418s, 500 calls @ 11418us
#
# [20:17:18] ======== Monitor (0): GPUHistMakerDevice0 ========
# [20:17:18] AllReduce: 0.0014s, 2500 calls @ 1400us
#
# [20:17:18] BuildHist: 0.056776s, 2500 calls @ 56776us
#
# [20:17:18] EvaluateSplits: 0.505234s, 2500 calls @ 505234us
#
# [20:17:18] FinalisePosition: 0.09807s, 500 calls @ 98070us
#
# [20:17:18] InitRoot: 0.526488s, 500 calls @ 526488us
#
# [20:17:18] Reset: 0.255802s, 500 calls @ 255802us
#
# [20:17:18] UpdatePosition: 0.736123s, 2500 calls @ 736123us
# /usr/local/lib/python3.10/dist-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cuda
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 0.00552 | val_0_rmse: 0.02319 |  0:01:24s
# epoch 1  | loss: 0.00061 | val_0_rmse: 0.0212  |  0:02:49s
# epoch 2  | loss: 0.00056 | val_0_rmse: 0.02082 |  0:04:14s
# epoch 3  | loss: 0.00052 | val_0_rmse: 0.02026 |  0:05:39s
# epoch 4  | loss: 0.00052 | val_0_rmse: 0.02086 |  0:07:05s
# epoch 5  | loss: 0.00049 | val_0_rmse: 0.02006 |  0:08:30s
# epoch 6  | loss: 0.00048 | val_0_rmse: 0.02271 |  0:09:58s
# epoch 7  | loss: 0.00048 | val_0_rmse: 0.02045 |  0:11:24s
# epoch 8  | loss: 0.00047 | val_0_rmse: 0.02179 |  0:12:48s
# epoch 9  | loss: 0.00049 | val_0_rmse: 0.02029 |  0:14:13s
# Stop training because you reached max_epochs = 10 with best_epoch = 5 and best_val_0_rmse = 0.02006
# /usr/local/lib/python3.10/dist-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 128)               1152
#
#  dense_11 (Dense)            (None, 64)                8256
#
#  dense_12 (Dense)            (None, 32)                2080
#
#  dense_13 (Dense)            (None, 16)                528
#
#  dense_14 (Dense)            (None, 2)                 34
#
# =================================================================
# Total params: 12050 (47.07 KB)
# Trainable params: 12050 (47.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 1620/1620 [==============================] - 13s 7ms/step - loss: 0.2247 - mean_absolute_error: 0.1916 - mean_squared_error: 0.1060 - val_loss: 0.0305 - val_mean_absolute_error: 0.0208 - val_mean_squared_error: 6.7507e-04
# Epoch 2/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0289 - mean_absolute_error: 0.0188 - mean_squared_error: 5.9126e-04 - val_loss: 0.0275 - val_mean_absolute_error: 0.0178 - val_mean_squared_error: 5.3546e-04
# Epoch 3/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0268 - mean_absolute_error: 0.0167 - mean_squared_error: 4.9675e-04 - val_loss: 0.0259 - val_mean_absolute_error: 0.0164 - val_mean_squared_error: 4.7132e-04
# Epoch 4/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0257 - mean_absolute_error: 0.0158 - mean_squared_error: 4.5556e-04 - val_loss: 0.0252 - val_mean_absolute_error: 0.0157 - val_mean_squared_error: 4.4635e-04
# Epoch 5/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0251 - mean_absolute_error: 0.0153 - mean_squared_error: 4.3589e-04 - val_loss: 0.0247 - val_mean_absolute_error: 0.0153 - val_mean_squared_error: 4.3146e-04
# Epoch 6/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0247 - mean_absolute_error: 0.0149 - mean_squared_error: 4.2336e-04 - val_loss: 0.0244 - val_mean_absolute_error: 0.0150 - val_mean_squared_error: 4.2204e-04
# Epoch 7/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0244 - mean_absolute_error: 0.0147 - mean_squared_error: 4.1347e-04 - val_loss: 0.0241 - val_mean_absolute_error: 0.0148 - val_mean_squared_error: 4.1252e-04
# Epoch 8/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0241 - mean_absolute_error: 0.0144 - mean_squared_error: 4.0630e-04 - val_loss: 0.0239 - val_mean_absolute_error: 0.0146 - val_mean_squared_error: 4.0854e-04
# Epoch 9/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0239 - mean_absolute_error: 0.0143 - mean_squared_error: 4.0173e-04 - val_loss: 0.0238 - val_mean_absolute_error: 0.0146 - val_mean_squared_error: 4.0769e-04
# Epoch 10/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0238 - mean_absolute_error: 0.0142 - mean_squared_error: 3.9811e-04 - val_loss: 0.0236 - val_mean_absolute_error: 0.0144 - val_mean_squared_error: 4.0115e-04
# Epoch 11/50
# 1620/1620 [==============================] - 13s 8ms/step - loss: 0.0236 - mean_absolute_error: 0.0141 - mean_squared_error: 3.9521e-04 - val_loss: 0.0235 - val_mean_absolute_error: 0.0143 - val_mean_squared_error: 3.9886e-04
# Epoch 12/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0235 - mean_absolute_error: 0.0140 - mean_squared_error: 3.9235e-04 - val_loss: 0.0234 - val_mean_absolute_error: 0.0142 - val_mean_squared_error: 3.9687e-04
# Epoch 13/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0234 - mean_absolute_error: 0.0139 - mean_squared_error: 3.8973e-04 - val_loss: 0.0232 - val_mean_absolute_error: 0.0142 - val_mean_squared_error: 3.9340e-04
# Epoch 14/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0233 - mean_absolute_error: 0.0139 - mean_squared_error: 3.8717e-04 - val_loss: 0.0231 - val_mean_absolute_error: 0.0141 - val_mean_squared_error: 3.9108e-04
# Epoch 15/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0232 - mean_absolute_error: 0.0138 - mean_squared_error: 3.8471e-04 - val_loss: 0.0231 - val_mean_absolute_error: 0.0141 - val_mean_squared_error: 3.8922e-04
# Epoch 16/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0231 - mean_absolute_error: 0.0137 - mean_squared_error: 3.8247e-04 - val_loss: 0.0230 - val_mean_absolute_error: 0.0140 - val_mean_squared_error: 3.8742e-04
# Epoch 17/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0231 - mean_absolute_error: 0.0137 - mean_squared_error: 3.8019e-04 - val_loss: 0.0229 - val_mean_absolute_error: 0.0139 - val_mean_squared_error: 3.8645e-04
# Epoch 18/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0230 - mean_absolute_error: 0.0136 - mean_squared_error: 3.7815e-04 - val_loss: 0.0229 - val_mean_absolute_error: 0.0139 - val_mean_squared_error: 3.8363e-04
# Epoch 19/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0229 - mean_absolute_error: 0.0136 - mean_squared_error: 3.7603e-04 - val_loss: 0.0228 - val_mean_absolute_error: 0.0139 - val_mean_squared_error: 3.8326e-04
# Epoch 20/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0229 - mean_absolute_error: 0.0135 - mean_squared_error: 3.7401e-04 - val_loss: 0.0228 - val_mean_absolute_error: 0.0138 - val_mean_squared_error: 3.8082e-04
# Epoch 21/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0228 - mean_absolute_error: 0.0135 - mean_squared_error: 3.7201e-04 - val_loss: 0.0227 - val_mean_absolute_error: 0.0137 - val_mean_squared_error: 3.7829e-04
# Epoch 22/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0227 - mean_absolute_error: 0.0134 - mean_squared_error: 3.7011e-04 - val_loss: 0.0227 - val_mean_absolute_error: 0.0137 - val_mean_squared_error: 3.7802e-04
# Epoch 23/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0227 - mean_absolute_error: 0.0134 - mean_squared_error: 3.6830e-04 - val_loss: 0.0226 - val_mean_absolute_error: 0.0137 - val_mean_squared_error: 3.7680e-04
# Epoch 24/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0226 - mean_absolute_error: 0.0134 - mean_squared_error: 3.6661e-04 - val_loss: 0.0225 - val_mean_absolute_error: 0.0136 - val_mean_squared_error: 3.7424e-04
# Epoch 25/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0226 - mean_absolute_error: 0.0133 - mean_squared_error: 3.6501e-04 - val_loss: 0.0225 - val_mean_absolute_error: 0.0136 - val_mean_squared_error: 3.7264e-04
# Epoch 26/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0225 - mean_absolute_error: 0.0133 - mean_squared_error: 3.6335e-04 - val_loss: 0.0225 - val_mean_absolute_error: 0.0137 - val_mean_squared_error: 3.7389e-04
# Epoch 27/50
# 1620/1620 [==============================] - 12s 8ms/step - loss: 0.0225 - mean_absolute_error: 0.0132 - mean_squared_error: 3.6180e-04 - val_loss: 0.0224 - val_mean_absolute_error: 0.0136 - val_mean_squared_error: 3.7174e-04
# Epoch 28/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0224 - mean_absolute_error: 0.0132 - mean_squared_error: 3.6023e-04 - val_loss: 0.0224 - val_mean_absolute_error: 0.0135 - val_mean_squared_error: 3.6979e-04
# Epoch 29/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0224 - mean_absolute_error: 0.0132 - mean_squared_error: 3.5869e-04 - val_loss: 0.0224 - val_mean_absolute_error: 0.0135 - val_mean_squared_error: 3.6963e-04
# Epoch 30/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0223 - mean_absolute_error: 0.0131 - mean_squared_error: 3.5720e-04 - val_loss: 0.0223 - val_mean_absolute_error: 0.0134 - val_mean_squared_error: 3.6696e-04
# Epoch 31/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0223 - mean_absolute_error: 0.0131 - mean_squared_error: 3.5578e-04 - val_loss: 0.0224 - val_mean_absolute_error: 0.0135 - val_mean_squared_error: 3.7093e-04
# Epoch 32/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0222 - mean_absolute_error: 0.0131 - mean_squared_error: 3.5426e-04 - val_loss: 0.0222 - val_mean_absolute_error: 0.0134 - val_mean_squared_error: 3.6531e-04
# Epoch 33/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0222 - mean_absolute_error: 0.0130 - mean_squared_error: 3.5289e-04 - val_loss: 0.0222 - val_mean_absolute_error: 0.0134 - val_mean_squared_error: 3.6395e-04
# Epoch 34/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0221 - mean_absolute_error: 0.0130 - mean_squared_error: 3.5138e-04 - val_loss: 0.0222 - val_mean_absolute_error: 0.0133 - val_mean_squared_error: 3.6255e-04
# Epoch 35/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0221 - mean_absolute_error: 0.0130 - mean_squared_error: 3.4993e-04 - val_loss: 0.0221 - val_mean_absolute_error: 0.0133 - val_mean_squared_error: 3.6119e-04
# Epoch 36/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0221 - mean_absolute_error: 0.0129 - mean_squared_error: 3.4852e-04 - val_loss: 0.0221 - val_mean_absolute_error: 0.0133 - val_mean_squared_error: 3.6047e-04
# Epoch 37/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0220 - mean_absolute_error: 0.0129 - mean_squared_error: 3.4729e-04 - val_loss: 0.0221 - val_mean_absolute_error: 0.0133 - val_mean_squared_error: 3.6165e-04
# Epoch 38/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0220 - mean_absolute_error: 0.0129 - mean_squared_error: 3.4599e-04 - val_loss: 0.0220 - val_mean_absolute_error: 0.0132 - val_mean_squared_error: 3.5869e-04
# Epoch 39/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0219 - mean_absolute_error: 0.0129 - mean_squared_error: 3.4469e-04 - val_loss: 0.0220 - val_mean_absolute_error: 0.0132 - val_mean_squared_error: 3.5820e-04
# Epoch 40/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0219 - mean_absolute_error: 0.0128 - mean_squared_error: 3.4336e-04 - val_loss: 0.0219 - val_mean_absolute_error: 0.0132 - val_mean_squared_error: 3.5550e-04
# Epoch 41/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0219 - mean_absolute_error: 0.0128 - mean_squared_error: 3.4206e-04 - val_loss: 0.0219 - val_mean_absolute_error: 0.0132 - val_mean_squared_error: 3.5607e-04
# Epoch 42/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0218 - mean_absolute_error: 0.0128 - mean_squared_error: 3.4066e-04 - val_loss: 0.0219 - val_mean_absolute_error: 0.0131 - val_mean_squared_error: 3.5381e-04
# Epoch 43/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0218 - mean_absolute_error: 0.0127 - mean_squared_error: 3.3937e-04 - val_loss: 0.0219 - val_mean_absolute_error: 0.0131 - val_mean_squared_error: 3.5471e-04
# Epoch 44/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0217 - mean_absolute_error: 0.0127 - mean_squared_error: 3.3807e-04 - val_loss: 0.0219 - val_mean_absolute_error: 0.0131 - val_mean_squared_error: 3.5350e-04
# Epoch 45/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0217 - mean_absolute_error: 0.0127 - mean_squared_error: 3.3685e-04 - val_loss: 0.0218 - val_mean_absolute_error: 0.0130 - val_mean_squared_error: 3.4963e-04
# Epoch 46/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0217 - mean_absolute_error: 0.0126 - mean_squared_error: 3.3568e-04 - val_loss: 0.0217 - val_mean_absolute_error: 0.0130 - val_mean_squared_error: 3.4747e-04
# Epoch 47/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0216 - mean_absolute_error: 0.0126 - mean_squared_error: 3.3442e-04 - val_loss: 0.0217 - val_mean_absolute_error: 0.0130 - val_mean_squared_error: 3.4771e-04
# Epoch 48/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0216 - mean_absolute_error: 0.0126 - mean_squared_error: 3.3317e-04 - val_loss: 0.0217 - val_mean_absolute_error: 0.0129 - val_mean_squared_error: 3.4598e-04
# Epoch 49/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0216 - mean_absolute_error: 0.0126 - mean_squared_error: 3.3206e-04 - val_loss: 0.0217 - val_mean_absolute_error: 0.0129 - val_mean_squared_error: 3.4651e-04
# Epoch 50/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0215 - mean_absolute_error: 0.0125 - mean_squared_error: 3.3085e-04 - val_loss: 0.0217 - val_mean_absolute_error: 0.0130 - val_mean_squared_error: 3.4573e-04
# [20:43:23] ======== Monitor (0): HostSketchContainer ========
# [20:43:23] AllReduce: 0.006974s, 1 calls @ 6974us
#
# [20:43:23] MakeCuts: 0.007014s, 1 calls @ 7014us
#
# [20:43:23] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [20:43:23] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# [20:43:23] ======== Monitor (0):  ========
# [20:43:23] InitCompressedData: 0.000335s, 1 calls @ 335us
#
# [20:43:29] ======== Monitor (0): Learner ========
# [20:43:29] Configure: 0.001331s, 1 calls @ 1331us
#
# [20:43:29] EvalOneIter: 0.001606s, 250 calls @ 1606us
#
# [20:43:29] GetGradient: 2.69947s, 250 calls @ 2699465us
#
# [20:43:29] PredictRaw: 0.000491s, 250 calls @ 491us
#
# [20:43:29] UpdateOneIter: 5.37088s, 250 calls @ 5370879us
#
# [20:43:29] ======== Monitor (0): GBTree ========
# [20:43:29] BoostNewTrees: 2.56566s, 250 calls @ 2565663us
#
# [20:43:29] CommitModel: 0.000144s, 250 calls @ 144us
#
# [20:43:29] ======== Device 0 Memory Allocations:  ========
# [20:43:29] Peak memory usage: 211MiB
# [20:43:29] Number of allocations: 71334
# [20:43:29] ======== Monitor (0): updater_gpu_hist ========
# [20:43:29] InitData: 0.000454s, 500 calls @ 454us
#
# [20:43:29] InitDataOnce: 0.000352s, 1 calls @ 352us
#
# [20:43:29] Update: 2.20858s, 500 calls @ 2208584us
#
# [20:43:29] UpdatePredictionCache: 0.246353s, 500 calls @ 246353us
#
# [20:43:29] ======== Monitor (0): gradient_based_sampler ========
# [20:43:29] Sample: 0.011305s, 500 calls @ 11305us
#
# [20:43:29] ======== Monitor (0): GPUHistMakerDevice0 ========
# [20:43:29] AllReduce: 0.001374s, 2500 calls @ 1374us
#
# [20:43:29] BuildHist: 0.056528s, 2500 calls @ 56528us
#
# [20:43:29] EvaluateSplits: 0.508099s, 2500 calls @ 508099us
#
# [20:43:29] FinalisePosition: 0.105071s, 500 calls @ 105071us
#
# [20:43:29] InitRoot: 0.52989s, 500 calls @ 529890us
#
# [20:43:29] Reset: 0.254629s, 500 calls @ 254629us
#
# [20:43:29] UpdatePosition: 0.737371s, 2500 calls @ 737371us
#
# epoch 0  | loss: 0.00576 | val_0_rmse: 0.02327 |  0:01:24s
# epoch 1  | loss: 0.00064 | val_0_rmse: 0.02208 |  0:02:48s
# epoch 2  | loss: 0.00052 | val_0_rmse: 0.02166 |  0:04:12s
# epoch 3  | loss: 0.00049 | val_0_rmse: 0.02215 |  0:05:36s
# epoch 4  | loss: 0.00049 | val_0_rmse: 0.02172 |  0:06:59s
# epoch 5  | loss: 0.00047 | val_0_rmse: 0.02127 |  0:08:23s
# epoch 6  | loss: 0.00046 | val_0_rmse: 0.02124 |  0:09:47s
# epoch 7  | loss: 0.00046 | val_0_rmse: 0.02148 |  0:11:11s
# epoch 8  | loss: 0.00047 | val_0_rmse: 0.02157 |  0:12:35s
# epoch 9  | loss: 0.00047 | val_0_rmse: 0.02169 |  0:13:59s
# Stop training because you reached max_epochs = 10 with best_epoch = 6 and best_val_0_rmse = 0.02124
# /usr/local/lib/python3.10/dist-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 128)               1152
#
#  dense_16 (Dense)            (None, 64)                8256
#
#  dense_17 (Dense)            (None, 32)                2080
#
#  dense_18 (Dense)            (None, 16)                528
#
#  dense_19 (Dense)            (None, 2)                 34
#
# =================================================================
# Total params: 12050 (47.07 KB)
# Trainable params: 12050 (47.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 1620/1620 [==============================] - 13s 6ms/step - loss: 0.1335 - mean_absolute_error: 0.1109 - mean_squared_error: 0.0464 - val_loss: 0.0326 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 8.0435e-04
# Epoch 2/50
# 1620/1620 [==============================] - 12s 8ms/step - loss: 0.0301 - mean_absolute_error: 0.0203 - mean_squared_error: 6.6180e-04 - val_loss: 0.0289 - val_mean_absolute_error: 0.0192 - val_mean_squared_error: 6.1525e-04
# Epoch 3/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0275 - mean_absolute_error: 0.0178 - mean_squared_error: 5.4270e-04 - val_loss: 0.0271 - val_mean_absolute_error: 0.0175 - val_mean_squared_error: 5.3428e-04
# Epoch 4/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0261 - mean_absolute_error: 0.0165 - mean_squared_error: 4.8206e-04 - val_loss: 0.0257 - val_mean_absolute_error: 0.0162 - val_mean_squared_error: 4.7779e-04
# Epoch 5/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0251 - mean_absolute_error: 0.0156 - mean_squared_error: 4.4563e-04 - val_loss: 0.0249 - val_mean_absolute_error: 0.0155 - val_mean_squared_error: 4.4966e-04
# Epoch 6/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0246 - mean_absolute_error: 0.0151 - mean_squared_error: 4.2831e-04 - val_loss: 0.0244 - val_mean_absolute_error: 0.0152 - val_mean_squared_error: 4.3579e-04
# Epoch 7/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0242 - mean_absolute_error: 0.0149 - mean_squared_error: 4.1817e-04 - val_loss: 0.0241 - val_mean_absolute_error: 0.0149 - val_mean_squared_error: 4.2584e-04
# Epoch 8/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0239 - mean_absolute_error: 0.0147 - mean_squared_error: 4.1078e-04 - val_loss: 0.0239 - val_mean_absolute_error: 0.0148 - val_mean_squared_error: 4.1945e-04
# Epoch 9/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0237 - mean_absolute_error: 0.0145 - mean_squared_error: 4.0538e-04 - val_loss: 0.0236 - val_mean_absolute_error: 0.0146 - val_mean_squared_error: 4.1193e-04
# Epoch 10/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0235 - mean_absolute_error: 0.0144 - mean_squared_error: 4.0139e-04 - val_loss: 0.0234 - val_mean_absolute_error: 0.0145 - val_mean_squared_error: 4.0825e-04
# Epoch 11/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0234 - mean_absolute_error: 0.0143 - mean_squared_error: 3.9839e-04 - val_loss: 0.0233 - val_mean_absolute_error: 0.0144 - val_mean_squared_error: 4.0529e-04
# Epoch 12/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0233 - mean_absolute_error: 0.0142 - mean_squared_error: 3.9587e-04 - val_loss: 0.0232 - val_mean_absolute_error: 0.0143 - val_mean_squared_error: 4.0341e-04
# Epoch 13/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0232 - mean_absolute_error: 0.0142 - mean_squared_error: 3.9337e-04 - val_loss: 0.0231 - val_mean_absolute_error: 0.0143 - val_mean_squared_error: 4.0223e-04
# Epoch 14/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0231 - mean_absolute_error: 0.0141 - mean_squared_error: 3.9120e-04 - val_loss: 0.0230 - val_mean_absolute_error: 0.0142 - val_mean_squared_error: 3.9833e-04
# Epoch 15/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0230 - mean_absolute_error: 0.0140 - mean_squared_error: 3.8919e-04 - val_loss: 0.0229 - val_mean_absolute_error: 0.0141 - val_mean_squared_error: 3.9720e-04
# Epoch 16/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0229 - mean_absolute_error: 0.0140 - mean_squared_error: 3.8729e-04 - val_loss: 0.0229 - val_mean_absolute_error: 0.0141 - val_mean_squared_error: 3.9626e-04
# Epoch 17/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0228 - mean_absolute_error: 0.0139 - mean_squared_error: 3.8536e-04 - val_loss: 0.0227 - val_mean_absolute_error: 0.0140 - val_mean_squared_error: 3.9234e-04
# Epoch 18/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0228 - mean_absolute_error: 0.0139 - mean_squared_error: 3.8358e-04 - val_loss: 0.0227 - val_mean_absolute_error: 0.0141 - val_mean_squared_error: 3.9276e-04
# Epoch 19/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0227 - mean_absolute_error: 0.0138 - mean_squared_error: 3.8205e-04 - val_loss: 0.0226 - val_mean_absolute_error: 0.0139 - val_mean_squared_error: 3.8865e-04
# Epoch 20/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0226 - mean_absolute_error: 0.0138 - mean_squared_error: 3.8062e-04 - val_loss: 0.0226 - val_mean_absolute_error: 0.0139 - val_mean_squared_error: 3.8833e-04
# Epoch 21/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0226 - mean_absolute_error: 0.0138 - mean_squared_error: 3.7920e-04 - val_loss: 0.0225 - val_mean_absolute_error: 0.0140 - val_mean_squared_error: 3.8820e-04
# Epoch 22/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0225 - mean_absolute_error: 0.0137 - mean_squared_error: 3.7790e-04 - val_loss: 0.0224 - val_mean_absolute_error: 0.0138 - val_mean_squared_error: 3.8426e-04
# Epoch 23/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0225 - mean_absolute_error: 0.0137 - mean_squared_error: 3.7663e-04 - val_loss: 0.0224 - val_mean_absolute_error: 0.0138 - val_mean_squared_error: 3.8246e-04
# Epoch 24/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0224 - mean_absolute_error: 0.0137 - mean_squared_error: 3.7539e-04 - val_loss: 0.0223 - val_mean_absolute_error: 0.0138 - val_mean_squared_error: 3.8194e-04
# Epoch 25/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0224 - mean_absolute_error: 0.0136 - mean_squared_error: 3.7421e-04 - val_loss: 0.0223 - val_mean_absolute_error: 0.0138 - val_mean_squared_error: 3.8254e-04
# Epoch 26/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0224 - mean_absolute_error: 0.0136 - mean_squared_error: 3.7295e-04 - val_loss: 0.0222 - val_mean_absolute_error: 0.0137 - val_mean_squared_error: 3.7933e-04
# Epoch 27/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0223 - mean_absolute_error: 0.0136 - mean_squared_error: 3.7182e-04 - val_loss: 0.0222 - val_mean_absolute_error: 0.0137 - val_mean_squared_error: 3.7790e-04
# Epoch 28/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0223 - mean_absolute_error: 0.0136 - mean_squared_error: 3.7064e-04 - val_loss: 0.0221 - val_mean_absolute_error: 0.0136 - val_mean_squared_error: 3.7581e-04
# Epoch 29/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0222 - mean_absolute_error: 0.0135 - mean_squared_error: 3.6952e-04 - val_loss: 0.0221 - val_mean_absolute_error: 0.0136 - val_mean_squared_error: 3.7504e-04
# Epoch 30/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0222 - mean_absolute_error: 0.0135 - mean_squared_error: 3.6839e-04 - val_loss: 0.0221 - val_mean_absolute_error: 0.0136 - val_mean_squared_error: 3.7402e-04
# Epoch 31/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0222 - mean_absolute_error: 0.0135 - mean_squared_error: 3.6732e-04 - val_loss: 0.0221 - val_mean_absolute_error: 0.0136 - val_mean_squared_error: 3.7376e-04
# Epoch 32/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0221 - mean_absolute_error: 0.0135 - mean_squared_error: 3.6619e-04 - val_loss: 0.0220 - val_mean_absolute_error: 0.0135 - val_mean_squared_error: 3.7192e-04
# Epoch 33/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0221 - mean_absolute_error: 0.0134 - mean_squared_error: 3.6508e-04 - val_loss: 0.0220 - val_mean_absolute_error: 0.0135 - val_mean_squared_error: 3.7139e-04
# Epoch 34/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0221 - mean_absolute_error: 0.0134 - mean_squared_error: 3.6400e-04 - val_loss: 0.0219 - val_mean_absolute_error: 0.0135 - val_mean_squared_error: 3.6976e-04
# Epoch 35/50
# 1620/1620 [==============================] - 12s 8ms/step - loss: 0.0220 - mean_absolute_error: 0.0134 - mean_squared_error: 3.6263e-04 - val_loss: 0.0219 - val_mean_absolute_error: 0.0135 - val_mean_squared_error: 3.6913e-04
# Epoch 36/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0220 - mean_absolute_error: 0.0133 - mean_squared_error: 3.6149e-04 - val_loss: 0.0218 - val_mean_absolute_error: 0.0134 - val_mean_squared_error: 3.6682e-04
# Epoch 37/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0219 - mean_absolute_error: 0.0133 - mean_squared_error: 3.6034e-04 - val_loss: 0.0218 - val_mean_absolute_error: 0.0134 - val_mean_squared_error: 3.6598e-04
# Epoch 38/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0219 - mean_absolute_error: 0.0133 - mean_squared_error: 3.5922e-04 - val_loss: 0.0217 - val_mean_absolute_error: 0.0133 - val_mean_squared_error: 3.6377e-04
# Epoch 39/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0219 - mean_absolute_error: 0.0133 - mean_squared_error: 3.5810e-04 - val_loss: 0.0217 - val_mean_absolute_error: 0.0133 - val_mean_squared_error: 3.6337e-04
# Epoch 40/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0218 - mean_absolute_error: 0.0132 - mean_squared_error: 3.5706e-04 - val_loss: 0.0217 - val_mean_absolute_error: 0.0133 - val_mean_squared_error: 3.6174e-04
# Epoch 41/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0218 - mean_absolute_error: 0.0132 - mean_squared_error: 3.5603e-04 - val_loss: 0.0216 - val_mean_absolute_error: 0.0133 - val_mean_squared_error: 3.6020e-04
# Epoch 42/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0218 - mean_absolute_error: 0.0132 - mean_squared_error: 3.5502e-04 - val_loss: 0.0216 - val_mean_absolute_error: 0.0132 - val_mean_squared_error: 3.5813e-04
# Epoch 43/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0218 - mean_absolute_error: 0.0132 - mean_squared_error: 3.5402e-04 - val_loss: 0.0216 - val_mean_absolute_error: 0.0132 - val_mean_squared_error: 3.5863e-04
# Epoch 44/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0217 - mean_absolute_error: 0.0131 - mean_squared_error: 3.5308e-04 - val_loss: 0.0216 - val_mean_absolute_error: 0.0132 - val_mean_squared_error: 3.5790e-04
# Epoch 45/50
# 1620/1620 [==============================] - 12s 8ms/step - loss: 0.0217 - mean_absolute_error: 0.0131 - mean_squared_error: 3.5210e-04 - val_loss: 0.0215 - val_mean_absolute_error: 0.0132 - val_mean_squared_error: 3.5590e-04
# Epoch 46/50
# 1620/1620 [==============================] - 10s 6ms/step - loss: 0.0217 - mean_absolute_error: 0.0131 - mean_squared_error: 3.5114e-04 - val_loss: 0.0215 - val_mean_absolute_error: 0.0131 - val_mean_squared_error: 3.5520e-04
# Epoch 47/50
# 1620/1620 [==============================] - 12s 8ms/step - loss: 0.0216 - mean_absolute_error: 0.0131 - mean_squared_error: 3.5015e-04 - val_loss: 0.0214 - val_mean_absolute_error: 0.0131 - val_mean_squared_error: 3.5383e-04
# Epoch 48/50
# 1620/1620 [==============================] - 12s 7ms/step - loss: 0.0216 - mean_absolute_error: 0.0130 - mean_squared_error: 3.4920e-04 - val_loss: 0.0214 - val_mean_absolute_error: 0.0131 - val_mean_squared_error: 3.5231e-04
# Epoch 49/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0216 - mean_absolute_error: 0.0130 - mean_squared_error: 3.4823e-04 - val_loss: 0.0214 - val_mean_absolute_error: 0.0131 - val_mean_squared_error: 3.5312e-04
# Epoch 50/50
# 1620/1620 [==============================] - 11s 7ms/step - loss: 0.0216 - mean_absolute_error: 0.0130 - mean_squared_error: 3.4708e-04 - val_loss: 0.0214 - val_mean_absolute_error: 0.0130 - val_mean_squared_error: 3.5064e-04
# [21:09:18] ======== Monitor (0): HostSketchContainer ========
# [21:09:18] AllReduce: 0.004759s, 1 calls @ 4759us
#
# [21:09:18] MakeCuts: 0.004794s, 1 calls @ 4794us
#
# [21:09:18] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [21:09:18] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# [21:09:18] ======== Monitor (0):  ========
# [21:09:18] InitCompressedData: 0.000353s, 1 calls @ 353us
#
# [21:09:24] ======== Monitor (0): Learner ========
# [21:09:24] Configure: 0.000797s, 1 calls @ 797us
#
# [21:09:24] EvalOneIter: 0.00156s, 250 calls @ 1560us
#
# [21:09:24] GetGradient: 2.66475s, 250 calls @ 2664746us
#
# [21:09:24] PredictRaw: 0.000495s, 250 calls @ 495us
#
# [21:09:24] UpdateOneIter: 5.32568s, 250 calls @ 5325684us
#
# [21:09:24] ======== Monitor (0): GBTree ========
# [21:09:24] BoostNewTrees: 2.55513s, 250 calls @ 2555133us
#
# [21:09:24] CommitModel: 0.00012s, 250 calls @ 120us
#
# [21:09:24] ======== Device 0 Memory Allocations:  ========
# [21:09:24] Peak memory usage: 242MiB
# [21:09:24] Number of allocations: 95112
# [21:09:24] ======== Monitor (0): updater_gpu_hist ========
# [21:09:24] InitData: 0.00047s, 500 calls @ 470us
#
# [21:09:24] InitDataOnce: 0.000351s, 1 calls @ 351us
#
# [21:09:24] Update: 2.19944s, 500 calls @ 2199439us
#
# [21:09:24] UpdatePredictionCache: 0.245639s, 500 calls @ 245639us
#
# [21:09:24] ======== Monitor (0): gradient_based_sampler ========
# [21:09:24] Sample: 0.011235s, 500 calls @ 11235us
#
# [21:09:24] ======== Monitor (0): GPUHistMakerDevice0 ========
# [21:09:24] AllReduce: 0.001335s, 2500 calls @ 1335us
#
# [21:09:24] BuildHist: 0.055342s, 2500 calls @ 55342us
#
# [21:09:24] EvaluateSplits: 0.509836s, 2500 calls @ 509836us
#
# [21:09:24] FinalisePosition: 0.096936s, 500 calls @ 96936us
#
# [21:09:24] InitRoot: 0.530678s, 500 calls @ 530678us
#
# [21:09:24] Reset: 0.254077s, 500 calls @ 254077us
#
# [21:09:24] UpdatePosition: 0.736272s, 2500 calls @ 736272us
# /usr/local/lib/python3.10/dist-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cuda
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 0.00566 | val_0_rmse: 0.0227  |  0:01:24s
# epoch 1  | loss: 0.00059 | val_0_rmse: 0.02263 |  0:02:48s
# epoch 2  | loss: 0.00054 | val_0_rmse: 0.02248 |  0:04:13s
# epoch 3  | loss: 0.00053 | val_0_rmse: 0.02233 |  0:05:39s
# epoch 4  | loss: 0.00051 | val_0_rmse: 0.02215 |  0:07:04s
# epoch 5  | loss: 0.0005  | val_0_rmse: 0.02197 |  0:08:29s
# epoch 6  | loss: 0.00048 | val_0_rmse: 0.02147 |  0:09:54s
# epoch 7  | loss: 0.00049 | val_0_rmse: 0.02187 |  0:11:19s
# epoch 8  | loss: 0.00047 | val_0_rmse: 0.02155 |  0:12:44s
# epoch 9  | loss: 0.00047 | val_0_rmse: 0.02142 |  0:14:09s
# Stop training because you reached max_epochs = 10 with best_epoch = 9 and best_val_0_rmse = 0.02142
# /usr/local/lib/python3.10/dist-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)

# %% [markdown]
# # EVALUATION SIMULATION TEST DATA

# %%
# Evaluation tables simulated data
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
names = ['Permittivity_Real', 'Permittivity_Imaginary']
model_names = ["FNN","XGBoost","TabNet"]
num_models = len(model_dictionary)
num_targets = 2
y_pred_models = [[] for _ in range(num_models)]
y_test_targets = [[] for _ in range(num_targets)]
for i in range(num_models):
    nn_model, xgb_model, tabnet_model = model_dictionary[i]
    y_pred_nn = np.mean(nn_model.predict(X_test).reshape(-1,1001,2),axis=1)
    y_pred_nn[:,0] = y_pred_nn[:,0] * 100
    y_pred_xgb = np.mean(xgb_model.predict(X_test).reshape(-1,1001,2),axis=1)
    y_pred_xgb[:,0] = y_pred_xgb[:,0] * 100
    y_pred_tab = np.mean(tabnet_model.predict(X_test).reshape(-1,1001,2),axis=1)
    y_pred_tab[:,0] = y_pred_tab[:,0] * 100
    y_pred_models[i] = [y_pred_nn, y_pred_xgb, y_pred_tab]
    y_test_targets[0] = np.mean(y_test[:, 0].reshape(-1,1001),axis=1) * 100
    y_test_targets[1] = np.mean(y_test[:, 1].reshape(-1,1001),axis=1)
for t in range(num_targets):
    metrics_data = []
    y_test_target = y_test_targets[t]
    target_data = {
        "Target": names[t]
    }
    for model_type in range(len(y_pred_models[0])):
        mean = np.zeros_like(y_pred_models[0][model_type][:, t])
        squared_diff_sum = np.zeros_like(y_pred_models[0][model_type][:, t])
        for k_fold in range(len(y_pred_models)):
            y_pred_fold = y_pred_models[k_fold][model_type][:, t]
            mean += y_pred_fold
            squared_diff_sum += (y_pred_fold - mean) ** 2
        mean = mean / len(y_pred_models)
        std_deviation = np.sqrt(squared_diff_sum / len(y_pred_models))
        mse = mean_squared_error(y_test_target, mean)
        mae = mean_absolute_error(y_test_target, mean)
        rmse = np.sqrt(mse)
        r_squared = r2_score(y_test_target, mean)
        target_data[f"Mean ({model_names[model_type]})"] = mean
        target_data[f"SD ({model_names[model_type]})"] = std_deviation
        target_data[f"MSE ({model_names[model_type]})"] = mse
        target_data[f"MAE ({model_names[model_type]})"] = mae
        target_data[f"RMSE ({model_names[model_type]})"] = rmse
        target_data[f"R² ({model_names[model_type]})"] = r_squared

    metrics_data.append(target_data)
    metrics_df = pd.DataFrame(metrics_data)
    display(metrics_df)
# Out:
# 6288/6288 [==============================] - 38s 6ms/step
# [21:26:34] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [21:26:34] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [21:26:34] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# 6288/6288 [==============================] - 35s 6ms/step
# [21:27:19] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [21:27:19] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# 6288/6288 [==============================] - 32s 5ms/step
# [21:28:01] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [21:28:01] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# 6288/6288 [==============================] - 36s 6ms/step
# [21:28:47] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [21:28:47] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
#               Target                                         Mean (FNN)  \
# 0  Permittivity_Real  [1.226271, 7.930952, 7.4290886, 6.9276514, 5.9...
#
#                                             SD (FNN)  MSE (FNN)  MAE (FNN)  \
# 0  [2.3264346, 14.987247, 13.994014, 13.074572, 1...   0.135839   0.268564
#
#    RMSE (FNN)  R² (FNN)                                     Mean (XGBoost)  \
# 0    0.368564  0.971096  [1.3210931, 8.233148, 7.4819565, 6.9533195, 5....
#
#                                         SD (XGBoost)  MSE (XGBoost)  \
# 0  [2.4722033, 15.398713, 13.993051, 13.006527, 1...       0.109035
#
#    MAE (XGBoost)  RMSE (XGBoost)  R² (XGBoost)  \
# 0       0.249522        0.330205      0.976799
#
#                                        Mean (TabNet)  \
# 0  [1.9117138, 7.8938613, 7.3603373, 6.968379, 5....
#
#                                          SD (TabNet)  MSE (TabNet)  \
# 0  [3.5838547, 14.7514515, 13.778556, 13.07198, 1...      0.218388
#
#    MAE (TabNet)  RMSE (TabNet)  R² (TabNet)
# 0      0.391796        0.46732      0.95353
#                    Target                                         Mean (FNN)  \
# 0  Permittivity_Imaginary  [0.047212996, 0.03937146, 0.045656428, 0.04243...
#
#                                             SD (FNN)  MSE (FNN)  MAE (FNN)  \
# 0  [0.08870587, 0.07292706, 0.08469621, 0.0786819...   0.000552    0.02062
#
#    RMSE (FNN)  R² (FNN)                                     Mean (XGBoost)  \
# 0    0.023496  0.355554  [0.048453577, 0.030561902, 0.04489419, 0.04130...
#
#                                         SD (XGBoost)  MSE (XGBoost)  \
# 0  [0.090699494, 0.05702089, 0.08367679, 0.077162...       0.000483
#
#    MAE (XGBoost)  RMSE (XGBoost)  R² (XGBoost)  \
# 0       0.019144        0.021968      0.436652
#
#                                        Mean (TabNet)  \
# 0  [0.049298637, 0.050101783, 0.05007772, 0.05000...
#
#                                          SD (TabNet)  MSE (TabNet)  \
# 0  [0.09298056, 0.09325053, 0.093261726, 0.093186...      0.000854
#
#    MAE (TabNet)  RMSE (TabNet)  R² (TabNet)
# 0      0.025922       0.029226     0.002843

# %%
# Evaluation plots simulated data
names = ['Permittivity_Real', 'Permittivity_Imaginary']
model_names = ["FNN","XGBoost","TabNet"]
num_models = len(model_dictionary)
num_targets = 2
y_pred_models = [[] for _ in range(num_models)]
y_test_targets = [[] for _ in range(num_targets)]
for i in range(num_models):
    nn_model, xgb_model, tabnet_model = model_dictionary[i]
    y_pred_nn = np.mean(nn_model.predict(X_test).reshape(-1,1001,2),axis=1)
    y_pred_nn[:,0] = y_pred_nn[:,0] * 100
    y_pred_xgb = np.mean(xgb_model.predict(X_test).reshape(-1,1001,2),axis=1)
    y_pred_xgb[:,0] = y_pred_xgb[:,0] * 100
    y_pred_tab = np.mean(tabnet_model.predict(X_test).reshape(-1,1001,2),axis=1)
    y_pred_tab[:,0] = y_pred_tab[:,0] * 100
    y_pred_models[i] = [y_pred_nn, y_pred_xgb, y_pred_tab]
    y_test_targets[0] = np.mean(y_test[:, 0].reshape(-1,1001),axis=1) * 100
    y_test_targets[1] = np.mean(y_test[:, 1].reshape(-1,1001),axis=1)
for t in range(num_targets):
  y_test_target = y_test_targets[t]
  plt.figure(figsize=(6, 4))
  plt.plot(range(len(y_test_target)), y_test_target, label='Actual', color='blue', alpha=0.7)
  for model_type in range(len(y_pred_models[0])):
    mean = np.zeros_like(y_pred_models[0][model_type][:, t])
    squared_diff_sum = np.zeros_like(y_pred_models[0][model_type][:, t])
    for k_fold in range(len(y_pred_models)):
      y_pred_fold = y_pred_models[k_fold][model_type][:, t]
      mean += y_pred_fold
    mean = mean / len(y_pred_models)
    for k_fold in range(len(y_pred_models)):
      y_pred_fold = y_pred_models[k_fold][model_type][:, t]
      squared_diff_sum += (y_pred_fold - mean) ** 2
    std_deviation = np.sqrt(squared_diff_sum / len(y_pred_models))
    std_deviation = np.sqrt(squared_diff_sum / len(y_pred_models))
    plt.plot(range(len(y_test_target)), mean, label=f'Predicted Mean (Model {model_names[model_type]})', alpha=0.7)
    plt.fill_between(range(len(y_test_target)), mean - std_deviation, mean + std_deviation, alpha=0.2, label=f'Standard Deviation (Model {model_names[model_type]})')
  plt.title(f'Simulated Meteorite Actual and Predicted (Target {names[t]})')
  plt.xlabel('Data Point')
  plt.ylabel('Value')
  plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
  plt.show()
# Out:
# 6288/6288 [==============================] - 33s 5ms/step
# 6288/6288 [==============================] - 30s 5ms/step
# 6288/6288 [==============================] - 32s 5ms/step
# 6288/6288 [==============================] - 33s 5ms/step

# %% [markdown]
# # EVALUATION ACTUAL TEST DATA

# %%
X_test = testing_dataframe[columns].values
y_test = testing_dataframe[['Permittivity_Real', 'Permittivity_Imaginary']].values

# %%
# Evaluation tables actual data
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
names = ['Permittivity_Real', 'Permittivity_Imaginary']
model_names = ["FNN","XGBoost","TabNet"]
num_models = len(model_dictionary)
num_targets = 2
y_pred_models = [[] for _ in range(num_models)]
y_test_targets = [[] for _ in range(num_targets)]
for i in range(num_models):
    nn_model, xgb_model, tabnet_model = model_dictionary[i]
    y_pred_nn = np.mean(nn_model.predict(X_test).reshape(-1,1001,2),axis=1)
    y_pred_nn[:,0] = y_pred_nn[:,0] * 100
    y_pred_xgb = np.mean(xgb_model.predict(X_test).reshape(-1,1001,2),axis=1)
    y_pred_xgb[:,0] = y_pred_xgb[:,0] * 100
    y_pred_tab = np.mean(tabnet_model.predict(X_test).reshape(-1,1001,2),axis=1)
    y_pred_tab[:,0] = y_pred_tab[:,0] * 100
    y_pred_models[i] = [y_pred_nn, y_pred_xgb, y_pred_tab]
    y_test_targets[0] = np.mean(y_test[:, 0].reshape(-1,1001),axis=1) * 100
    y_test_targets[1] = np.mean(y_test[:, 1].reshape(-1,1001),axis=1)
for t in range(num_targets):
    metrics_data = []
    y_test_target = y_test_targets[t]
    target_data = {
        "Target": names[t]
    }
    for model_type in range(len(y_pred_models[0])):
        mean = np.zeros_like(y_pred_models[0][model_type][:, t])
        squared_diff_sum = np.zeros_like(y_pred_models[0][model_type][:, t])
        for k_fold in range(len(y_pred_models)):
            y_pred_fold = y_pred_models[k_fold][model_type][:, t]
            mean += y_pred_fold
            squared_diff_sum += (y_pred_fold - mean) ** 2
        mean = mean / len(y_pred_models)
        std_deviation = np.sqrt(squared_diff_sum / len(y_pred_models))
        mse = mean_squared_error(y_test_target, mean)
        mae = mean_absolute_error(y_test_target, mean)
        rmse = np.sqrt(mse)
        r_squared = r2_score(y_test_target, mean)
        target_data[f"Mean ({model_names[model_type]})"] = mean
        target_data[f"SD ({model_names[model_type]})"] = std_deviation
        target_data[f"MSE ({model_names[model_type]})"] = mse
        target_data[f"MAE ({model_names[model_type]})"] = mae
        target_data[f"RMSE ({model_names[model_type]})"] = rmse
        target_data[f"R² ({model_names[model_type]})"] = r_squared

    metrics_data.append(target_data)
    metrics_df = pd.DataFrame(metrics_data)
    display(metrics_df)
# Out:
# 126/126 [==============================] - 0s 1ms/step
# 126/126 [==============================] - 0s 1ms/step
# 126/126 [==============================] - 2s 18ms/step
# 126/126 [==============================] - 0s 1ms/step
#               Target                                    Mean (FNN)  \
# 0  Permittivity_Real  [4.9646583, 5.5246925, 4.9246683, 5.5345774]
#
#                                    SD (FNN)  MSE (FNN)  MAE (FNN)  RMSE (FNN)  \
# 0  [7.869646, 8.564607, 7.8065734, 8.60349]   6.451434   2.512851    2.539967
#
#     R² (FNN)                            Mean (XGBoost)  \
# 0 -33.407649  [7.009429, 8.076754, 6.972565, 8.028368]
#
#                                    SD (XGBoost)  MSE (XGBoost)  MAE (XGBoost)  \
# 0  [13.007445, 14.976421, 12.940763, 14.882782]       0.265602       0.285496
#
#    RMSE (XGBoost)  R² (XGBoost)                           Mean (TabNet)  \
# 0        0.515366     -0.416543  [6.1354, 7.142061, 6.099071, 7.105197]
#
#                                     SD (TabNet)  MSE (TabNet)  MAE (TabNet)  \
# 0  [11.313408, 13.117522, 11.245729, 13.049132]      1.474449      1.129568
#
#    RMSE (TabNet)  R² (TabNet)
# 0       1.214269    -6.863728
#                    Target                                        Mean (FNN)  \
# 0  Permittivity_Imaginary  [0.14559047, 0.15155314, 0.14542012, 0.15182954]
#
#                                          SD (FNN)  MSE (FNN)  MAE (FNN)  \
# 0  [0.29907724, 0.311363, 0.29905996, 0.31181103]   0.193738   0.294197
#
#    RMSE (FNN)  R² (FNN)                                   Mean (XGBoost)  \
# 0    0.440157 -0.703942  [0.20530304, 0.2449851, 0.20404397, 0.24094741]
#
#                                        SD (XGBoost)  MSE (XGBoost)  \
# 0  [0.37029374, 0.44965944, 0.36789975, 0.44204956]       0.161834
#
#    MAE (XGBoost)  RMSE (XGBoost)  R² (XGBoost)  \
# 0       0.248832        0.402286     -0.423343
#
#                                        Mean (TabNet)  \
# 0  [0.0524763, 0.052350268, 0.052473135, 0.05240135]
#
#                                          SD (TabNet)  MSE (TabNet)  \
# 0  [0.09856591, 0.09829298, 0.098558635, 0.098415...      0.256251
#
#    MAE (TabNet)  RMSE (TabNet)  R² (TabNet)
# 0      0.377575       0.506212    -1.253743

# %%
# Evaluation plots actual data
names = ['Permittivity_Real', 'Permittivity_Imaginary']
model_names = ["FNN","XGBoost","TabNet"]
num_models = len(model_dictionary)
num_targets = 2
y_pred_models = [[] for _ in range(num_models)]
y_test_targets = [[] for _ in range(num_targets)]
for i in range(num_models):
    nn_model, xgb_model, tabnet_model = model_dictionary[i]
    y_pred_nn = np.mean(nn_model.predict(X_test).reshape(-1,1001,2),axis=1)
    y_pred_nn[:,0] = y_pred_nn[:,0] * 100
    y_pred_xgb = np.mean(xgb_model.predict(X_test).reshape(-1,1001,2),axis=1)
    y_pred_xgb[:,0] = y_pred_xgb[:,0] * 100
    y_pred_tab = np.mean(tabnet_model.predict(X_test).reshape(-1,1001,2),axis=1)
    y_pred_tab[:,0] = y_pred_tab[:,0] * 100
    y_pred_models[i] = [y_pred_nn, y_pred_xgb, y_pred_tab]
    y_test_targets[0] = np.mean(y_test[:, 0].reshape(-1,1001),axis=1) * 100
    y_test_targets[1] = np.mean(y_test[:, 1].reshape(-1,1001),axis=1)
for t in range(num_targets):
  y_test_target = y_test_targets[t]
  plt.figure(figsize=(6, 4))
  plt.plot(range(len(y_test_target)), y_test_target, label='Actual', color='blue', alpha=0.7)
  for model_type in range(len(y_pred_models[0])):
    mean = np.zeros_like(y_pred_models[0][model_type][:, t])
    squared_diff_sum = np.zeros_like(y_pred_models[0][model_type][:, t])
    for k_fold in range(len(y_pred_models)):
      y_pred_fold = y_pred_models[k_fold][model_type][:, t]
      mean += y_pred_fold
    mean = mean / len(y_pred_models)
    for k_fold in range(len(y_pred_models)):
      y_pred_fold = y_pred_models[k_fold][model_type][:, t]
      squared_diff_sum += (y_pred_fold - mean) ** 2
    std_deviation = np.sqrt(squared_diff_sum / len(y_pred_models))
    std_deviation = np.sqrt(squared_diff_sum / len(y_pred_models))
    plt.plot(range(len(y_test_target)), mean, label=f'Predicted Mean (Model {model_names[model_type]})', alpha=0.7)
    plt.fill_between(range(len(y_test_target)), mean - std_deviation, mean + std_deviation, alpha=0.2, label=f'Standard Deviation (Model {model_names[model_type]})')
  plt.title(f'Actual Meteorite Actual and Predicted (Target {names[t]})')
  plt.xlabel('Data Point')
  plt.ylabel('Value')
  plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
  plt.show()
# Out:
# 126/126 [==============================] - 4s 36ms/step
# 126/126 [==============================] - 0s 1ms/step
# 126/126 [==============================] - 0s 1ms/step
# 126/126 [==============================] - 3s 23ms/step
