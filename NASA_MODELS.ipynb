# %% [markdown]
# # Preprocessing

# %%
# !git clone https://github.com/DanteMillerDS/NASA-Material-Classifier.git
# Out:
# Cloning into 'NASA-Material-Classifier'...
# remote: Enumerating objects: 111, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 111 (delta 5), reused 11 (delta 2), pack-reused 97
# Receiving objects: 100% (111/111), 45.44 MiB | 12.39 MiB/s, done.
# Resolving deltas: 100% (33/33), done.

# %%
# %cd NASA-Material-Classifier
# Out:
# /content/NASA-Material-Classifier/NASA-Material-Classifier/NASA-Material-Classifier/NASA-Material-Classifier

# %%
import numpy as np
np.random.seed(1000)
import pandas as pd
import torch.nn.functional as F
import tensorflow as tf
tf.random.set_seed(1000)
from tensorflow import keras
import matplotlib.pyplot as plt
import seaborn as sns
import torch.optim.lr_scheduler as lr_scheduler
import scipy.io
import torch.nn as nn
from sklearn.model_selection import train_test_split
import uuid
import torch
from keras.layers import Bidirectional, LSTM, Dense
import pandas as pd
from torch.utils.data import Dataset, DataLoader

# %%
file_paths = dict()
file_paths[0] = [
    "data/S11_parameter_data_for_zero_orientation.txt",
    "data/S12_parameter_data_for_zero_orientation.txt",
    "data/S21_parameter_data_for_zero_orientation.txt",
    "data/S22_parameter_data_for_zero_orientation.txt"]
file_paths[1] = [
    "data/S11_parameter_data_for_CW90_orientation.txt",
    "data/S12_parameter_data_for_CW90_orientation.txt",
    "data/S21_parameter_data_for_CW90_orientation.txt",
    "data/S22_parameter_data_for_CW90_orientation.txt"]
file_paths[2] = [
    "data/S11_parameter_data_for_CCW90_orientation.txt",
    "data/S12_parameter_data_for_CCW90_orientation.txt",
    "data/S21_parameter_data_for_CCW90_orientation.txt",
    "data/S22_parameter_data_for_CCW90_orientation.txt"]
file_paths[3] = [
    "data/S11_parameter_data_for_tilt_orientation.txt",
    "data/S12_parameter_data_for_tilt_orientation.txt",
    "data/S21_parameter_data_for_tilt_orientation.txt",
    "data/S22_parameter_data_for_tilt_orientation.txt"]
def process_file(file_path,orientation):
    datasets = []
    with open(file_path, 'r') as file:
        current_dataset = []
        for line in file:
            if line.startswith("#Parameters"):
                if current_dataset:
                    datasets.append(current_dataset)
                    current_dataset = []
                params_str = line[line.index("{") + 1:line.index("}")]
                params = dict(param.split('=') for param in params_str.split(';'))
                current_dataset.append(params)
            elif line.startswith("#"):
                continue
            else:
                data = line.strip().split('\t')
                current_dataset.append(data)
        if current_dataset:
            datasets.append(current_dataset)
    data = []
    for dataset in datasets:
        permittivity_values = dataset[0]
        df_data = dataset[1:]
        s_parameter_name = file_path.split("_parameter_data_for_")[0]
        df = pd.DataFrame(df_data, columns=["Frequency", f"{s_parameter_name}_Real", f"{s_parameter_name}_Imaginary"])
        df["Orientation"] = orientation
        df["ID"] = str(uuid.uuid4())[:8]
        for key, value in permittivity_values.items():
            if "er1" in key or "er11" in key:
                df[key] = value
        data.append(df)
    return data
all_combined_data = []
for index in file_paths:
    for file in file_paths[index]:
        combined_data = process_file(file,index)
        combined_data = pd.concat(combined_data, ignore_index=True)
        all_combined_data.append(combined_data)
array = []
group_size = 4
for i in range(0, len(all_combined_data), group_size):
    combined_dataframe = pd.concat(all_combined_data[i:i+group_size], axis=1)
    combined_dataframe.reset_index(drop=True, inplace=True)
    array.append(combined_dataframe)
training_dataframe = pd.concat(array, axis=0)
training_dataframe.reset_index(drop=True, inplace=True)
training_dataframe = training_dataframe.loc[:, ~training_dataframe.columns.duplicated()]

# %%
file_paths = dict()
file_paths[0] = ["data/mea_rot_0.txt"]
file_paths[1] = ["data/mea_rot_cw90.txt"]
file_paths[2] = ["data/mea_rot_ccw90.txt"]
file_paths[3] = ["data/mea_rot_0_tilt.txt"]
def process_file(file_path,orientation):
    datasets = []
    with open(file_path, 'r') as file:
        current_dataset = []
        for line in file:
            if line.startswith("#Parameters"):
                if current_dataset:
                    datasets.append(current_dataset)
                    current_dataset = []
                params_str = line[line.index("{") + 1:line.index("}")]
                params = dict(param.split('=') for param in params_str.split(';'))
                current_dataset.append(params)
            elif line.startswith("#"):
                continue
            else:
                data = line.strip().split('\t')
                current_dataset.append(data)
        if current_dataset:
            datasets.append(current_dataset)
    dictionary = {
    0: "S11",
    1: "S21",
    2: "S12",
    3: "S22"
    }
    data = []
    for index, dataset in enumerate(datasets):
        permittivity_values = dataset[0]
        df_data = dataset[1:]
        s_parameter_name = dictionary[index]
        df = pd.DataFrame(df_data, columns=["Frequency", f"{s_parameter_name}_Real", f"{s_parameter_name}_Imaginary"])
        df["Orientation"] = orientation
        df["ID"] = str(uuid.uuid4())[:8]
        for key, value in permittivity_values.items():
            if "er1" in key or "er11" in key:
                df[key] = value
        data.append(df)
    return data
all_combined_data = []
for index in file_paths:
    for file in file_paths[index]:
        combined_data = process_file(file,index)
        all_combined_data.append(combined_data)
array = []
group_size = 4
for group in range(len(all_combined_data)):
    for i in range(0, len(all_combined_data[group]), group_size):
        combined_dataframe = pd.concat(all_combined_data[group][i:i+group_size], axis=1)
        combined_dataframe.reset_index(drop=True, inplace=True)
        array.append(combined_dataframe)
testing_dataframe = pd.concat(array, axis=0)
testing_dataframe.reset_index(drop=True, inplace=True)
testing_dataframe = testing_dataframe.loc[:, ~testing_dataframe.columns.duplicated()]

# %%
training_dataframe.columns = ['Frequency', 'S11_Real', 'S11_Imaginary', 'Orientation', 'ID','Permittivity_Real', 'Permittivity_Imaginary', 'S21_Real',
       'S21_Imaginary', 'S12_Real', 'S12_Imaginary', 'S22_Real',
       'S22_Imaginary']
training_dataframe = training_dataframe[['ID','Frequency', 'Orientation', 'Permittivity_Real', 'Permittivity_Imaginary','S11_Real', 'S11_Imaginary', 'S12_Real',
       'S12_Imaginary', 'S21_Real', 'S21_Imaginary', 'S22_Real',
       'S22_Imaginary']]
testing_dataframe.columns = ['Frequency', 'S11_Real', 'S11_Imaginary', 'Orientation', 'ID','Permittivity_Real', 'Permittivity_Imaginary', 'S21_Real',
       'S21_Imaginary', 'S12_Real', 'S12_Imaginary', 'S22_Real',
       'S22_Imaginary']
testing_dataframe = testing_dataframe[['ID','Frequency', 'Orientation',  'Permittivity_Real', 'Permittivity_Imaginary','S11_Real', 'S11_Imaginary', 'S12_Real',
       'S12_Imaginary', 'S21_Real', 'S21_Imaginary', 'S22_Real',
       'S22_Imaginary']]

# %%
training_dataframe.dropna(inplace=True)
columns = training_dataframe.columns[1:]
training_dataframe[columns] = training_dataframe[columns].apply(pd.to_numeric)
testing_dataframe.dropna(inplace=True)
testing_dataframe[columns] = testing_dataframe[columns].apply(pd.to_numeric)

# %%
training_dataframe["Permittivity_Real"] /= 100
testing_dataframe["Permittivity_Real"] /= 100

# %%
training_dataframe = training_dataframe.iloc[:,1:]
testing_dataframe = testing_dataframe.iloc[:,1:]

# %%
columns = []
for column in training_dataframe.columns:
    if column != "Permittivity_Real" and column !="Permittivity_Imaginary":
        columns.append(column)
columns
# Out:
# ['Frequency',
#  'Orientation',
#  'S11_Real',
#  'S11_Imaginary',
#  'S12_Real',
#  'S12_Imaginary',
#  'S21_Real',
#  'S21_Imaginary',
#  'S22_Real',
#  'S22_Imaginary']

# %%
testing_dataframe['Permittivity_Imaginary'][testing_dataframe['Permittivity_Imaginary'] == 0.4] = 0.1
# Out:
# <ipython-input-176-45854e52fc1b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testing_dataframe['Permittivity_Imaginary'][testing_dataframe['Permittivity_Imaginary'] == 0.4] = 0.1

# %%
training_dataframe.head(5)
# Out:
#    Frequency  Orientation  Permittivity_Real  Permittivity_Imaginary  \
# 0     1.0000            0           0.022609                0.045054
# 1     1.0007            0           0.022609                0.045054
# 2     1.0014            0           0.022609                0.045054
# 3     1.0021            0           0.022609                0.045054
# 4     1.0028            0           0.022609                0.045054
#
#    S11_Real  S11_Imaginary  S12_Real  S12_Imaginary  S21_Real  S21_Imaginary  \
# 0  0.010708      -0.001546  0.218818       0.964274  0.218818       0.964274
# 1  0.010755      -0.001773  0.237425       0.960461  0.237425       0.960461
# 2  0.010795      -0.002004  0.255947       0.956298  0.255947       0.956298
# 3  0.010828      -0.002238  0.274378       0.951784  0.274378       0.951784
# 4  0.010853      -0.002474  0.292710       0.946918  0.292710       0.946918
#
#    S22_Real  S22_Imaginary
# 0  0.010327      -0.003227
# 1  0.010343      -0.003442
# 2  0.010353      -0.003656
# 3  0.010358      -0.003870
# 4  0.010356      -0.004082

# %%
testing_dataframe.head(5)
# Out:
#    Frequency  Orientation  Permittivity_Real  Permittivity_Imaginary  \
# 0     1.0000            0               0.05                     0.1
# 1     1.0007            0               0.05                     0.1
# 2     1.0014            0               0.05                     0.1
# 3     1.0021            0               0.05                     0.1
# 4     1.0028            0               0.05                     0.1
#
#    S11_Real  S11_Imaginary  S12_Real  S12_Imaginary  S21_Real  S21_Imaginary  \
# 0 -0.019713      -0.006039  0.999223      -0.020864  0.998418      -0.021599
# 1 -0.019483      -0.006385  0.998718      -0.020889  0.998630      -0.021391
# 2 -0.019138      -0.006591  0.998271      -0.020941  0.998445      -0.021038
# 3 -0.018813      -0.006997  0.998203      -0.020768  0.998248      -0.020766
# 4 -0.018616      -0.007612  0.998520      -0.020519  0.998265      -0.020615
#
#    S22_Real  S22_Imaginary
# 0  0.021095      -0.006780
# 1  0.020911      -0.007270
# 2  0.020691      -0.007730
# 3  0.020422      -0.008105
# 4  0.020164      -0.008383

# %%
training_dataframe.describe()
# Out:
#            Frequency    Orientation  Permittivity_Real  \
# count  400400.000000  400400.000000      400400.000000
# mean        1.350000       1.500000           0.051183
# std         0.202275       1.118035           0.022764
# min         1.000000       0.000000           0.010952
# 25%         1.175000       0.750000           0.030552
# 50%         1.350000       1.500000           0.053121
# 75%         1.525000       2.250000           0.070425
# max         1.700000       3.000000           0.087647
#
#        Permittivity_Imaginary       S11_Real  S11_Imaginary       S12_Real  \
# count           400400.000000  400400.000000  400400.000000  400400.000000
# mean                 0.048120      -0.001584      -0.002185      -0.047022
# std                  0.028907       0.015331       0.016359       0.717936
# min                  0.000463      -0.035654      -0.041414      -0.995684
# 25%                  0.023333      -0.012621      -0.013896      -0.764701
# 50%                  0.045073      -0.002871      -0.001957      -0.111570
# 75%                  0.077511       0.008562       0.009605       0.685784
# max                  0.099613       0.041451       0.040683       0.995090
#
#        S12_Imaginary       S21_Real  S21_Imaginary       S22_Real  \
# count  400400.000000  400400.000000  400400.000000  400400.000000
# mean       -0.054192      -0.047022      -0.054192       0.000979
# std         0.684740       0.717936       0.684740       0.016112
# min        -0.994878      -0.995684      -0.994878      -0.039840
# 25%        -0.733799      -0.764701      -0.733799      -0.010682
# 50%        -0.084830      -0.111570      -0.084830       0.001433
# 75%         0.613695       0.685784       0.613695       0.012647
# max         0.995193       0.995090       0.995193       0.040707
#
#        S22_Imaginary
# count  400400.000000
# mean       -0.001394
# std         0.015731
# min        -0.041402
# 25%        -0.012373
# 50%        -0.000090
# 75%         0.010078
# max         0.035653

# %%
testing_dataframe.describe()
# Out:
#        Frequency  Orientation  Permittivity_Real  Permittivity_Imaginary  \
# count  4004.0000  4004.000000       4.004000e+03            4.004000e+03
# mean      1.3500     1.500000       5.000000e-02            1.000000e-01
# std       0.2023     1.118174       6.939761e-18            1.387952e-17
# min       1.0000     0.000000       5.000000e-02            1.000000e-01
# 25%       1.1750     0.750000       5.000000e-02            1.000000e-01
# 50%       1.3500     1.500000       5.000000e-02            1.000000e-01
# 75%       1.5250     2.250000       5.000000e-02            1.000000e-01
# max       1.7000     3.000000       5.000000e-02            1.000000e-01
#
#           S11_Real  S11_Imaginary     S12_Real  S12_Imaginary     S21_Real  \
# count  4004.000000    4004.000000  4004.000000    4004.000000  4004.000000
# mean      0.000577       0.000549     0.999238      -0.015901     0.999127
# std       0.011171       0.011518     0.000563       0.002759     0.000539
# min      -0.020254      -0.019533     0.997404      -0.022488     0.997087
# 25%      -0.009929      -0.010517     0.998914      -0.017570     0.998798
# 50%       0.000705       0.001933     0.999316      -0.016833     0.999181
# 75%       0.010853       0.011191     0.999648      -0.015271     0.999511
# max       0.019258       0.017582     1.000619      -0.010323     1.000495
#
#        S21_Imaginary     S22_Real  S22_Imaginary
# count    4004.000000  4004.000000    4004.000000
# mean       -0.016045     0.000196       0.000537
# std         0.002727     0.011191       0.011311
# min        -0.022932    -0.016647      -0.019633
# 25%        -0.017717    -0.010537      -0.010187
# 50%        -0.016949    -0.000033       0.001886
# 75%        -0.015336     0.010635       0.010881
# max        -0.010558     0.021095       0.017354

# %%
plt.figure(figsize=(24, 8))
for i, column in enumerate(training_dataframe.columns):
    plt.subplot(2,6 , i+1)
    plt.hist(training_dataframe[column], bins=20, edgecolor='black')
    plt.title(column)
    plt.xlabel('Value')
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(24, 8))
for i, column in enumerate(testing_dataframe.columns):
    plt.subplot(2,6 , i+1)
    plt.hist(testing_dataframe[column], bins=20, edgecolor='black')
    plt.title(column)
    plt.xlabel('Value')
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
columns = training_dataframe.columns[3:]
training_mean_predicted_values = training_dataframe.groupby('Frequency')[columns].mean()
testing_mean_predicted_values = testing_dataframe.groupby('Frequency')[columns].mean()

# %%
q25 = np.percentile(training_dataframe["Permittivity_Real"], 25)
q50 = np.percentile(training_dataframe["Permittivity_Real"], 50)
q75 = np.percentile(training_dataframe["Permittivity_Real"], 75)
plt.hist(training_dataframe["Permittivity_Real"])
plt.xlabel("Permittivity Real Values")
plt.ylabel("Frequency")
plt.title("Training: Histogram of Permittivity Real Values")
plt.axvline(q25, color='red', linestyle='dashed', linewidth=2, label='25th Percentile (Q1)')
plt.axvline(q50, color='green', linestyle='dashed', linewidth=2, label='50th Percentile (Median)')
plt.axvline(q75, color='blue', linestyle='dashed', linewidth=2, label='75th Percentile (Q3)')
plt.legend()
plt.show()

# %%
plt.hist(testing_dataframe["Permittivity_Real"])
plt.xlabel("Permittivity Real Values")
plt.ylabel("Frequency")
plt.title("Testing: Histogram of Permittivity Real Values")
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(12, 6))
for col in training_mean_predicted_values.columns:
    plt.plot(training_mean_predicted_values.index, training_mean_predicted_values[col], label=col)
plt.xlabel('Frequency')
plt.ylabel('Mean Value')
plt.title('Training: Mean Values of Variables over Different Frequencies')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
for col in testing_mean_predicted_values.columns:
    plt.plot(testing_mean_predicted_values.index, testing_mean_predicted_values[col], label=col)
plt.xlabel('Frequency')
plt.ylabel('Mean Value')
plt.title('Testing: Mean Values of Variables over Different Frequencies')
plt.legend()
plt.show()

# %%
no_id = [
 'S11_Real',
 'S11_Imaginary',
 'S12_Real',
 'S12_Imaginary',
 'S21_Real',
 'S21_Imaginary',
 'S22_Real',
 'S22_Imaginary','Permittivity_Imaginary','Permittivity_Real']

# %%
from sklearn.preprocessing import PowerTransformer, QuantileTransformer
bc = QuantileTransformer()
bc.fit(training_dataframe[no_id])
training_dataframe[training_dataframe[no_id].columns] = bc.transform(training_dataframe[no_id])
testing_dataframe[testing_dataframe[no_id].columns]  = bc.transform(testing_dataframe[no_id])

# %%
plt.figure(figsize=(24, 8))
for i, column in enumerate(training_dataframe.columns):
    plt.subplot(2,6 , i+1)
    plt.hist(training_dataframe[column], bins=20, edgecolor='black')
    plt.title(column)
    plt.xlabel('Value')
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(24, 8))
for i, column in enumerate(testing_dataframe.columns):
    plt.subplot(2,6 , i+1)
    plt.hist(testing_dataframe[column], bins=20, edgecolor='black')
    plt.title(column)
    plt.xlabel('Value')
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Feedforward neural network

# %%
X_train = training_dataframe[columns].values
y_train = training_dataframe[['Permittivity_Real', 'Permittivity_Imaginary']].values
selected_indices = np.random.permutation(len(training_dataframe))
X_selected = X_train[selected_indices]
y_selected = y_train[selected_indices]
grouped_indices = {}
for idx in selected_indices:
    row = training_dataframe.iloc[idx]
    orientation = row['Orientation']
    frequency = row['Frequency']
    key = (orientation, frequency)
    if key not in grouped_indices:
        grouped_indices[key] = []
    grouped_indices[key].append(idx)
X_train_indices = []
X_val_indices = []
for key, indices in grouped_indices.items():
    train_indices, val_indices = train_test_split(indices, test_size=0.2, random_state=42)
    X_train_indices.extend(train_indices)
    X_val_indices.extend(val_indices)
X_train = X_selected[X_train_indices]
y_train = y_selected[X_train_indices]
X_val = X_selected[X_val_indices]
y_val = y_selected[X_val_indices]
X_test = testing_dataframe[columns].values
y_test = testing_dataframe[['Permittivity_Real', 'Permittivity_Imaginary']].values
X_train = X_train.astype(float)
y_train = y_train.astype(float)
X_val = X_val.astype(float)
y_val = y_val.astype(float)
X_test = X_test.astype(float)
y_test = y_test.astype(float)

# %%
selected_orientations = training_dataframe.loc[X_train_indices, 'Orientation']
selected_frequencies = training_dataframe.loc[X_train_indices, 'Frequency']
plt.figure(figsize=(15, 10))
plt.subplot(2, 2, 1)
plt.hist(selected_orientations, bins=10, color='blue', edgecolor='black')
plt.title('Training: Histogram of Selected Orientations')
plt.xlabel('Orientation')
plt.ylabel('Frequency')
plt.subplot(2, 2, 2)
plt.hist(selected_frequencies, bins=20, color='green', edgecolor='black')
plt.title('Training: Histogram of Selected Frequencies')
plt.xlabel('Frequency')
plt.ylabel('Frequency')
selected_orientations = training_dataframe.loc[X_val_indices, 'Orientation']
selected_frequencies = training_dataframe.loc[X_val_indices, 'Frequency']
plt.subplot(2, 2, 3)
plt.hist(selected_orientations, bins=10, color='blue', edgecolor='black')
plt.title('Testing: Histogram of Selected Orientations')
plt.xlabel('Orientation')
plt.ylabel('Frequency')
plt.subplot(2, 2, 4)
plt.hist(selected_frequencies, bins=20, color='green', edgecolor='black')
plt.title('Testing: Histogram of Selected Frequencies')
plt.xlabel('Frequency')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
def thresholded_rmse_loss(y_true, y_pred, threshold=2.0):
    y_true_real, y_true_imag = tf.split(y_true, 2, axis=-1)
    y_pred_real, y_pred_imag = tf.split(y_pred, 2, axis=-1)

    y_pred_real = tf.clip_by_value(y_pred_real, 0.0, threshold)
    y_pred_imag = tf.clip_by_value(y_pred_imag, 0.0, threshold)

    squared_error_real = tf.square(y_true_real - y_pred_real)
    squared_error_imag = tf.square(y_true_imag - y_pred_imag)

    mean_squared_error_loss_real = tf.reduce_mean(squared_error_real)
    mean_squared_error_loss_imag = tf.reduce_mean(squared_error_imag)

    root_mean_squared_error_loss_real = tf.sqrt(mean_squared_error_loss_real)
    root_mean_squared_error_loss_imag = tf.sqrt(mean_squared_error_loss_imag)

    return 0.5 * root_mean_squared_error_loss_real + 0.5 * root_mean_squared_error_loss_imag

model = keras.Sequential([
    keras.layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],),kernel_initializer='he_uniform', kernel_regularizer=tf.keras.regularizers.l2(0.00001)),
    keras.layers.Dense(64, activation='relu', kernel_initializer='he_uniform',kernel_regularizer=tf.keras.regularizers.l2(0.00001)),
    keras.layers.Dense(32, activation='relu', kernel_initializer='he_uniform',kernel_regularizer=tf.keras.regularizers.l2(0.00001)),
    keras.layers.Dense(16, activation='relu', kernel_initializer='he_uniform',kernel_regularizer=tf.keras.regularizers.l2(0.00001)),
    keras.layers.Dense(y_train.shape[1], activation='linear')
])


model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.0001,weight_decay=0.00001),
              loss=[thresholded_rmse_loss],
              metrics=[tf.metrics.MeanAbsoluteError(), tf.metrics.MeanSquaredError()])
model.summary()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=10000,shuffle=True)
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Mean Absolute Error')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error')
plt.legend(['Train', 'Validation'])
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])
plt.tight_layout()
plt.show()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_50 (Dense)            (None, 128)               1280
#
#  dense_51 (Dense)            (None, 64)                8256
#
#  dense_52 (Dense)            (None, 32)                2080
#
#  dense_53 (Dense)            (None, 16)                528
#
#  dense_54 (Dense)            (None, 2)                 34
#
# =================================================================
# Total params: 12,178
# Trainable params: 12,178
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 33/33 [==============================] - 3s 35ms/step - loss: 0.4955 - mean_absolute_error: 0.5303 - mean_squared_error: 0.4131 - val_loss: 0.4248 - val_mean_absolute_error: 0.4286 - val_mean_squared_error: 0.2854
# Epoch 2/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3791 - mean_absolute_error: 0.3487 - mean_squared_error: 0.1880 - val_loss: 0.3118 - val_mean_absolute_error: 0.2582 - val_mean_squared_error: 0.0962
# Epoch 3/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2661 - mean_absolute_error: 0.2143 - mean_squared_error: 0.0692 - val_loss: 0.2252 - val_mean_absolute_error: 0.1800 - val_mean_squared_error: 0.0490
# Epoch 4/100
# 33/33 [==============================] - 2s 56ms/step - loss: 0.1933 - mean_absolute_error: 0.1529 - mean_squared_error: 0.0377 - val_loss: 0.1606 - val_mean_absolute_error: 0.1265 - val_mean_squared_error: 0.0282
# Epoch 5/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1406 - mean_absolute_error: 0.1098 - mean_squared_error: 0.0236 - val_loss: 0.1260 - val_mean_absolute_error: 0.0973 - val_mean_squared_error: 0.0202
# Epoch 6/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1192 - mean_absolute_error: 0.0917 - mean_squared_error: 0.0184 - val_loss: 0.1130 - val_mean_absolute_error: 0.0870 - val_mean_squared_error: 0.0168
# Epoch 7/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1082 - mean_absolute_error: 0.0829 - mean_squared_error: 0.0156 - val_loss: 0.1037 - val_mean_absolute_error: 0.0795 - val_mean_squared_error: 0.0145
# Epoch 8/100
# 33/33 [==============================] - 1s 39ms/step - loss: 0.0999 - mean_absolute_error: 0.0760 - mean_squared_error: 0.0135 - val_loss: 0.0965 - val_mean_absolute_error: 0.0733 - val_mean_squared_error: 0.0127
# Epoch 9/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0934 - mean_absolute_error: 0.0703 - mean_squared_error: 0.0120 - val_loss: 0.0909 - val_mean_absolute_error: 0.0680 - val_mean_squared_error: 0.0115
# Epoch 10/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0884 - mean_absolute_error: 0.0659 - mean_squared_error: 0.0109 - val_loss: 0.0866 - val_mean_absolute_error: 0.0642 - val_mean_squared_error: 0.0105
# Epoch 11/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0847 - mean_absolute_error: 0.0627 - mean_squared_error: 0.0101 - val_loss: 0.0833 - val_mean_absolute_error: 0.0616 - val_mean_squared_error: 0.0098
# Epoch 12/100
# 33/33 [==============================] - 1s 6ms/step - loss: 0.0818 - mean_absolute_error: 0.0603 - mean_squared_error: 0.0095 - val_loss: 0.0807 - val_mean_absolute_error: 0.0591 - val_mean_squared_error: 0.0093
# Epoch 13/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0794 - mean_absolute_error: 0.0583 - mean_squared_error: 0.0091 - val_loss: 0.0785 - val_mean_absolute_error: 0.0577 - val_mean_squared_error: 0.0089
# Epoch 14/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0775 - mean_absolute_error: 0.0568 - mean_squared_error: 0.0087 - val_loss: 0.0769 - val_mean_absolute_error: 0.0566 - val_mean_squared_error: 0.0086
# Epoch 15/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0760 - mean_absolute_error: 0.0556 - mean_squared_error: 0.0085 - val_loss: 0.0756 - val_mean_absolute_error: 0.0554 - val_mean_squared_error: 0.0084
# Epoch 16/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0748 - mean_absolute_error: 0.0548 - mean_squared_error: 0.0083 - val_loss: 0.0746 - val_mean_absolute_error: 0.0546 - val_mean_squared_error: 0.0082
# Epoch 17/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0739 - mean_absolute_error: 0.0541 - mean_squared_error: 0.0081 - val_loss: 0.0736 - val_mean_absolute_error: 0.0541 - val_mean_squared_error: 0.0081
# Epoch 18/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0730 - mean_absolute_error: 0.0535 - mean_squared_error: 0.0080 - val_loss: 0.0729 - val_mean_absolute_error: 0.0535 - val_mean_squared_error: 0.0080
# Epoch 19/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0723 - mean_absolute_error: 0.0529 - mean_squared_error: 0.0079 - val_loss: 0.0721 - val_mean_absolute_error: 0.0529 - val_mean_squared_error: 0.0079
# Epoch 20/100
# 33/33 [==============================] - 1s 38ms/step - loss: 0.0716 - mean_absolute_error: 0.0524 - mean_squared_error: 0.0078 - val_loss: 0.0717 - val_mean_absolute_error: 0.0522 - val_mean_squared_error: 0.0079
# Epoch 21/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0711 - mean_absolute_error: 0.0519 - mean_squared_error: 0.0078 - val_loss: 0.0710 - val_mean_absolute_error: 0.0519 - val_mean_squared_error: 0.0077
# Epoch 22/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0706 - mean_absolute_error: 0.0515 - mean_squared_error: 0.0077 - val_loss: 0.0705 - val_mean_absolute_error: 0.0514 - val_mean_squared_error: 0.0076
# Epoch 23/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0701 - mean_absolute_error: 0.0511 - mean_squared_error: 0.0076 - val_loss: 0.0701 - val_mean_absolute_error: 0.0511 - val_mean_squared_error: 0.0076
# Epoch 24/100
# 33/33 [==============================] - 1s 21ms/step - loss: 0.0697 - mean_absolute_error: 0.0507 - mean_squared_error: 0.0075 - val_loss: 0.0696 - val_mean_absolute_error: 0.0505 - val_mean_squared_error: 0.0075
# Epoch 25/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0693 - mean_absolute_error: 0.0503 - mean_squared_error: 0.0075 - val_loss: 0.0692 - val_mean_absolute_error: 0.0503 - val_mean_squared_error: 0.0075
# Epoch 26/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0689 - mean_absolute_error: 0.0499 - mean_squared_error: 0.0074 - val_loss: 0.0689 - val_mean_absolute_error: 0.0498 - val_mean_squared_error: 0.0074
# Epoch 27/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0686 - mean_absolute_error: 0.0497 - mean_squared_error: 0.0074 - val_loss: 0.0686 - val_mean_absolute_error: 0.0496 - val_mean_squared_error: 0.0074
# Epoch 28/100
# 33/33 [==============================] - 1s 39ms/step - loss: 0.0683 - mean_absolute_error: 0.0493 - mean_squared_error: 0.0073 - val_loss: 0.0683 - val_mean_absolute_error: 0.0494 - val_mean_squared_error: 0.0073
# Epoch 29/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0680 - mean_absolute_error: 0.0491 - mean_squared_error: 0.0073 - val_loss: 0.0681 - val_mean_absolute_error: 0.0490 - val_mean_squared_error: 0.0073
# Epoch 30/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0678 - mean_absolute_error: 0.0488 - mean_squared_error: 0.0073 - val_loss: 0.0677 - val_mean_absolute_error: 0.0486 - val_mean_squared_error: 0.0073
# Epoch 31/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0675 - mean_absolute_error: 0.0486 - mean_squared_error: 0.0072 - val_loss: 0.0675 - val_mean_absolute_error: 0.0485 - val_mean_squared_error: 0.0072
# Epoch 32/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0672 - mean_absolute_error: 0.0483 - mean_squared_error: 0.0072 - val_loss: 0.0673 - val_mean_absolute_error: 0.0484 - val_mean_squared_error: 0.0072
# Epoch 33/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0670 - mean_absolute_error: 0.0481 - mean_squared_error: 0.0071 - val_loss: 0.0671 - val_mean_absolute_error: 0.0481 - val_mean_squared_error: 0.0071
# Epoch 34/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0668 - mean_absolute_error: 0.0479 - mean_squared_error: 0.0071 - val_loss: 0.0669 - val_mean_absolute_error: 0.0481 - val_mean_squared_error: 0.0071
# Epoch 35/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0666 - mean_absolute_error: 0.0477 - mean_squared_error: 0.0071 - val_loss: 0.0669 - val_mean_absolute_error: 0.0479 - val_mean_squared_error: 0.0071
# Epoch 36/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0665 - mean_absolute_error: 0.0476 - mean_squared_error: 0.0071 - val_loss: 0.0666 - val_mean_absolute_error: 0.0477 - val_mean_squared_error: 0.0071
# Epoch 37/100
# 33/33 [==============================] - 1s 38ms/step - loss: 0.0663 - mean_absolute_error: 0.0474 - mean_squared_error: 0.0070 - val_loss: 0.0663 - val_mean_absolute_error: 0.0474 - val_mean_squared_error: 0.0070
# Epoch 38/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0660 - mean_absolute_error: 0.0471 - mean_squared_error: 0.0070 - val_loss: 0.0661 - val_mean_absolute_error: 0.0473 - val_mean_squared_error: 0.0070
# Epoch 39/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0659 - mean_absolute_error: 0.0469 - mean_squared_error: 0.0070 - val_loss: 0.0663 - val_mean_absolute_error: 0.0470 - val_mean_squared_error: 0.0071
# Epoch 40/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0658 - mean_absolute_error: 0.0468 - mean_squared_error: 0.0070 - val_loss: 0.0657 - val_mean_absolute_error: 0.0468 - val_mean_squared_error: 0.0069
# Epoch 41/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0655 - mean_absolute_error: 0.0466 - mean_squared_error: 0.0069 - val_loss: 0.0657 - val_mean_absolute_error: 0.0467 - val_mean_squared_error: 0.0069
# Epoch 42/100
# 33/33 [==============================] - 1s 38ms/step - loss: 0.0654 - mean_absolute_error: 0.0464 - mean_squared_error: 0.0069 - val_loss: 0.0655 - val_mean_absolute_error: 0.0465 - val_mean_squared_error: 0.0069
# Epoch 43/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0652 - mean_absolute_error: 0.0462 - mean_squared_error: 0.0069 - val_loss: 0.0654 - val_mean_absolute_error: 0.0463 - val_mean_squared_error: 0.0069
# Epoch 44/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0651 - mean_absolute_error: 0.0461 - mean_squared_error: 0.0068 - val_loss: 0.0652 - val_mean_absolute_error: 0.0462 - val_mean_squared_error: 0.0068
# Epoch 45/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0650 - mean_absolute_error: 0.0459 - mean_squared_error: 0.0068 - val_loss: 0.0650 - val_mean_absolute_error: 0.0460 - val_mean_squared_error: 0.0068
# Epoch 46/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0648 - mean_absolute_error: 0.0457 - mean_squared_error: 0.0068 - val_loss: 0.0649 - val_mean_absolute_error: 0.0457 - val_mean_squared_error: 0.0068
# Epoch 47/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0647 - mean_absolute_error: 0.0456 - mean_squared_error: 0.0068 - val_loss: 0.0648 - val_mean_absolute_error: 0.0455 - val_mean_squared_error: 0.0068
# Epoch 48/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0646 - mean_absolute_error: 0.0454 - mean_squared_error: 0.0067 - val_loss: 0.0647 - val_mean_absolute_error: 0.0454 - val_mean_squared_error: 0.0067
# Epoch 49/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0645 - mean_absolute_error: 0.0453 - mean_squared_error: 0.0067 - val_loss: 0.0646 - val_mean_absolute_error: 0.0454 - val_mean_squared_error: 0.0067
# Epoch 50/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0643 - mean_absolute_error: 0.0452 - mean_squared_error: 0.0067 - val_loss: 0.0644 - val_mean_absolute_error: 0.0453 - val_mean_squared_error: 0.0067
# Epoch 51/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0642 - mean_absolute_error: 0.0450 - mean_squared_error: 0.0067 - val_loss: 0.0643 - val_mean_absolute_error: 0.0450 - val_mean_squared_error: 0.0067
# Epoch 52/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0641 - mean_absolute_error: 0.0449 - mean_squared_error: 0.0067 - val_loss: 0.0643 - val_mean_absolute_error: 0.0451 - val_mean_squared_error: 0.0067
# Epoch 53/100
# 33/33 [==============================] - 1s 22ms/step - loss: 0.0640 - mean_absolute_error: 0.0448 - mean_squared_error: 0.0066 - val_loss: 0.0644 - val_mean_absolute_error: 0.0455 - val_mean_squared_error: 0.0067
# Epoch 54/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0639 - mean_absolute_error: 0.0447 - mean_squared_error: 0.0066 - val_loss: 0.0640 - val_mean_absolute_error: 0.0446 - val_mean_squared_error: 0.0066
# Epoch 55/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0638 - mean_absolute_error: 0.0446 - mean_squared_error: 0.0066 - val_loss: 0.0641 - val_mean_absolute_error: 0.0446 - val_mean_squared_error: 0.0067
# Epoch 56/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0637 - mean_absolute_error: 0.0444 - mean_squared_error: 0.0066 - val_loss: 0.0638 - val_mean_absolute_error: 0.0445 - val_mean_squared_error: 0.0066
# Epoch 57/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0635 - mean_absolute_error: 0.0443 - mean_squared_error: 0.0066 - val_loss: 0.0637 - val_mean_absolute_error: 0.0446 - val_mean_squared_error: 0.0066
# Epoch 58/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0635 - mean_absolute_error: 0.0443 - mean_squared_error: 0.0065 - val_loss: 0.0639 - val_mean_absolute_error: 0.0445 - val_mean_squared_error: 0.0066
# Epoch 59/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0634 - mean_absolute_error: 0.0442 - mean_squared_error: 0.0065 - val_loss: 0.0636 - val_mean_absolute_error: 0.0446 - val_mean_squared_error: 0.0066
# Epoch 60/100
# 33/33 [==============================] - 1s 24ms/step - loss: 0.0632 - mean_absolute_error: 0.0441 - mean_squared_error: 0.0065 - val_loss: 0.0634 - val_mean_absolute_error: 0.0440 - val_mean_squared_error: 0.0065
# Epoch 61/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0631 - mean_absolute_error: 0.0439 - mean_squared_error: 0.0065 - val_loss: 0.0635 - val_mean_absolute_error: 0.0443 - val_mean_squared_error: 0.0065
# Epoch 62/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0631 - mean_absolute_error: 0.0439 - mean_squared_error: 0.0065 - val_loss: 0.0632 - val_mean_absolute_error: 0.0438 - val_mean_squared_error: 0.0065
# Epoch 63/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0630 - mean_absolute_error: 0.0437 - mean_squared_error: 0.0065 - val_loss: 0.0631 - val_mean_absolute_error: 0.0436 - val_mean_squared_error: 0.0065
# Epoch 64/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0629 - mean_absolute_error: 0.0436 - mean_squared_error: 0.0064 - val_loss: 0.0633 - val_mean_absolute_error: 0.0439 - val_mean_squared_error: 0.0065
# Epoch 65/100
# 33/33 [==============================] - 1s 38ms/step - loss: 0.0628 - mean_absolute_error: 0.0436 - mean_squared_error: 0.0064 - val_loss: 0.0630 - val_mean_absolute_error: 0.0439 - val_mean_squared_error: 0.0065
# Epoch 66/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0627 - mean_absolute_error: 0.0435 - mean_squared_error: 0.0064 - val_loss: 0.0629 - val_mean_absolute_error: 0.0437 - val_mean_squared_error: 0.0064
# Epoch 67/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0626 - mean_absolute_error: 0.0434 - mean_squared_error: 0.0064 - val_loss: 0.0627 - val_mean_absolute_error: 0.0435 - val_mean_squared_error: 0.0064
# Epoch 68/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0625 - mean_absolute_error: 0.0433 - mean_squared_error: 0.0064 - val_loss: 0.0627 - val_mean_absolute_error: 0.0433 - val_mean_squared_error: 0.0064
# Epoch 69/100
# 33/33 [==============================] - 1s 38ms/step - loss: 0.0625 - mean_absolute_error: 0.0432 - mean_squared_error: 0.0064 - val_loss: 0.0626 - val_mean_absolute_error: 0.0434 - val_mean_squared_error: 0.0064
# Epoch 70/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0624 - mean_absolute_error: 0.0432 - mean_squared_error: 0.0064 - val_loss: 0.0628 - val_mean_absolute_error: 0.0433 - val_mean_squared_error: 0.0064
# Epoch 71/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0623 - mean_absolute_error: 0.0431 - mean_squared_error: 0.0063 - val_loss: 0.0630 - val_mean_absolute_error: 0.0434 - val_mean_squared_error: 0.0064
# Epoch 72/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0623 - mean_absolute_error: 0.0431 - mean_squared_error: 0.0063 - val_loss: 0.0625 - val_mean_absolute_error: 0.0430 - val_mean_squared_error: 0.0064
# Epoch 73/100
# 33/33 [==============================] - 1s 38ms/step - loss: 0.0622 - mean_absolute_error: 0.0429 - mean_squared_error: 0.0063 - val_loss: 0.0623 - val_mean_absolute_error: 0.0429 - val_mean_squared_error: 0.0063
# Epoch 74/100
# 33/33 [==============================] - 1s 39ms/step - loss: 0.0621 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0063 - val_loss: 0.0623 - val_mean_absolute_error: 0.0428 - val_mean_squared_error: 0.0063
# Epoch 75/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0620 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0063 - val_loss: 0.0622 - val_mean_absolute_error: 0.0429 - val_mean_squared_error: 0.0063
# Epoch 76/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0620 - mean_absolute_error: 0.0427 - mean_squared_error: 0.0063 - val_loss: 0.0625 - val_mean_absolute_error: 0.0436 - val_mean_squared_error: 0.0064
# Epoch 77/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0620 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0063 - val_loss: 0.0620 - val_mean_absolute_error: 0.0428 - val_mean_squared_error: 0.0063
# Epoch 78/100
# 33/33 [==============================] - 1s 43ms/step - loss: 0.0618 - mean_absolute_error: 0.0425 - mean_squared_error: 0.0063 - val_loss: 0.0620 - val_mean_absolute_error: 0.0428 - val_mean_squared_error: 0.0063
# Epoch 79/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0618 - mean_absolute_error: 0.0425 - mean_squared_error: 0.0062 - val_loss: 0.0619 - val_mean_absolute_error: 0.0427 - val_mean_squared_error: 0.0063
# Epoch 80/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0617 - mean_absolute_error: 0.0425 - mean_squared_error: 0.0062 - val_loss: 0.0620 - val_mean_absolute_error: 0.0426 - val_mean_squared_error: 0.0063
# Epoch 81/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0617 - mean_absolute_error: 0.0424 - mean_squared_error: 0.0062 - val_loss: 0.0618 - val_mean_absolute_error: 0.0425 - val_mean_squared_error: 0.0062
# Epoch 82/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0616 - mean_absolute_error: 0.0423 - mean_squared_error: 0.0062 - val_loss: 0.0618 - val_mean_absolute_error: 0.0425 - val_mean_squared_error: 0.0062
# Epoch 83/100
# 33/33 [==============================] - 1s 38ms/step - loss: 0.0615 - mean_absolute_error: 0.0422 - mean_squared_error: 0.0062 - val_loss: 0.0618 - val_mean_absolute_error: 0.0423 - val_mean_squared_error: 0.0063
# Epoch 84/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0615 - mean_absolute_error: 0.0422 - mean_squared_error: 0.0062 - val_loss: 0.0617 - val_mean_absolute_error: 0.0422 - val_mean_squared_error: 0.0062
# Epoch 85/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0614 - mean_absolute_error: 0.0421 - mean_squared_error: 0.0062 - val_loss: 0.0617 - val_mean_absolute_error: 0.0424 - val_mean_squared_error: 0.0062
# Epoch 86/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0614 - mean_absolute_error: 0.0421 - mean_squared_error: 0.0062 - val_loss: 0.0616 - val_mean_absolute_error: 0.0424 - val_mean_squared_error: 0.0062
# Epoch 87/100
# 33/33 [==============================] - 1s 6ms/step - loss: 0.0613 - mean_absolute_error: 0.0420 - mean_squared_error: 0.0062 - val_loss: 0.0615 - val_mean_absolute_error: 0.0421 - val_mean_squared_error: 0.0062
# Epoch 88/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0612 - mean_absolute_error: 0.0419 - mean_squared_error: 0.0062 - val_loss: 0.0615 - val_mean_absolute_error: 0.0425 - val_mean_squared_error: 0.0062
# Epoch 89/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0612 - mean_absolute_error: 0.0420 - mean_squared_error: 0.0062 - val_loss: 0.0615 - val_mean_absolute_error: 0.0424 - val_mean_squared_error: 0.0062
# Epoch 90/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0612 - mean_absolute_error: 0.0419 - mean_squared_error: 0.0061 - val_loss: 0.0616 - val_mean_absolute_error: 0.0421 - val_mean_squared_error: 0.0062
# Epoch 91/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0611 - mean_absolute_error: 0.0418 - mean_squared_error: 0.0061 - val_loss: 0.0614 - val_mean_absolute_error: 0.0421 - val_mean_squared_error: 0.0062
# Epoch 92/100
# 33/33 [==============================] - 1s 38ms/step - loss: 0.0611 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0061 - val_loss: 0.0613 - val_mean_absolute_error: 0.0418 - val_mean_squared_error: 0.0062
# Epoch 93/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0610 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0061 - val_loss: 0.0611 - val_mean_absolute_error: 0.0418 - val_mean_squared_error: 0.0061
# Epoch 94/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0610 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0061 - val_loss: 0.0613 - val_mean_absolute_error: 0.0417 - val_mean_squared_error: 0.0062
# Epoch 95/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0609 - mean_absolute_error: 0.0416 - mean_squared_error: 0.0061 - val_loss: 0.0613 - val_mean_absolute_error: 0.0419 - val_mean_squared_error: 0.0061
# Epoch 96/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0609 - mean_absolute_error: 0.0416 - mean_squared_error: 0.0061 - val_loss: 0.0611 - val_mean_absolute_error: 0.0416 - val_mean_squared_error: 0.0061
# Epoch 97/100
# 33/33 [==============================] - 1s 38ms/step - loss: 0.0608 - mean_absolute_error: 0.0415 - mean_squared_error: 0.0061 - val_loss: 0.0610 - val_mean_absolute_error: 0.0416 - val_mean_squared_error: 0.0061
# Epoch 98/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0608 - mean_absolute_error: 0.0415 - mean_squared_error: 0.0061 - val_loss: 0.0610 - val_mean_absolute_error: 0.0416 - val_mean_squared_error: 0.0061
# Epoch 99/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0608 - mean_absolute_error: 0.0415 - mean_squared_error: 0.0061 - val_loss: 0.0609 - val_mean_absolute_error: 0.0416 - val_mean_squared_error: 0.0061
# Epoch 100/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0607 - mean_absolute_error: 0.0414 - mean_squared_error: 0.0060 - val_loss: 0.0610 - val_mean_absolute_error: 0.0417 - val_mean_squared_error: 0.0061

# %%
y_pred = model.predict(X_test)
def remove_outliers(y_pred, y_test, threshold=2):
    z_scores = np.abs((y_pred - np.mean(y_pred)) / np.std(y_pred))
    outliers_mask = z_scores > 2.0

    y_pred_filtered = y_pred[~outliers_mask]
    y_test_filtered = y_test[~outliers_mask]

    return y_pred_filtered, y_test_filtered

# Assuming you have y_pred, y_test, and X_test available
y_pred_0, y_test_filtered_0 = remove_outliers(y_pred[:, 0], y_test[:, 0], threshold=2.0)
y_pred_1, y_test_filtered_1 = remove_outliers(y_pred[:, 1], y_test[:, 1], threshold=2.0)
# Out:
# 126/126 [==============================] - 0s 1ms/step

# %%
plt.figure(figsize=(16, 4))
plt.subplot(1, 2, 1)
plt.plot([0, len(y_test_filtered_0) - 1], [np.mean(y_pred_0), np.mean(y_pred_0)], label='Predicted Mean', color='red', linestyle='dashed')
plt.scatter(range(len(y_test_filtered_0)),y_test_filtered_0, label='Actual', color='blue', alpha=0.5)
plt.scatter(range(len(y_test_filtered_0)), y_pred_0, label='Predicted', color='orange', alpha=0.5)
plt.title('Comparison of Actual and Predicted Permittivity Real Values')
plt.xlabel('Data Point')
plt.ylabel('Value')
plt.legend()

# %%
plt.figure(figsize=(16, 4))
plt.subplot(1, 2, 1)
plt.plot([0, len(y_test_filtered_1) - 1], [np.mean(y_pred_1), np.mean(y_pred_1)], label='Predicted Mean', color='red', linestyle='dashed')
plt.scatter(range(len(y_test_filtered_1)), y_test_filtered_1, label='Actual', color='blue', alpha=0.5)
plt.scatter(range(len(y_test_filtered_1)), y_pred_1, label='Predicted', color='orange', alpha=0.5)
plt.title('Comparison of Actual and Predicted Permittivity Imaginary Values')
plt.xlabel('Data Point')
plt.ylabel('Value')
plt.legend()

# %%
X_train = training_dataframe[columns].values
y_train = training_dataframe[['Permittivity_Real', 'Permittivity_Imaginary']].values
X_test = testing_dataframe[columns].values
y_test = testing_dataframe[['Permittivity_Real', 'Permittivity_Imaginary']].values
X_train = X_train.astype(float)
y_train = y_train.astype(float)
X_test = X_test.astype(float)
y_test = y_test.astype(float)

# %%
def thresholded_rmse_loss(y_true, y_pred, threshold=2.0):
    y_true_real, y_true_imag = tf.split(y_true, 2, axis=-1)
    y_pred_real, y_pred_imag = tf.split(y_pred, 2, axis=-1)

    y_pred_real = tf.clip_by_value(y_pred_real, 0.0, threshold)
    y_pred_imag = tf.clip_by_value(y_pred_imag, 0.0, threshold)

    squared_error_real = tf.square(y_true_real - y_pred_real)
    squared_error_imag = tf.square(y_true_imag - y_pred_imag)

    mean_squared_error_loss_real = tf.reduce_mean(squared_error_real)
    mean_squared_error_loss_imag = tf.reduce_mean(squared_error_imag)

    root_mean_squared_error_loss_real = tf.sqrt(mean_squared_error_loss_real)
    root_mean_squared_error_loss_imag = tf.sqrt(mean_squared_error_loss_imag)

    return 0.5 * root_mean_squared_error_loss_real + 0.5 * root_mean_squared_error_loss_imag

model = keras.Sequential([
    keras.layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],),kernel_initializer='he_uniform', kernel_regularizer=tf.keras.regularizers.l2(0.00001)),
    keras.layers.Dense(64, activation='relu', kernel_initializer='he_uniform',kernel_regularizer=tf.keras.regularizers.l2(0.00001)),
    keras.layers.Dense(32, activation='relu', kernel_initializer='he_uniform',kernel_regularizer=tf.keras.regularizers.l2(0.00001)),
    keras.layers.Dense(16, activation='relu', kernel_initializer='he_uniform',kernel_regularizer=tf.keras.regularizers.l2(0.00001)),
    keras.layers.Dense(y_train.shape[1], activation='linear')
])


model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.0001,weight_decay=0.00001),
              loss=[thresholded_rmse_loss],
              metrics=[tf.metrics.MeanAbsoluteError(), tf.metrics.MeanSquaredError()])
model.summary()
history = model.fit(X_train, y_train, epochs=100, batch_size=5000,shuffle=True)
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['mean_absolute_error'])
plt.title('Mean Absolute Error')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error')
plt.legend(['Train'])
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train'])
plt.tight_layout()
plt.show()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 128)               1280
#
#  dense_16 (Dense)            (None, 64)                8256
#
#  dense_17 (Dense)            (None, 32)                2080
#
#  dense_18 (Dense)            (None, 16)                528
#
#  dense_19 (Dense)            (None, 2)                 34
#
# =================================================================
# Total params: 12,178
# Trainable params: 12,178
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 81/81 [==============================] - 4s 29ms/step - loss: 0.4277 - mean_absolute_error: 0.6524 - mean_squared_error: 0.7242
# Epoch 2/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3813 - mean_absolute_error: 0.5352 - mean_squared_error: 0.5280
# Epoch 3/100
# 81/81 [==============================] - 3s 38ms/step - loss: 0.2010 - mean_absolute_error: 0.1730 - mean_squared_error: 0.0673
# Epoch 4/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.1023 - mean_absolute_error: 0.0776 - mean_squared_error: 0.0120
# Epoch 5/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0864 - mean_absolute_error: 0.0638 - mean_squared_error: 0.0096
# Epoch 6/100
# 81/81 [==============================] - 1s 17ms/step - loss: 0.0801 - mean_absolute_error: 0.0586 - mean_squared_error: 0.0088
# Epoch 7/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0764 - mean_absolute_error: 0.0555 - mean_squared_error: 0.0083
# Epoch 8/100
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0739 - mean_absolute_error: 0.0534 - mean_squared_error: 0.0079
# Epoch 9/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0723 - mean_absolute_error: 0.0522 - mean_squared_error: 0.0077
# Epoch 10/100
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0710 - mean_absolute_error: 0.0512 - mean_squared_error: 0.0075
# Epoch 11/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0700 - mean_absolute_error: 0.0504 - mean_squared_error: 0.0074
# Epoch 12/100
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0692 - mean_absolute_error: 0.0498 - mean_squared_error: 0.0073
# Epoch 13/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0685 - mean_absolute_error: 0.0493 - mean_squared_error: 0.0072
# Epoch 14/100
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0679 - mean_absolute_error: 0.0489 - mean_squared_error: 0.0072
# Epoch 15/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0674 - mean_absolute_error: 0.0486 - mean_squared_error: 0.0071
# Epoch 16/100
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0670 - mean_absolute_error: 0.0482 - mean_squared_error: 0.0070
# Epoch 17/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0665 - mean_absolute_error: 0.0478 - mean_squared_error: 0.0070
# Epoch 18/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0661 - mean_absolute_error: 0.0475 - mean_squared_error: 0.0069
# Epoch 19/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0658 - mean_absolute_error: 0.0473 - mean_squared_error: 0.0069
# Epoch 20/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0655 - mean_absolute_error: 0.0470 - mean_squared_error: 0.0069
# Epoch 21/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0652 - mean_absolute_error: 0.0468 - mean_squared_error: 0.0068
# Epoch 22/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0649 - mean_absolute_error: 0.0465 - mean_squared_error: 0.0068
# Epoch 23/100
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0646 - mean_absolute_error: 0.0463 - mean_squared_error: 0.0068
# Epoch 24/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0643 - mean_absolute_error: 0.0460 - mean_squared_error: 0.0067
# Epoch 25/100
# 81/81 [==============================] - 1s 17ms/step - loss: 0.0642 - mean_absolute_error: 0.0459 - mean_squared_error: 0.0067
# Epoch 26/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0639 - mean_absolute_error: 0.0457 - mean_squared_error: 0.0067
# Epoch 27/100
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0637 - mean_absolute_error: 0.0455 - mean_squared_error: 0.0067
# Epoch 28/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0636 - mean_absolute_error: 0.0454 - mean_squared_error: 0.0067
# Epoch 29/100
# 81/81 [==============================] - 1s 19ms/step - loss: 0.0634 - mean_absolute_error: 0.0452 - mean_squared_error: 0.0067
# Epoch 30/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0632 - mean_absolute_error: 0.0451 - mean_squared_error: 0.0066
# Epoch 31/100
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0630 - mean_absolute_error: 0.0449 - mean_squared_error: 0.0066
# Epoch 32/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0629 - mean_absolute_error: 0.0447 - mean_squared_error: 0.0066
# Epoch 33/100
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0628 - mean_absolute_error: 0.0446 - mean_squared_error: 0.0066
# Epoch 34/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0626 - mean_absolute_error: 0.0444 - mean_squared_error: 0.0066
# Epoch 35/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0625 - mean_absolute_error: 0.0443 - mean_squared_error: 0.0066
# Epoch 36/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0624 - mean_absolute_error: 0.0442 - mean_squared_error: 0.0065
# Epoch 37/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0623 - mean_absolute_error: 0.0441 - mean_squared_error: 0.0065
# Epoch 38/100
# 81/81 [==============================] - 1s 4ms/step - loss: 0.0622 - mean_absolute_error: 0.0440 - mean_squared_error: 0.0065
# Epoch 39/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0621 - mean_absolute_error: 0.0439 - mean_squared_error: 0.0065
# Epoch 40/100
# 81/81 [==============================] - 1s 17ms/step - loss: 0.0619 - mean_absolute_error: 0.0437 - mean_squared_error: 0.0065
# Epoch 41/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0618 - mean_absolute_error: 0.0436 - mean_squared_error: 0.0064
# Epoch 42/100
# 81/81 [==============================] - 1s 17ms/step - loss: 0.0617 - mean_absolute_error: 0.0435 - mean_squared_error: 0.0064
# Epoch 43/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0616 - mean_absolute_error: 0.0433 - mean_squared_error: 0.0064
# Epoch 44/100
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0615 - mean_absolute_error: 0.0431 - mean_squared_error: 0.0064
# Epoch 45/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0614 - mean_absolute_error: 0.0430 - mean_squared_error: 0.0064
# Epoch 46/100
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0613 - mean_absolute_error: 0.0429 - mean_squared_error: 0.0063
# Epoch 47/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0612 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0063
# Epoch 48/100
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0611 - mean_absolute_error: 0.0426 - mean_squared_error: 0.0063
# Epoch 49/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0610 - mean_absolute_error: 0.0425 - mean_squared_error: 0.0063
# Epoch 50/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0609 - mean_absolute_error: 0.0425 - mean_squared_error: 0.0063
# Epoch 51/100
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0608 - mean_absolute_error: 0.0423 - mean_squared_error: 0.0063
# Epoch 52/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0608 - mean_absolute_error: 0.0423 - mean_squared_error: 0.0062
# Epoch 53/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0607 - mean_absolute_error: 0.0422 - mean_squared_error: 0.0062
# Epoch 54/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0606 - mean_absolute_error: 0.0421 - mean_squared_error: 0.0062
# Epoch 55/100
# 81/81 [==============================] - 1s 17ms/step - loss: 0.0606 - mean_absolute_error: 0.0420 - mean_squared_error: 0.0062
# Epoch 56/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0604 - mean_absolute_error: 0.0419 - mean_squared_error: 0.0062
# Epoch 57/100
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0603 - mean_absolute_error: 0.0418 - mean_squared_error: 0.0062
# Epoch 58/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0603 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0062
# Epoch 59/100
# 81/81 [==============================] - 1s 17ms/step - loss: 0.0602 - mean_absolute_error: 0.0416 - mean_squared_error: 0.0061
# Epoch 60/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0601 - mean_absolute_error: 0.0416 - mean_squared_error: 0.0061
# Epoch 61/100
# 81/81 [==============================] - 1s 17ms/step - loss: 0.0601 - mean_absolute_error: 0.0415 - mean_squared_error: 0.0061
# Epoch 62/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0600 - mean_absolute_error: 0.0414 - mean_squared_error: 0.0061
# Epoch 63/100
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0599 - mean_absolute_error: 0.0413 - mean_squared_error: 0.0061
# Epoch 64/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0598 - mean_absolute_error: 0.0412 - mean_squared_error: 0.0061
# Epoch 65/100
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0597 - mean_absolute_error: 0.0411 - mean_squared_error: 0.0060
# Epoch 66/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0597 - mean_absolute_error: 0.0410 - mean_squared_error: 0.0060
# Epoch 67/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0595 - mean_absolute_error: 0.0409 - mean_squared_error: 0.0060
# Epoch 68/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0595 - mean_absolute_error: 0.0409 - mean_squared_error: 0.0060
# Epoch 69/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0593 - mean_absolute_error: 0.0407 - mean_squared_error: 0.0060
# Epoch 70/100
# 81/81 [==============================] - 1s 17ms/step - loss: 0.0592 - mean_absolute_error: 0.0407 - mean_squared_error: 0.0059
# Epoch 71/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0591 - mean_absolute_error: 0.0406 - mean_squared_error: 0.0059
# Epoch 72/100
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0590 - mean_absolute_error: 0.0405 - mean_squared_error: 0.0059
# Epoch 73/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0589 - mean_absolute_error: 0.0404 - mean_squared_error: 0.0059
# Epoch 74/100
# 81/81 [==============================] - 1s 17ms/step - loss: 0.0588 - mean_absolute_error: 0.0403 - mean_squared_error: 0.0059
# Epoch 75/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0587 - mean_absolute_error: 0.0402 - mean_squared_error: 0.0058
# Epoch 76/100
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0586 - mean_absolute_error: 0.0402 - mean_squared_error: 0.0058
# Epoch 77/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0585 - mean_absolute_error: 0.0401 - mean_squared_error: 0.0058
# Epoch 78/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0584 - mean_absolute_error: 0.0400 - mean_squared_error: 0.0058
# Epoch 79/100
# 81/81 [==============================] - 1s 17ms/step - loss: 0.0583 - mean_absolute_error: 0.0399 - mean_squared_error: 0.0058
# Epoch 80/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0582 - mean_absolute_error: 0.0398 - mean_squared_error: 0.0057
# Epoch 81/100
# 81/81 [==============================] - 2s 30ms/step - loss: 0.0581 - mean_absolute_error: 0.0397 - mean_squared_error: 0.0057
# Epoch 82/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0581 - mean_absolute_error: 0.0397 - mean_squared_error: 0.0057
# Epoch 83/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0580 - mean_absolute_error: 0.0396 - mean_squared_error: 0.0057
# Epoch 84/100
# 81/81 [==============================] - 1s 17ms/step - loss: 0.0579 - mean_absolute_error: 0.0396 - mean_squared_error: 0.0057
# Epoch 85/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0578 - mean_absolute_error: 0.0395 - mean_squared_error: 0.0057
# Epoch 86/100
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0577 - mean_absolute_error: 0.0394 - mean_squared_error: 0.0056
# Epoch 87/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0576 - mean_absolute_error: 0.0393 - mean_squared_error: 0.0056
# Epoch 88/100
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0576 - mean_absolute_error: 0.0393 - mean_squared_error: 0.0056
# Epoch 89/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0575 - mean_absolute_error: 0.0392 - mean_squared_error: 0.0056
# Epoch 90/100
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0574 - mean_absolute_error: 0.0391 - mean_squared_error: 0.0056
# Epoch 91/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0573 - mean_absolute_error: 0.0391 - mean_squared_error: 0.0056
# Epoch 92/100
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0573 - mean_absolute_error: 0.0390 - mean_squared_error: 0.0056
# Epoch 93/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0572 - mean_absolute_error: 0.0389 - mean_squared_error: 0.0055
# Epoch 94/100
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0571 - mean_absolute_error: 0.0388 - mean_squared_error: 0.0055
# Epoch 95/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0571 - mean_absolute_error: 0.0388 - mean_squared_error: 0.0055
# Epoch 96/100
# 81/81 [==============================] - 1s 17ms/step - loss: 0.0570 - mean_absolute_error: 0.0387 - mean_squared_error: 0.0055
# Epoch 97/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0569 - mean_absolute_error: 0.0387 - mean_squared_error: 0.0055
# Epoch 98/100
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0569 - mean_absolute_error: 0.0386 - mean_squared_error: 0.0055
# Epoch 99/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0568 - mean_absolute_error: 0.0385 - mean_squared_error: 0.0055
# Epoch 100/100
# 81/81 [==============================] - 1s 17ms/step - loss: 0.0567 - mean_absolute_error: 0.0385 - mean_squared_error: 0.0054

# %%
y_pred = model.predict(X_test)
def remove_outliers(y_pred, y_test, threshold=2):
    z_scores = np.abs((y_pred - np.mean(y_pred)) / np.std(y_pred))
    outliers_mask = z_scores > 2.0

    y_pred_filtered = y_pred[~outliers_mask]
    y_test_filtered = y_test[~outliers_mask]

    return y_pred_filtered, y_test_filtered

# Assuming you have y_pred, y_test, and X_test available
y_pred_0, y_test_filtered_0 = remove_outliers(y_pred[:, 0], y_test[:, 0], threshold=2.0)
y_pred_1, y_test_filtered_1 = remove_outliers(y_pred[:, 1], y_test[:, 1], threshold=2.0)
# Out:
# 126/126 [==============================] - 1s 6ms/step

# %%
plt.figure(figsize=(16, 4))
plt.subplot(1, 2, 1)
plt.plot([0, len(y_test_filtered_0) - 1], [np.mean(y_pred_0), np.mean(y_pred_0)], label='Predicted Mean', color='red', linestyle='dashed')
plt.scatter(range(len(y_test_filtered_0)),y_test_filtered_0, label='Actual', color='blue', alpha=0.5)
plt.scatter(range(len(y_test_filtered_0)), y_pred_0, label='Predicted', color='orange', alpha=0.5)
plt.title('Comparison of Actual and Predicted Permittivity Real Values')
plt.xlabel('Data Point')
plt.ylabel('Value')
plt.legend()

# %%
plt.figure(figsize=(16, 4))
plt.subplot(1, 2, 1)
plt.plot([0, len(y_test_filtered_1) - 1], [np.mean(y_pred_1), np.mean(y_pred_1)], label='Predicted Mean', color='red', linestyle='dashed')
plt.scatter(range(len(y_test_filtered_1)), y_test_filtered_1, label='Actual', color='blue', alpha=0.5)
plt.scatter(range(len(y_test_filtered_1)), y_pred_1, label='Predicted', color='orange', alpha=0.5)
plt.title('Comparison of Actual and Predicted Permittivity Imaginary Values')
plt.xlabel('Data Point')
plt.ylabel('Value')
plt.legend()

# %% [markdown]
# # CONV1D

# %%
X_train = training_dataframe[columns].values
X_train = X_train.reshape((-1, 1001, X_train.shape[1]))
y_train = training_dataframe[['Permittivity_Real', 'Permittivity_Imaginary']].values
y_train = y_train.reshape((-1, 1001, 2))
X_test = testing_dataframe[columns].values
X_test = X_test.reshape((-1, 1001, X_test.shape[1]))
y_test = testing_dataframe[['Permittivity_Real', 'Permittivity_Imaginary']].values
y_test = y_test.reshape((-1, 1001, 2))
X_train = X_train.astype(float)
y_train = y_train.astype(float)[:,0,:]
X_test = X_test.astype(float)
y_test = y_test.astype(float)

# %%
def thresholded_rmse_loss(y_true, y_pred, threshold=2.0):
    y_true_real, y_true_imag = tf.split(y_true, 2, axis=-1)
    y_pred_real, y_pred_imag = tf.split(y_pred, 2, axis=-1)

    y_pred_real = tf.clip_by_value(y_pred_real, 0.0, threshold)
    y_pred_imag = tf.clip_by_value(y_pred_imag, 0.0, threshold)

    squared_error_real = tf.square(y_true_real - y_pred_real)
    squared_error_imag = tf.square(y_true_imag - y_pred_imag)
    mean_squared_error_loss_real = tf.reduce_mean(squared_error_real)
    mean_squared_error_loss_imag = tf.reduce_mean(squared_error_imag)
    root_mean_squared_error_loss_real = tf.sqrt(mean_squared_error_loss_real)
    root_mean_squared_error_loss_imag = tf.sqrt(mean_squared_error_loss_imag)
    return 0.5 * root_mean_squared_error_loss_real + 0.5 * root_mean_squared_error_loss_imag

model = keras.Sequential([
        keras.layers.Conv1D(filters=128, kernel_size=3, activation='relu', input_shape=(1001,X_train.shape[2])),
        keras.layers.Conv1D(filters=64, kernel_size=3, activation='relu'),
        keras.layers.Conv1D(filters=32, kernel_size=3, activation='relu'),
        keras.layers.Conv1D(filters=16, kernel_size=3, activation='relu'),
        keras.layers.Flatten(),
        keras.layers.Dense(y_train.shape[1], activation='linear')
    ])


model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.0001,weight_decay=0.001),
              loss=[thresholded_rmse_loss],
              metrics=[tf.metrics.MeanAbsoluteError(), tf.metrics.MeanSquaredError()])
model.summary()
history = model.fit(X_train, y_train, epochs=100, batch_size=20,shuffle=False)
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['mean_absolute_error'])
plt.title('Mean Absolute Error')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error')
plt.legend(['Train'])
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train'])
plt.tight_layout()
plt.show()
# Out:
# Model: "sequential_111"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_356 (Conv1D)         (None, 999, 128)          3584
#
#  conv1d_357 (Conv1D)         (None, 997, 64)           24640
#
#  conv1d_358 (Conv1D)         (None, 995, 32)           6176
#
#  conv1d_359 (Conv1D)         (None, 993, 16)           1552
#
#  flatten_94 (Flatten)        (None, 15888)             0
#
#  dense_161 (Dense)           (None, 2)                 31778
#
# =================================================================
# Total params: 67,730
# Trainable params: 67,730
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 20/20 [==============================] - 3s 7ms/step - loss: 0.3658 - mean_absolute_error: 0.3223 - mean_squared_error: 0.1751
# Epoch 2/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1518 - mean_absolute_error: 0.1300 - mean_squared_error: 0.0360
# Epoch 3/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1081 - mean_absolute_error: 0.0943 - mean_squared_error: 0.0151
# Epoch 4/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0673 - mean_absolute_error: 0.0595 - mean_squared_error: 0.0073
# Epoch 5/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0647 - mean_absolute_error: 0.0572 - mean_squared_error: 0.0068
# Epoch 6/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0672 - mean_absolute_error: 0.0607 - mean_squared_error: 0.0068
# Epoch 7/100
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0561 - mean_absolute_error: 0.0493 - mean_squared_error: 0.0059
# Epoch 8/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0623 - mean_absolute_error: 0.0560 - mean_squared_error: 0.0073
# Epoch 9/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0726 - mean_absolute_error: 0.0669 - mean_squared_error: 0.0107
# Epoch 10/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0969 - mean_absolute_error: 0.0925 - mean_squared_error: 0.0206
# Epoch 11/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1098 - mean_absolute_error: 0.1006 - mean_squared_error: 0.0232
# Epoch 12/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1042 - mean_absolute_error: 0.0928 - mean_squared_error: 0.0177
# Epoch 13/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0964 - mean_absolute_error: 0.0839 - mean_squared_error: 0.0139
# Epoch 14/100
# 20/20 [==============================] - 1s 67ms/step - loss: 0.0941 - mean_absolute_error: 0.0820 - mean_squared_error: 0.0132
# Epoch 15/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0849 - mean_absolute_error: 0.0733 - mean_squared_error: 0.0122
# Epoch 16/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0793 - mean_absolute_error: 0.0673 - mean_squared_error: 0.0113
# Epoch 17/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0742 - mean_absolute_error: 0.0624 - mean_squared_error: 0.0103
# Epoch 18/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0666 - mean_absolute_error: 0.0557 - mean_squared_error: 0.0098
# Epoch 19/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0636 - mean_absolute_error: 0.0531 - mean_squared_error: 0.0094
# Epoch 20/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0651 - mean_absolute_error: 0.0546 - mean_squared_error: 0.0089
# Epoch 21/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0621 - mean_absolute_error: 0.0515 - mean_squared_error: 0.0081
# Epoch 22/100
# 20/20 [==============================] - 1s 69ms/step - loss: 0.0581 - mean_absolute_error: 0.0474 - mean_squared_error: 0.0072
# Epoch 23/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0598 - mean_absolute_error: 0.0490 - mean_squared_error: 0.0075
# Epoch 24/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0619 - mean_absolute_error: 0.0510 - mean_squared_error: 0.0081
# Epoch 25/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0603 - mean_absolute_error: 0.0496 - mean_squared_error: 0.0086
# Epoch 26/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0635 - mean_absolute_error: 0.0530 - mean_squared_error: 0.0093
# Epoch 27/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0678 - mean_absolute_error: 0.0567 - mean_squared_error: 0.0095
# Epoch 28/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0675 - mean_absolute_error: 0.0562 - mean_squared_error: 0.0092
# Epoch 29/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0669 - mean_absolute_error: 0.0558 - mean_squared_error: 0.0087
# Epoch 30/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0723 - mean_absolute_error: 0.0610 - mean_squared_error: 0.0090
# Epoch 31/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0715 - mean_absolute_error: 0.0620 - mean_squared_error: 0.0088
# Epoch 32/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0656 - mean_absolute_error: 0.0556 - mean_squared_error: 0.0081
# Epoch 33/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0583 - mean_absolute_error: 0.0477 - mean_squared_error: 0.0075
# Epoch 34/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0614 - mean_absolute_error: 0.0501 - mean_squared_error: 0.0066
# Epoch 35/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0578 - mean_absolute_error: 0.0468 - mean_squared_error: 0.0069
# Epoch 36/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0549 - mean_absolute_error: 0.0444 - mean_squared_error: 0.0073
# Epoch 37/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0582 - mean_absolute_error: 0.0474 - mean_squared_error: 0.0078
# Epoch 38/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0582 - mean_absolute_error: 0.0478 - mean_squared_error: 0.0082
# Epoch 39/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0595 - mean_absolute_error: 0.0490 - mean_squared_error: 0.0085
# Epoch 40/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0612 - mean_absolute_error: 0.0507 - mean_squared_error: 0.0086
# Epoch 41/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0596 - mean_absolute_error: 0.0490 - mean_squared_error: 0.0080
# Epoch 42/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0542 - mean_absolute_error: 0.0441 - mean_squared_error: 0.0075
# Epoch 43/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0584 - mean_absolute_error: 0.0476 - mean_squared_error: 0.0074
# Epoch 44/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0545 - mean_absolute_error: 0.0442 - mean_squared_error: 0.0069
# Epoch 45/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0536 - mean_absolute_error: 0.0433 - mean_squared_error: 0.0063
# Epoch 46/100
# 20/20 [==============================] - 1s 65ms/step - loss: 0.0531 - mean_absolute_error: 0.0430 - mean_squared_error: 0.0055
# Epoch 47/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0600 - mean_absolute_error: 0.0498 - mean_squared_error: 0.0063
# Epoch 48/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0574 - mean_absolute_error: 0.0468 - mean_squared_error: 0.0060
# Epoch 49/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0505 - mean_absolute_error: 0.0403 - mean_squared_error: 0.0057
# Epoch 50/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0531 - mean_absolute_error: 0.0427 - mean_squared_error: 0.0065
# Epoch 51/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0551 - mean_absolute_error: 0.0449 - mean_squared_error: 0.0074
# Epoch 52/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0648 - mean_absolute_error: 0.0539 - mean_squared_error: 0.0081
# Epoch 53/100
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0703 - mean_absolute_error: 0.0597 - mean_squared_error: 0.0086
# Epoch 54/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0726 - mean_absolute_error: 0.0620 - mean_squared_error: 0.0084
# Epoch 55/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0561 - mean_absolute_error: 0.0456 - mean_squared_error: 0.0070
# Epoch 56/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0543 - mean_absolute_error: 0.0433 - mean_squared_error: 0.0067
# Epoch 57/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0499 - mean_absolute_error: 0.0397 - mean_squared_error: 0.0063
# Epoch 58/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0493 - mean_absolute_error: 0.0390 - mean_squared_error: 0.0062
# Epoch 59/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0477 - mean_absolute_error: 0.0374 - mean_squared_error: 0.0061
# Epoch 60/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0462 - mean_absolute_error: 0.0361 - mean_squared_error: 0.0058
# Epoch 61/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0445 - mean_absolute_error: 0.0344 - mean_squared_error: 0.0056
# Epoch 62/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0438 - mean_absolute_error: 0.0337 - mean_squared_error: 0.0054
# Epoch 63/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0419 - mean_absolute_error: 0.0323 - mean_squared_error: 0.0046
# Epoch 64/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0402 - mean_absolute_error: 0.0311 - mean_squared_error: 0.0040
# Epoch 65/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0446 - mean_absolute_error: 0.0347 - mean_squared_error: 0.0043
# Epoch 66/100
# 20/20 [==============================] - 1s 70ms/step - loss: 0.0512 - mean_absolute_error: 0.0406 - mean_squared_error: 0.0052
# Epoch 67/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0627 - mean_absolute_error: 0.0522 - mean_squared_error: 0.0074
# Epoch 68/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0589 - mean_absolute_error: 0.0482 - mean_squared_error: 0.0065
# Epoch 69/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0652 - mean_absolute_error: 0.0545 - mean_squared_error: 0.0076
# Epoch 70/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0543 - mean_absolute_error: 0.0437 - mean_squared_error: 0.0063
# Epoch 71/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0509 - mean_absolute_error: 0.0400 - mean_squared_error: 0.0057
# Epoch 72/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0456 - mean_absolute_error: 0.0353 - mean_squared_error: 0.0053
# Epoch 73/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0503 - mean_absolute_error: 0.0400 - mean_squared_error: 0.0053
# Epoch 74/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0543 - mean_absolute_error: 0.0438 - mean_squared_error: 0.0055
# Epoch 75/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0587 - mean_absolute_error: 0.0487 - mean_squared_error: 0.0060
# Epoch 76/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0503 - mean_absolute_error: 0.0398 - mean_squared_error: 0.0055
# Epoch 77/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0466 - mean_absolute_error: 0.0362 - mean_squared_error: 0.0047
# Epoch 78/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0453 - mean_absolute_error: 0.0347 - mean_squared_error: 0.0047
# Epoch 79/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0429 - mean_absolute_error: 0.0330 - mean_squared_error: 0.0043
# Epoch 80/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0477 - mean_absolute_error: 0.0386 - mean_squared_error: 0.0043
# Epoch 81/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0531 - mean_absolute_error: 0.0434 - mean_squared_error: 0.0050
# Epoch 82/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0439 - mean_absolute_error: 0.0341 - mean_squared_error: 0.0047
# Epoch 83/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0389 - mean_absolute_error: 0.0302 - mean_squared_error: 0.0037
# Epoch 84/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0403 - mean_absolute_error: 0.0329 - mean_squared_error: 0.0033
# Epoch 85/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0527 - mean_absolute_error: 0.0431 - mean_squared_error: 0.0048
# Epoch 86/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0502 - mean_absolute_error: 0.0411 - mean_squared_error: 0.0043
# Epoch 87/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0457 - mean_absolute_error: 0.0373 - mean_squared_error: 0.0037
# Epoch 88/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0416 - mean_absolute_error: 0.0336 - mean_squared_error: 0.0032
# Epoch 89/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0384 - mean_absolute_error: 0.0311 - mean_squared_error: 0.0030
# Epoch 90/100
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0365 - mean_absolute_error: 0.0300 - mean_squared_error: 0.0027
# Epoch 91/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0388 - mean_absolute_error: 0.0317 - mean_squared_error: 0.0029
# Epoch 92/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0435 - mean_absolute_error: 0.0362 - mean_squared_error: 0.0031
# Epoch 93/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0508 - mean_absolute_error: 0.0423 - mean_squared_error: 0.0039
# Epoch 94/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0477 - mean_absolute_error: 0.0395 - mean_squared_error: 0.0041
# Epoch 95/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0402 - mean_absolute_error: 0.0327 - mean_squared_error: 0.0032
# Epoch 96/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0381 - mean_absolute_error: 0.0315 - mean_squared_error: 0.0029
# Epoch 97/100
# 20/20 [==============================] - 1s 5ms/step - loss: 0.0364 - mean_absolute_error: 0.0300 - mean_squared_error: 0.0028
# Epoch 98/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0415 - mean_absolute_error: 0.0342 - mean_squared_error: 0.0032
# Epoch 99/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0380 - mean_absolute_error: 0.0320 - mean_squared_error: 0.0029
# Epoch 100/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0483 - mean_absolute_error: 0.0397 - mean_squared_error: 0.0040

# %%
y_pred = model.predict(X_test)
def remove_outliers(y_pred, y_test, threshold=2):
    z_scores = np.abs((y_pred - np.mean(y_pred)) / np.std(y_pred))
    outliers_mask = z_scores > 2.0

    y_pred_filtered = y_pred[~outliers_mask]
    y_test_filtered = y_test[~outliers_mask]

    return y_pred_filtered, y_test_filtered

# Assuming you have y_pred, y_test, and X_test available
y_pred_0, y_test_filtered_0 = remove_outliers(y_pred[:, 0], y_test[:,0, 0], threshold=2.0)
y_pred_1, y_test_filtered_1 = remove_outliers(y_pred[:, 1], y_test[:,0, 1], threshold=2.0)
# Out:
# 1/1 [==============================] - 0s 94ms/step

# %%
plt.figure(figsize=(16, 4))
plt.subplot(1, 2, 1)
plt.plot([0, len(y_test_filtered_0) - 1], [np.mean(y_pred_0), np.mean(y_pred_0)], label='Predicted Mean', color='red', linestyle='dashed')
plt.scatter(range(len(y_test_filtered_0)),y_test_filtered_0, label='Actual', color='blue', alpha=0.5)
plt.scatter(range(len(y_test_filtered_0)), y_pred_0, label='Predicted', color='orange', alpha=0.5)
plt.title('Comparison of Actual and Predicted Permittivity Real Values')
plt.xlabel('Data Point')
plt.ylabel('Value')
plt.legend()

# %%
plt.figure(figsize=(16, 4))
plt.subplot(1, 2, 1)
plt.plot([0, len(y_test_filtered_1) - 1], [np.mean(y_pred_1), np.mean(y_pred_1)], label='Predicted Mean', color='red', linestyle='dashed')
plt.scatter(range(len(y_test_filtered_1)), y_test_filtered_1, label='Actual', color='blue', alpha=0.5)
plt.scatter(range(len(y_test_filtered_1)), y_pred_1, label='Predicted', color='orange', alpha=0.5)
plt.title('Comparison of Actual and Predicted Permittivity Imaginary Values')
plt.xlabel('Data Point')
plt.ylabel('Value')
plt.legend()

# %% [markdown]
# # LSTM

# %%
X_train = training_dataframe[columns].values
X_train = X_train.reshape((-1, 1001, X_train.shape[1]))
y_train = training_dataframe[['Permittivity_Real', 'Permittivity_Imaginary']].values
y_train = y_train.reshape((-1, 1001, 2))
X_test = testing_dataframe[columns].values
X_test = X_test.reshape((-1, 1001, X_test.shape[1]))
y_test = testing_dataframe[['Permittivity_Real', 'Permittivity_Imaginary']].values
y_test = y_test.reshape((-1, 1001, 2))
X_train = X_train.astype(float)
y_train = y_train.astype(float)[:,0,:]
X_test = X_test.astype(float)
y_test = y_test.astype(float)

# %%
def thresholded_rmse_loss(y_true, y_pred, threshold=2.0):
    y_true_real, y_true_imag = tf.split(y_true, 2, axis=-1)
    y_pred_real, y_pred_imag = tf.split(y_pred, 2, axis=-1)

    y_pred_real = tf.clip_by_value(y_pred_real, 0.0, threshold)
    y_pred_imag = tf.clip_by_value(y_pred_imag, 0.0, threshold)

    squared_error_real = tf.square(y_true_real - y_pred_real)
    squared_error_imag = tf.square(y_true_imag - y_pred_imag)
    mean_squared_error_loss_real = tf.reduce_mean(squared_error_real)
    mean_squared_error_loss_imag = tf.reduce_mean(squared_error_imag)
    root_mean_squared_error_loss_real = tf.sqrt(mean_squared_error_loss_real)
    root_mean_squared_error_loss_imag = tf.sqrt(mean_squared_error_loss_imag)
    return 0.5 * root_mean_squared_error_loss_real + 0.5 * root_mean_squared_error_loss_imag

model = keras.Sequential([
    keras.layers.LSTM(128, return_sequences=True, input_shape=(1001,X_train.shape[2])),
    keras.layers.LSTM(64, return_sequences=True),
    keras.layers.LSTM(32, return_sequences=True),
    keras.layers.LSTM(16, return_sequences=True),
    keras.layers.GlobalAveragePooling1D(),
    keras.layers.Dense(y_train.shape[1], activation='linear')
])



model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.0001,weight_decay=0.001),
              loss=[thresholded_rmse_loss],
              metrics=[tf.metrics.MeanAbsoluteError(), tf.metrics.MeanSquaredError()])
model.summary()
history = model.fit(X_train, y_train, epochs=100, batch_size=20,shuffle=False)
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['mean_absolute_error'])
plt.title('Mean Absolute Error')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error')
plt.legend(['Train'])
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train'])
plt.tight_layout()
plt.show()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_60 (LSTM)              (None, 1001, 128)         70656
#
#  lstm_61 (LSTM)              (None, 1001, 64)          49408
#
#  lstm_62 (LSTM)              (None, 1001, 32)          12416
#
#  lstm_63 (LSTM)              (None, 1001, 16)          3136
#
#  global_average_pooling1d_19  (None, 16)               0
#   (GlobalAveragePooling1D)
#
#  dense_19 (Dense)            (None, 2)                 34
#
# =================================================================
# Total params: 135,650
# Trainable params: 135,650
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 20/20 [==============================] - 11s 231ms/step - loss: 0.3346 - mean_absolute_error: 0.2826 - mean_squared_error: 0.1200
# Epoch 2/100
# 20/20 [==============================] - 3s 164ms/step - loss: 0.2602 - mean_absolute_error: 0.2266 - mean_squared_error: 0.0700
# Epoch 3/100
# 20/20 [==============================] - 3s 161ms/step - loss: 0.2172 - mean_absolute_error: 0.1885 - mean_squared_error: 0.0531
# Epoch 4/100
# 20/20 [==============================] - 3s 159ms/step - loss: 0.1582 - mean_absolute_error: 0.1386 - mean_squared_error: 0.0390
# Epoch 5/100
# 20/20 [==============================] - 3s 161ms/step - loss: 0.1435 - mean_absolute_error: 0.1233 - mean_squared_error: 0.0357
# Epoch 6/100
# 20/20 [==============================] - 4s 212ms/step - loss: 0.1373 - mean_absolute_error: 0.1184 - mean_squared_error: 0.0338
# Epoch 7/100
# 20/20 [==============================] - 3s 159ms/step - loss: 0.1321 - mean_absolute_error: 0.1141 - mean_squared_error: 0.0316
# Epoch 8/100
# 20/20 [==============================] - 3s 158ms/step - loss: 0.1255 - mean_absolute_error: 0.1081 - mean_squared_error: 0.0285
# Epoch 9/100
# 20/20 [==============================] - 6s 304ms/step - loss: 0.1156 - mean_absolute_error: 0.0988 - mean_squared_error: 0.0239
# Epoch 10/100
# 20/20 [==============================] - 4s 187ms/step - loss: 0.0992 - mean_absolute_error: 0.0833 - mean_squared_error: 0.0170
# Epoch 11/100
# 20/20 [==============================] - 4s 211ms/step - loss: 0.0809 - mean_absolute_error: 0.0698 - mean_squared_error: 0.0111
# Epoch 12/100
# 20/20 [==============================] - 3s 160ms/step - loss: 0.0717 - mean_absolute_error: 0.0620 - mean_squared_error: 0.0087
# Epoch 13/100
# 20/20 [==============================] - 3s 159ms/step - loss: 0.0665 - mean_absolute_error: 0.0549 - mean_squared_error: 0.0074
# Epoch 14/100
# 20/20 [==============================] - 3s 159ms/step - loss: 0.0679 - mean_absolute_error: 0.0566 - mean_squared_error: 0.0074
# Epoch 15/100
# 20/20 [==============================] - 3s 167ms/step - loss: 0.0634 - mean_absolute_error: 0.0537 - mean_squared_error: 0.0062
# Epoch 16/100
# 20/20 [==============================] - 3s 160ms/step - loss: 0.0612 - mean_absolute_error: 0.0514 - mean_squared_error: 0.0057
# Epoch 17/100
# 20/20 [==============================] - 4s 215ms/step - loss: 0.0678 - mean_absolute_error: 0.0587 - mean_squared_error: 0.0076
# Epoch 18/100
# 20/20 [==============================] - 4s 228ms/step - loss: 0.0847 - mean_absolute_error: 0.0739 - mean_squared_error: 0.0129
# Epoch 19/100
# 20/20 [==============================] - 3s 160ms/step - loss: 0.1016 - mean_absolute_error: 0.0889 - mean_squared_error: 0.0187
# Epoch 20/100
# 20/20 [==============================] - 3s 163ms/step - loss: 0.0898 - mean_absolute_error: 0.0783 - mean_squared_error: 0.0162
# Epoch 21/100
# 20/20 [==============================] - 3s 162ms/step - loss: 0.0836 - mean_absolute_error: 0.0709 - mean_squared_error: 0.0134
# Epoch 22/100
# 20/20 [==============================] - 3s 160ms/step - loss: 0.0782 - mean_absolute_error: 0.0658 - mean_squared_error: 0.0116
# Epoch 23/100
# 20/20 [==============================] - 3s 159ms/step - loss: 0.0760 - mean_absolute_error: 0.0639 - mean_squared_error: 0.0110
# Epoch 24/100
# 20/20 [==============================] - 4s 158ms/step - loss: 0.0750 - mean_absolute_error: 0.0629 - mean_squared_error: 0.0107
# Epoch 25/100
# 20/20 [==============================] - 3s 164ms/step - loss: 0.0738 - mean_absolute_error: 0.0617 - mean_squared_error: 0.0103
# Epoch 26/100
# 20/20 [==============================] - 3s 157ms/step - loss: 0.0728 - mean_absolute_error: 0.0608 - mean_squared_error: 0.0101
# Epoch 27/100
# 20/20 [==============================] - 4s 196ms/step - loss: 0.0719 - mean_absolute_error: 0.0600 - mean_squared_error: 0.0099
# Epoch 28/100
# 20/20 [==============================] - 3s 163ms/step - loss: 0.0711 - mean_absolute_error: 0.0593 - mean_squared_error: 0.0097
# Epoch 29/100
# 20/20 [==============================] - 3s 165ms/step - loss: 0.0704 - mean_absolute_error: 0.0586 - mean_squared_error: 0.0096
# Epoch 30/100
# 20/20 [==============================] - 3s 159ms/step - loss: 0.0698 - mean_absolute_error: 0.0581 - mean_squared_error: 0.0095
# Epoch 31/100
# 20/20 [==============================] - 4s 181ms/step - loss: 0.0693 - mean_absolute_error: 0.0576 - mean_squared_error: 0.0093
# Epoch 32/100
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0689 - mean_absolute_error: 0.0572 - mean_squared_error: 0.0093
# Epoch 33/100
# 20/20 [==============================] - 4s 200ms/step - loss: 0.0686 - mean_absolute_error: 0.0570 - mean_squared_error: 0.0092
# Epoch 34/100
# 20/20 [==============================] - 4s 213ms/step - loss: 0.0685 - mean_absolute_error: 0.0568 - mean_squared_error: 0.0091
# Epoch 35/100
# 20/20 [==============================] - 3s 167ms/step - loss: 0.0683 - mean_absolute_error: 0.0567 - mean_squared_error: 0.0090
# Epoch 36/100
# 20/20 [==============================] - 3s 162ms/step - loss: 0.0682 - mean_absolute_error: 0.0566 - mean_squared_error: 0.0090
# Epoch 37/100
# 20/20 [==============================] - 3s 158ms/step - loss: 0.0679 - mean_absolute_error: 0.0564 - mean_squared_error: 0.0089
# Epoch 38/100
# 20/20 [==============================] - 4s 181ms/step - loss: 0.0679 - mean_absolute_error: 0.0564 - mean_squared_error: 0.0089
# Epoch 39/100
# 20/20 [==============================] - 3s 161ms/step - loss: 0.0679 - mean_absolute_error: 0.0565 - mean_squared_error: 0.0088
# Epoch 40/100
# 20/20 [==============================] - 3s 160ms/step - loss: 0.0675 - mean_absolute_error: 0.0562 - mean_squared_error: 0.0088
# Epoch 41/100
# 20/20 [==============================] - 3s 163ms/step - loss: 0.0666 - mean_absolute_error: 0.0553 - mean_squared_error: 0.0088
# Epoch 42/100
# 20/20 [==============================] - 3s 161ms/step - loss: 0.0659 - mean_absolute_error: 0.0547 - mean_squared_error: 0.0087
# Epoch 43/100
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0650 - mean_absolute_error: 0.0538 - mean_squared_error: 0.0086
# Epoch 44/100
# 20/20 [==============================] - 5s 240ms/step - loss: 0.0645 - mean_absolute_error: 0.0532 - mean_squared_error: 0.0086
# Epoch 45/100
# 20/20 [==============================] - 3s 159ms/step - loss: 0.0638 - mean_absolute_error: 0.0525 - mean_squared_error: 0.0086
# Epoch 46/100
# 20/20 [==============================] - 3s 157ms/step - loss: 0.0630 - mean_absolute_error: 0.0519 - mean_squared_error: 0.0086
# Epoch 47/100
# 20/20 [==============================] - 3s 161ms/step - loss: 0.0633 - mean_absolute_error: 0.0521 - mean_squared_error: 0.0086
# Epoch 48/100
# 20/20 [==============================] - 3s 162ms/step - loss: 0.0630 - mean_absolute_error: 0.0520 - mean_squared_error: 0.0086
# Epoch 49/100
# 20/20 [==============================] - 3s 156ms/step - loss: 0.0641 - mean_absolute_error: 0.0531 - mean_squared_error: 0.0086
# Epoch 50/100
# 20/20 [==============================] - 4s 230ms/step - loss: 0.0649 - mean_absolute_error: 0.0540 - mean_squared_error: 0.0086
# Epoch 51/100
# 20/20 [==============================] - 5s 244ms/step - loss: 0.0647 - mean_absolute_error: 0.0538 - mean_squared_error: 0.0086
# Epoch 52/100
# 20/20 [==============================] - 4s 185ms/step - loss: 0.0639 - mean_absolute_error: 0.0531 - mean_squared_error: 0.0086
# Epoch 53/100
# 20/20 [==============================] - 3s 161ms/step - loss: 0.0631 - mean_absolute_error: 0.0524 - mean_squared_error: 0.0086
# Epoch 54/100
# 20/20 [==============================] - 3s 159ms/step - loss: 0.0622 - mean_absolute_error: 0.0515 - mean_squared_error: 0.0085
# Epoch 55/100
# 20/20 [==============================] - 4s 210ms/step - loss: 0.0614 - mean_absolute_error: 0.0507 - mean_squared_error: 0.0085
# Epoch 56/100
# 20/20 [==============================] - 3s 158ms/step - loss: 0.0605 - mean_absolute_error: 0.0499 - mean_squared_error: 0.0086
# Epoch 57/100
# 20/20 [==============================] - 3s 165ms/step - loss: 0.0595 - mean_absolute_error: 0.0490 - mean_squared_error: 0.0086
# Epoch 58/100
# 20/20 [==============================] - 6s 293ms/step - loss: 0.0600 - mean_absolute_error: 0.0495 - mean_squared_error: 0.0086
# Epoch 59/100
# 20/20 [==============================] - 4s 186ms/step - loss: 0.0590 - mean_absolute_error: 0.0486 - mean_squared_error: 0.0087
# Epoch 60/100
# 20/20 [==============================] - 5s 239ms/step - loss: 0.0598 - mean_absolute_error: 0.0494 - mean_squared_error: 0.0087
# Epoch 61/100
# 20/20 [==============================] - 3s 163ms/step - loss: 0.0605 - mean_absolute_error: 0.0502 - mean_squared_error: 0.0087
# Epoch 62/100
# 20/20 [==============================] - 3s 158ms/step - loss: 0.0622 - mean_absolute_error: 0.0520 - mean_squared_error: 0.0089
# Epoch 63/100
# 20/20 [==============================] - 3s 160ms/step - loss: 0.0611 - mean_absolute_error: 0.0508 - mean_squared_error: 0.0089
# Epoch 64/100
# 20/20 [==============================] - 4s 181ms/step - loss: 0.0607 - mean_absolute_error: 0.0507 - mean_squared_error: 0.0089
# Epoch 65/100
# 20/20 [==============================] - 3s 159ms/step - loss: 0.0595 - mean_absolute_error: 0.0496 - mean_squared_error: 0.0088
# Epoch 66/100
# 20/20 [==============================] - 3s 164ms/step - loss: 0.0588 - mean_absolute_error: 0.0490 - mean_squared_error: 0.0088
# Epoch 67/100
# 20/20 [==============================] - 3s 162ms/step - loss: 0.0565 - mean_absolute_error: 0.0469 - mean_squared_error: 0.0086
# Epoch 68/100
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0541 - mean_absolute_error: 0.0451 - mean_squared_error: 0.0081
# Epoch 69/100
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0509 - mean_absolute_error: 0.0418 - mean_squared_error: 0.0074
# Epoch 70/100
# 20/20 [==============================] - 4s 209ms/step - loss: 0.0507 - mean_absolute_error: 0.0403 - mean_squared_error: 0.0069
# Epoch 71/100
# 20/20 [==============================] - 5s 239ms/step - loss: 0.0562 - mean_absolute_error: 0.0447 - mean_squared_error: 0.0078
# Epoch 72/100
# 20/20 [==============================] - 4s 230ms/step - loss: 0.0590 - mean_absolute_error: 0.0487 - mean_squared_error: 0.0088
# Epoch 73/100
# 20/20 [==============================] - 4s 219ms/step - loss: 0.0622 - mean_absolute_error: 0.0520 - mean_squared_error: 0.0095
# Epoch 74/100
# 20/20 [==============================] - 5s 283ms/step - loss: 0.0638 - mean_absolute_error: 0.0532 - mean_squared_error: 0.0096
# Epoch 75/100
# 20/20 [==============================] - 4s 184ms/step - loss: 0.0635 - mean_absolute_error: 0.0528 - mean_squared_error: 0.0091
# Epoch 76/100
# 20/20 [==============================] - 6s 296ms/step - loss: 0.0612 - mean_absolute_error: 0.0510 - mean_squared_error: 0.0089
# Epoch 77/100
# 20/20 [==============================] - 3s 161ms/step - loss: 0.0603 - mean_absolute_error: 0.0501 - mean_squared_error: 0.0089
# Epoch 78/100
# 20/20 [==============================] - 5s 238ms/step - loss: 0.0595 - mean_absolute_error: 0.0494 - mean_squared_error: 0.0089
# Epoch 79/100
# 20/20 [==============================] - 6s 292ms/step - loss: 0.0580 - mean_absolute_error: 0.0478 - mean_squared_error: 0.0090
# Epoch 80/100
# 20/20 [==============================] - 4s 230ms/step - loss: 0.0577 - mean_absolute_error: 0.0476 - mean_squared_error: 0.0091
# Epoch 81/100
# 20/20 [==============================] - 3s 171ms/step - loss: 0.0582 - mean_absolute_error: 0.0482 - mean_squared_error: 0.0091
# Epoch 82/100
# 20/20 [==============================] - 4s 220ms/step - loss: 0.0590 - mean_absolute_error: 0.0490 - mean_squared_error: 0.0090
# Epoch 83/100
# 20/20 [==============================] - 3s 163ms/step - loss: 0.0591 - mean_absolute_error: 0.0491 - mean_squared_error: 0.0089
# Epoch 84/100
# 20/20 [==============================] - 4s 207ms/step - loss: 0.0583 - mean_absolute_error: 0.0484 - mean_squared_error: 0.0089
# Epoch 85/100
# 20/20 [==============================] - 3s 163ms/step - loss: 0.0577 - mean_absolute_error: 0.0479 - mean_squared_error: 0.0089
# Epoch 86/100
# 20/20 [==============================] - 5s 237ms/step - loss: 0.0574 - mean_absolute_error: 0.0477 - mean_squared_error: 0.0088
# Epoch 87/100
# 20/20 [==============================] - 5s 262ms/step - loss: 0.0578 - mean_absolute_error: 0.0480 - mean_squared_error: 0.0088
# Epoch 88/100
# 20/20 [==============================] - 3s 167ms/step - loss: 0.0594 - mean_absolute_error: 0.0497 - mean_squared_error: 0.0088
# Epoch 89/100
# 20/20 [==============================] - 3s 162ms/step - loss: 0.0593 - mean_absolute_error: 0.0491 - mean_squared_error: 0.0088
# Epoch 90/100
# 20/20 [==============================] - 3s 158ms/step - loss: 0.0588 - mean_absolute_error: 0.0489 - mean_squared_error: 0.0086
# Epoch 91/100
# 20/20 [==============================] - 3s 162ms/step - loss: 0.0572 - mean_absolute_error: 0.0476 - mean_squared_error: 0.0085
# Epoch 92/100
# 20/20 [==============================] - 3s 165ms/step - loss: 0.0553 - mean_absolute_error: 0.0458 - mean_squared_error: 0.0084
# Epoch 93/100
# 20/20 [==============================] - 4s 211ms/step - loss: 0.0543 - mean_absolute_error: 0.0448 - mean_squared_error: 0.0083
# Epoch 94/100
# 20/20 [==============================] - 3s 158ms/step - loss: 0.0539 - mean_absolute_error: 0.0446 - mean_squared_error: 0.0084
# Epoch 95/100
# 20/20 [==============================] - 6s 299ms/step - loss: 0.0545 - mean_absolute_error: 0.0452 - mean_squared_error: 0.0085
# Epoch 96/100
# 20/20 [==============================] - 3s 163ms/step - loss: 0.0549 - mean_absolute_error: 0.0456 - mean_squared_error: 0.0085
# Epoch 97/100
# 20/20 [==============================] - 3s 162ms/step - loss: 0.0565 - mean_absolute_error: 0.0470 - mean_squared_error: 0.0085
# Epoch 98/100
# 20/20 [==============================] - 3s 158ms/step - loss: 0.0574 - mean_absolute_error: 0.0476 - mean_squared_error: 0.0083
# Epoch 99/100
# 20/20 [==============================] - 3s 161ms/step - loss: 0.0546 - mean_absolute_error: 0.0453 - mean_squared_error: 0.0081
# Epoch 100/100
# 20/20 [==============================] - 3s 161ms/step - loss: 0.0527 - mean_absolute_error: 0.0435 - mean_squared_error: 0.0078

# %%
y_pred = model.predict(X_test)
def remove_outliers(y_pred, y_test, threshold=2):
    z_scores = np.abs((y_pred - np.mean(y_pred)) / np.std(y_pred))
    outliers_mask = z_scores > 2.0

    y_pred_filtered = y_pred[~outliers_mask]
    y_test_filtered = y_test[~outliers_mask]

    return y_pred_filtered, y_test_filtered

# Assuming you have y_pred, y_test, and X_test available
y_pred_0, y_test_filtered_0 = remove_outliers(y_pred[:, 0], y_test[:,0, 0], threshold=2.0)
y_pred_1, y_test_filtered_1 = remove_outliers(y_pred[:, 1], y_test[:,0, 1], threshold=2.0)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
plt.figure(figsize=(16, 4))
plt.subplot(1, 2, 1)
plt.plot([0, len(y_test_filtered_0) - 1], [np.mean(y_pred_0), np.mean(y_pred_0)], label='Predicted Mean', color='red', linestyle='dashed')
plt.scatter(range(len(y_test_filtered_0)),y_test_filtered_0, label='Actual', color='blue', alpha=0.5)
plt.scatter(range(len(y_test_filtered_0)), y_pred_0, label='Predicted', color='orange', alpha=0.5)
plt.title('Comparison of Actual and Predicted Permittivity Real Values')
plt.xlabel('Data Point')
plt.ylabel('Value')
plt.legend()

# %%
plt.figure(figsize=(16, 4))
plt.subplot(1, 2, 1)
plt.plot([0, len(y_test_filtered_1) - 1], [np.mean(y_pred_1), np.mean(y_pred_1)], label='Predicted Mean', color='red', linestyle='dashed')
plt.scatter(range(len(y_test_filtered_1)), y_test_filtered_1, label='Actual', color='blue', alpha=0.5)
plt.scatter(range(len(y_test_filtered_1)), y_pred_1, label='Predicted', color='orange', alpha=0.5)
plt.title('Comparison of Actual and Predicted Permittivity Imaginary Values')
plt.xlabel('Data Point')
plt.ylabel('Value')
plt.legend()
