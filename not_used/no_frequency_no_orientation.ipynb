# %%
import numpy as np
np.random.seed(1111)
import pandas as pd
import tensorflow as tf
tf.random.set_seed(1111)
from tensorflow import keras
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.io

# %%
file_paths = dict()
file_paths[0] = [
    "data/S11_parameter_data_for_zero_orientation.txt",
    "data/S21_parameter_data_for_zero_orientation.txt",
    "data/S12_parameter_data_for_zero_orientation.txt",
    "data/S22_parameter_data_for_zero_orientation.txt"]
file_paths[1] = [
    "data/S11_parameter_data_for_CW90_orientation.txt",
    "data/S21_parameter_data_for_CW90_orientation.txt",
    "data/S12_parameter_data_for_CW90_orientation.txt",
    "data/S22_parameter_data_for_CW90_orientation.txt"]
file_paths[2] = [
    "data/S11_parameter_data_for_CCW90_orientation.txt",
    "data/S21_parameter_data_for_CCW90_orientation.txt",
    "data/S12_parameter_data_for_CCW90_orientation.txt",
    "data/S22_parameter_data_for_CCW90_orientation.txt"]
file_paths[3] = [
    "data/S11_parameter_data_for_tilt_orientation.txt",
    "data/S21_parameter_data_for_tilt_orientation.txt",
    "data/S12_parameter_data_for_tilt_orientation.txt",
    "data/S22_parameter_data_for_tilt_orientation.txt"]
def process_file(file_path,orientation):
    datasets = []
    with open(file_path, 'r') as file:
        current_dataset = []
        for line in file:
            if line.startswith("#Parameters"):
                if current_dataset:
                    datasets.append(current_dataset)
                    current_dataset = []
                params_str = line[line.index("{") + 1:line.index("}")]
                params = dict(param.split('=') for param in params_str.split(';'))
                current_dataset.append(params)
            elif line.startswith("#"):
                continue
            else:
                data = line.strip().split('\t')
                current_dataset.append(data)
        if current_dataset:
            datasets.append(current_dataset)
    data = []
    for dataset in datasets:
        permittivity_values = dataset[0]
        df_data = dataset[1:]
        s_parameter_name = file_path.split("_parameter_data_for_")[0]
        df = pd.DataFrame(df_data, columns=["Frequency", f"{s_parameter_name}_Real", f"{s_parameter_name}_Imaginary"])
        df["Orientation"] = orientation
        for key, value in permittivity_values.items():
            if "er1" in key or "er11" in key:
                df[key] = value
        data.append(df)
    return data
all_combined_data = []
for index in file_paths:
    for file in file_paths[index]:
        combined_data = process_file(file,index)
        combined_data = pd.concat(combined_data, ignore_index=True)
        all_combined_data.append(combined_data)
array = []
group_size = 4
for i in range(0, len(all_combined_data), group_size):
    combined_dataframe = pd.concat(all_combined_data[i:i+group_size], axis=1)
    combined_dataframe.reset_index(drop=True, inplace=True)
    combined_dataframe = combined_dataframe.T.drop_duplicates().T
    array.append(combined_dataframe)
training_dataframe = pd.concat(array, axis=0)
training_dataframe.reset_index(drop=True, inplace=True)

# %%
training_dataframe
# Out:
#               Frequency       data/S11_Real   data/S11_Imaginary Orientation
# 0       1.0000000000000   0.010708443820477  -0.0015462124720216           0  \
# 1       1.0006999969482   0.010755277238786  -0.0017734571592882           0
# 2       1.0013999938965   0.010795198380947  -0.0020041132811457           0
# 3       1.0020999908447   0.010827971622348  -0.0022378272842616           0
# 4       1.0027999877930   0.010853389278054  -0.0024742297828197           0
# ...                 ...                 ...                  ...         ...
# 400395  1.6971999406815  0.0086805028840899    0.022289762273431           3
# 400396  1.6979000568390  0.0089422538876534    0.022231062874198           3
# 400397  1.6986000537872  0.0092031918466091    0.022169157862663           3
# 400398  1.6993000507355  0.0094632459804416    0.022104114294052           3
# 400399  1.7000000476837  0.0097223594784737    0.022035989910364           3
#
#                     er1               er11      data/S21_Real
# 0       2.2609046534204   0.04505415985025   0.21881757676601  \
# 1       2.2609046534204   0.04505415985025   0.23742462694645
# 2       2.2609046534204   0.04505415985025   0.25594717264175
# 3       2.2609046534204   0.04505415985025   0.27437821030617
# 4       2.2609046534204   0.04505415985025   0.29271024465561
# ...                 ...                ...                ...
# 400395  6.9852127425897  0.058704470453142  -0.40560990571976
# 400396  6.9852127425897  0.058704470453142  -0.39663606882095
# 400397  6.9852127425897  0.058704470453142  -0.38762545585632
# 400398  6.9852127425897  0.058704470453142  -0.37857925891876
# 400399  6.9852127425897  0.058704470453142  -0.36949941515923
#
#        data/S21_Imaginary      data/S12_Real data/S12_Imaginary
# 0        0.96427404880524   0.21881759166718   0.96427410840988  \
# 1        0.96046137809753   0.23742462694645   0.96046137809753
# 2        0.95629817247391   0.25594717264175   0.95629823207855
# 3        0.95178377628326   0.27437824010849   0.95178383588791
# 4        0.94691836833954   0.29271024465561   0.94691836833954
# ...                   ...                ...                ...
# 400395   0.90874713659286  -0.40560993552208   0.90874713659286
# 400396   0.91266602277756  -0.39663609862328   0.91266608238220
# 400397   0.91649043560028  -0.38762545585632   0.91649043560028
# 400398   0.92022013664246  -0.37857928872108   0.92022019624710
# 400399   0.92385458946228  -0.36949941515923   0.92385458946228
#
#             data/S22_Real   data/S22_Imaginary
# 0       0.010326976887882  -0.0032272436656058
# 1       0.010342826135457  -0.0034419626463205
# 2       0.010353058576584  -0.0036560846492648
# 3       0.010357595048845  -0.0038695030380040
# 4       0.010356365703046  -0.0040821037255228
# ...                   ...                  ...
# 400395  0.022388560697436  -0.0084224054589868
# 400396  0.022354153916240  -0.0086299376562238
# 400397  0.022317390888929  -0.0088376719504595
# 400398  0.022278273478150  -0.0090456288307905
# 400399  0.022236829623580  -0.0092537812888622
#
# [400400 rows x 12 columns]

# %%
file_paths = dict()
file_paths[0] = ["data/mea_rot_0.txt"]
file_paths[1] = ["data/mea_rot_cw90.txt"]
file_paths[2] = ["data/mea_rot_ccw90.txt"]
file_paths[3] = ["data/mea_rot_0_tilt.txt"]
# Function to process each file and merge datasets
def process_file(file_path,orientation):
    datasets = []
    with open(file_path, 'r') as file:
        current_dataset = []
        for line in file:
            if line.startswith("#Parameters"):
                if current_dataset:
                    datasets.append(current_dataset)
                    current_dataset = []
                params_str = line[line.index("{") + 1:line.index("}")]
                params = dict(param.split('=') for param in params_str.split(';'))
                current_dataset.append(params)
            elif line.startswith("#"):
                continue
            else:
                data = line.strip().split('\t')
                current_dataset.append(data)
        if current_dataset:
            datasets.append(current_dataset)
    dictionary = {
    0: "S11",
    1: "S21",
    2: "S12",
    3: "S22"
    }
    data = []
    for index, dataset in enumerate(datasets):
        permittivity_values = dataset[0]
        df_data = dataset[1:]
        s_parameter_name = dictionary[index]
        df = pd.DataFrame(df_data, columns=["Frequency", f"{s_parameter_name}_Real", f"{s_parameter_name}_Imaginary"])
        df["Orientation"] = orientation
        for key, value in permittivity_values.items():
            if "er1" in key or "er11" in key:
                df[key] = value
        data.append(df)
    return data
all_combined_data = []
for index in file_paths:
    for file in file_paths[index]:
        combined_data = process_file(file,index)
        all_combined_data.append(combined_data)
array = []
group_size = 4
for group in range(len(all_combined_data)):
    for i in range(0, len(all_combined_data[group]), group_size):
        combined_dataframe = pd.concat(all_combined_data[group][i:i+group_size], axis=1)
        combined_dataframe.reset_index(drop=True, inplace=True)
        combined_dataframe = combined_dataframe.T.drop_duplicates().T
        array.append(combined_dataframe)
testing_dataframe = pd.concat(array, axis=0)
testing_dataframe.reset_index(drop=True, inplace=True)

# %%
testing_dataframe
# Out:
#             Frequency            S11_Real        S11_Imaginary Orientation
# 0     1.0000000000000  -0.019713426000000  -0.0060391319000000           0  \
# 1     1.0007000000000  -0.019482541585540  -0.0063846667326036           0
# 2     1.0014000000000  -0.019137625649780  -0.0065910681665272           0
# 3     1.0021000000000  -0.018813112374285  -0.0069965346072957           0
# 4     1.0028000000000  -0.018616413134193  -0.0076122439176546           0
# ...               ...                 ...                  ...         ...
# 3999  1.6972000000000  -0.011600339315836  -0.0022468552888657           3
# 4000  1.6979000000000  -0.011580232559659  -0.0023914196155704           3
# 4001  1.6986000000000  -0.011554945472181  -0.0025076094670767           3
# 4002  1.6993000000000  -0.011517901790077  -0.0025976429207074           3
# 4003  1.7000000000000  -0.011476784000000  -0.0026654671000000           3
#
#       er1  er11          S21_Real       S21_Imaginary          S12_Real
# 0       5   0.1  0.99841827000000  -0.021599129000000  0.99922335000000  \
# 1       5   0.1  0.99862961142762  -0.021390875332731  0.99871819006375
# 2       5   0.1  0.99844536227299  -0.021037567314369  0.99827064270063
# 3       5   0.1  0.99824771176501  -0.020766027366779  0.99820293745227
# 4       5   0.1  0.99826510603014  -0.020614971186886  0.99851990287783
# ...   ...   ...               ...                 ...               ...
# 3999    5   0.1  0.99943889707617  -0.012551124992394  0.99941394067255
# 4000    5   0.1  0.99950177289091  -0.012453218030109  0.99948836387565
# 4001    5   0.1  0.99934808753521  -0.012272222581248  0.99969033205847
# 4002    5   0.1  0.99909245961084  -0.012164381634824  0.99979096587965
# 4003    5   0.1  0.99925244000000  -0.012334294000000  0.99992371000000
#
#            S12_Imaginary           S22_Real        S22_Imaginary
# 0     -0.020864042000000  0.021094969000000  -0.0067798547000000
# 1     -0.020888964080002  0.020910906076745  -0.0072704463377855
# 2     -0.020941499353097  0.020691122020212  -0.0077301113670862
# 3     -0.020767770604437  0.020422204537027  -0.0081046434147131
# 4     -0.020519403197245  0.020163732147648  -0.0083827107262601
# ...                  ...                ...                  ...
# 3999  -0.011966879752902  0.011675129329758  -0.0025690063448839
# 4000  -0.012267111182474  0.011616661155427  -0.0027397168038479
# 4001  -0.012342750698088  0.011595997700361  -0.0028333870227771
# 4002  -0.012200160625934  0.011579854208092  -0.0028817326547755
# 4003  -0.012451233000000  0.011531265000000  -0.0030884951999999
#
# [4004 rows x 12 columns]

# %%
training_dataframe.columns = ['Frequency', 'S11_Real', 'S11_Imaginary', 'Orientation', 'Permittivity_Real', 'Permittivity_Imaginary', 'S21_Real',
       'S21_Imaginary', 'S12_Real', 'S12_Imaginary', 'S22_Real',
       'S22_Imaginary']
training_dataframe = training_dataframe[['Frequency', 'Orientation', 'Permittivity_Real', 'Permittivity_Imaginary','S11_Real', 'S11_Imaginary', 'S12_Real',
       'S12_Imaginary', 'S21_Real', 'S21_Imaginary', 'S22_Real',
       'S22_Imaginary']]
testing_dataframe.columns = ['Frequency', 'S11_Real', 'S11_Imaginary', 'Orientation', 'Permittivity_Real', 'Permittivity_Imaginary', 'S21_Real',
       'S21_Imaginary', 'S12_Real', 'S12_Imaginary', 'S22_Real',
       'S22_Imaginary']
testing_dataframe = testing_dataframe[['Frequency', 'Orientation',  'Permittivity_Real', 'Permittivity_Imaginary','S11_Real', 'S11_Imaginary', 'S12_Real',
       'S12_Imaginary', 'S21_Real', 'S21_Imaginary', 'S22_Real',
       'S22_Imaginary']]

# %%
training_dataframe.head(5)
# Out:
#          Frequency Orientation Permittivity_Real Permittivity_Imaginary
# 0  1.0000000000000           0   2.2609046534204       0.04505415985025  \
# 1  1.0006999969482           0   2.2609046534204       0.04505415985025
# 2  1.0013999938965           0   2.2609046534204       0.04505415985025
# 3  1.0020999908447           0   2.2609046534204       0.04505415985025
# 4  1.0027999877930           0   2.2609046534204       0.04505415985025
#
#             S11_Real        S11_Imaginary          S12_Real     S12_Imaginary
# 0  0.010708443820477  -0.0015462124720216  0.21881759166718  0.96427410840988  \
# 1  0.010755277238786  -0.0017734571592882  0.23742462694645  0.96046137809753
# 2  0.010795198380947  -0.0020041132811457  0.25594717264175  0.95629823207855
# 3  0.010827971622348  -0.0022378272842616  0.27437824010849  0.95178383588791
# 4  0.010853389278054  -0.0024742297828197  0.29271024465561  0.94691836833954
#
#            S21_Real     S21_Imaginary           S22_Real        S22_Imaginary
# 0  0.21881757676601  0.96427404880524  0.010326976887882  -0.0032272436656058
# 1  0.23742462694645  0.96046137809753  0.010342826135457  -0.0034419626463205
# 2  0.25594717264175  0.95629817247391  0.010353058576584  -0.0036560846492648
# 3  0.27437821030617  0.95178377628326  0.010357595048845  -0.0038695030380040
# 4  0.29271024465561  0.94691836833954  0.010356365703046  -0.0040821037255228

# %%
testing_dataframe.head(5)
# Out:
#          Frequency Orientation Permittivity_Real Permittivity_Imaginary
# 0  1.0000000000000           0                 5                    0.1  \
# 1  1.0007000000000           0                 5                    0.1
# 2  1.0014000000000           0                 5                    0.1
# 3  1.0021000000000           0                 5                    0.1
# 4  1.0028000000000           0                 5                    0.1
#
#              S11_Real        S11_Imaginary          S12_Real
# 0  -0.019713426000000  -0.0060391319000000  0.99922335000000  \
# 1  -0.019482541585540  -0.0063846667326036  0.99871819006375
# 2  -0.019137625649780  -0.0065910681665272  0.99827064270063
# 3  -0.018813112374285  -0.0069965346072957  0.99820293745227
# 4  -0.018616413134193  -0.0076122439176546  0.99851990287783
#
#         S12_Imaginary          S21_Real       S21_Imaginary
# 0  -0.020864042000000  0.99841827000000  -0.021599129000000  \
# 1  -0.020888964080002  0.99862961142762  -0.021390875332731
# 2  -0.020941499353097  0.99844536227299  -0.021037567314369
# 3  -0.020767770604437  0.99824771176501  -0.020766027366779
# 4  -0.020519403197245  0.99826510603014  -0.020614971186886
#
#             S22_Real        S22_Imaginary
# 0  0.021094969000000  -0.0067798547000000
# 1  0.020910906076745  -0.0072704463377855
# 2  0.020691122020212  -0.0077301113670862
# 3  0.020422204537027  -0.0081046434147131
# 4  0.020163732147648  -0.0083827107262601

# %%
training_dataframe.dropna(inplace=True)
training_dataframe[training_dataframe.columns] = training_dataframe[training_dataframe.columns].apply(pd.to_numeric)
testing_dataframe.dropna(inplace=True)
testing_dataframe[testing_dataframe.columns] = testing_dataframe[testing_dataframe.columns].apply(pd.to_numeric)

# %%
training_dataframe.head(5)
# Out:
#    Frequency  Orientation  Permittivity_Real  Permittivity_Imaginary
# 0     1.0000            0           2.260905                0.045054  \
# 1     1.0007            0           2.260905                0.045054
# 2     1.0014            0           2.260905                0.045054
# 3     1.0021            0           2.260905                0.045054
# 4     1.0028            0           2.260905                0.045054
#
#    S11_Real  S11_Imaginary  S12_Real  S12_Imaginary  S21_Real  S21_Imaginary
# 0  0.010708      -0.001546  0.218818       0.964274  0.218818       0.964274  \
# 1  0.010755      -0.001773  0.237425       0.960461  0.237425       0.960461
# 2  0.010795      -0.002004  0.255947       0.956298  0.255947       0.956298
# 3  0.010828      -0.002238  0.274378       0.951784  0.274378       0.951784
# 4  0.010853      -0.002474  0.292710       0.946918  0.292710       0.946918
#
#    S22_Real  S22_Imaginary
# 0  0.010327      -0.003227
# 1  0.010343      -0.003442
# 2  0.010353      -0.003656
# 3  0.010358      -0.003870
# 4  0.010356      -0.004082

# %%
testing_dataframe.head(5)
# Out:
#    Frequency  Orientation  Permittivity_Real  Permittivity_Imaginary
# 0     1.0000            0                  5                     0.1  \
# 1     1.0007            0                  5                     0.1
# 2     1.0014            0                  5                     0.1
# 3     1.0021            0                  5                     0.1
# 4     1.0028            0                  5                     0.1
#
#    S11_Real  S11_Imaginary  S12_Real  S12_Imaginary  S21_Real  S21_Imaginary
# 0 -0.019713      -0.006039  0.999223      -0.020864  0.998418      -0.021599  \
# 1 -0.019483      -0.006385  0.998718      -0.020889  0.998630      -0.021391
# 2 -0.019138      -0.006591  0.998271      -0.020941  0.998445      -0.021038
# 3 -0.018813      -0.006997  0.998203      -0.020768  0.998248      -0.020766
# 4 -0.018616      -0.007612  0.998520      -0.020519  0.998265      -0.020615
#
#    S22_Real  S22_Imaginary
# 0  0.021095      -0.006780
# 1  0.020911      -0.007270
# 2  0.020691      -0.007730
# 3  0.020422      -0.008105
# 4  0.020164      -0.008383

# %%
#sns.set(style="ticks")
#sns.pairplot(training_dataframe[['Permittivity_Real', 'Permittivity_Imaginary','S11_Real', 'S11_Imaginary', 'S21_Real',
#       'S21_Imaginary', 'S12_Real', 'S12_Imaginary', 'S22_Real',
#       'S22_Imaginary']], diag_kind="kde")
#plt.suptitle('Scatterplot Matrix')
#plt.tight_layout()
#plt.show()

# %%
#plt.figure(figsize=(12, 6))
#sns.heatmap(training_dataframe[['Permittivity_Real', 'Permittivity_Imaginary','S11_Real', 'S11_Imaginary', 'S21_Real',
#       'S21_Imaginary', 'S12_Real', 'S12_Imaginary', 'S22_Real',
#       'S22_Imaginary']].corr(), annot=True, cmap='coolwarm')
#plt.title('Correlation Matrix Heatmap')
#plt.show()

# %%
columns = []
for column in training_dataframe.columns:
    if column != "Permittivity_Real" and column !="Permittivity_Imaginary" and column != "Frequency" and column != "Orientation":
        columns.append(column)
columns
# Out:
# ['S11_Real',
#  'S11_Imaginary',
#  'S12_Real',
#  'S12_Imaginary',
#  'S21_Real',
#  'S21_Imaginary',
#  'S22_Real',
#  'S22_Imaginary']

# %%
from sklearn.preprocessing import MinMaxScaler
X_norm = MinMaxScaler().fit(training_dataframe[columns])
training_dataframe[columns] = X_norm.transform(training_dataframe[columns])
testing_dataframe[columns] = X_norm.transform(testing_dataframe[columns])

# %%
X_train = training_dataframe[columns].values
y_train = training_dataframe[['Permittivity_Real', 'Permittivity_Imaginary']].values
X = X_train
y = y_train
split_point = int(0.80 * len(X))
X_train = X[:split_point]
y_train = y[:split_point]
X_val = X[split_point:]
y_val = y[split_point:]
X_test = testing_dataframe[columns].values
y_test = testing_dataframe[['Permittivity_Real', 'Permittivity_Imaginary']].values
y_test[y_test == 0.4] = 0.1
X_train = X_train.astype(float)
y_train = y_train.astype(float)
X_val = X_val.astype(float)
y_val = y_val.astype(float)
X_test = X_test.astype(float)
y_test = y_test.astype(float)

# %%
def mae_loss(y_true, y_pred):
    y_true_real, y_true_imag = tf.split(y_true, 2, axis=-1)
    y_pred_real, y_pred_imag = tf.split(y_pred, 2, axis=-1)
    squared_loss_real = tf.losses.mean_squared_error(y_true_real, y_pred_real)
    squared_loss_imag = tf.losses.mean_squared_error(y_true_imag, y_pred_imag)
    return 0.5 * squared_loss_real + 0.5 * squared_loss_imag
model = keras.Sequential([
    keras.layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],),
                       kernel_initializer='he_uniform', kernel_regularizer=tf.keras.regularizers.l2(0.00001)),
    keras.layers.Dense(64, activation='relu', kernel_initializer='he_uniform',
                       kernel_regularizer=tf.keras.regularizers.l2(0.00001)),
    keras.layers.Dense(32, activation='relu', kernel_initializer='he_uniform',
                       kernel_regularizer=tf.keras.regularizers.l2(0.00001)),
    keras.layers.Dense(16, activation='relu', kernel_initializer='he_uniform',
                       kernel_regularizer=tf.keras.regularizers.l2(0.00001)),
    keras.layers.Dense(y_train.shape[1], activation='linear')
])

model.compile(optimizer=tf.optimizers.SGD(learning_rate=0.0001),
              loss=[mae_loss],
              metrics=[tf.metrics.MeanAbsoluteError(), tf.metrics.MeanSquaredError()])
model.summary()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=75, batch_size=10000,shuffle=True)
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Mean Absolute Error')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error')
plt.legend(['Train', 'Validation'])
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])
plt.tight_layout()
plt.show()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.SGD`.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 128)               1152
#
#  dense_11 (Dense)            (None, 64)                8256
#
#  dense_12 (Dense)            (None, 32)                2080
#
#  dense_13 (Dense)            (None, 16)                528
#
#  dense_14 (Dense)            (None, 2)                 34
#
# =================================================================
# Total params: 12050 (47.07 KB)
# Trainable params: 12050 (47.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/75
# 33/33 [==============================] - 1s 18ms/step - loss: 15.8711 - mean_absolute_error: 2.6479 - mean_squared_error: 15.8664 - val_loss: 13.5150 - val_mean_absolute_error: 2.4187 - val_mean_squared_error: 13.5102
# Epoch 2/75
# 33/33 [==============================] - 1s 17ms/step - loss: 14.2603 - mean_absolute_error: 2.4724 - mean_squared_error: 14.2555 - val_loss: 12.1027 - val_mean_absolute_error: 2.2579 - val_mean_squared_error: 12.0979
# Epoch 3/75
# 33/33 [==============================] - 1s 15ms/step - loss: 12.6550 - mean_absolute_error: 2.3014 - mean_squared_error: 12.6502 - val_loss: 10.3740 - val_mean_absolute_error: 2.0567 - val_mean_squared_error: 10.3693
# Epoch 4/75
# 33/33 [==============================] - 1s 17ms/step - loss: 10.8091 - mean_absolute_error: 2.0935 - mean_squared_error: 10.8043 - val_loss: 8.7341 - val_mean_absolute_error: 1.8537 - val_mean_squared_error: 8.7294
# Epoch 5/75
# 33/33 [==============================] - 0s 15ms/step - loss: 9.1547 - mean_absolute_error: 1.8963 - mean_squared_error: 9.1499 - val_loss: 7.2859 - val_mean_absolute_error: 1.6643 - val_mean_squared_error: 7.2811
# Epoch 6/75
# 33/33 [==============================] - 0s 14ms/step - loss: 7.6418 - mean_absolute_error: 1.7113 - mean_squared_error: 7.6370 - val_loss: 5.9665 - val_mean_absolute_error: 1.4881 - val_mean_squared_error: 5.9618
# Epoch 7/75
# 33/33 [==============================] - 0s 14ms/step - loss: 6.2693 - mean_absolute_error: 1.5411 - mean_squared_error: 6.2645 - val_loss: 4.8183 - val_mean_absolute_error: 1.3344 - val_mean_squared_error: 4.8136
# Epoch 8/75
# 33/33 [==============================] - 0s 13ms/step - loss: 5.1093 - mean_absolute_error: 1.3968 - mean_squared_error: 5.1045 - val_loss: 3.9395 - val_mean_absolute_error: 1.2197 - val_mean_squared_error: 3.9347
# Epoch 9/75
# 33/33 [==============================] - 0s 13ms/step - loss: 4.2430 - mean_absolute_error: 1.2885 - mean_squared_error: 4.2382 - val_loss: 3.3561 - val_mean_absolute_error: 1.1420 - val_mean_squared_error: 3.3513
# Epoch 10/75
# 33/33 [==============================] - 0s 14ms/step - loss: 3.6649 - mean_absolute_error: 1.2130 - mean_squared_error: 3.6601 - val_loss: 3.0164 - val_mean_absolute_error: 1.0938 - val_mean_squared_error: 3.0116
# Epoch 11/75
# 33/33 [==============================] - 0s 14ms/step - loss: 3.3147 - mean_absolute_error: 1.1646 - mean_squared_error: 3.3099 - val_loss: 2.8446 - val_mean_absolute_error: 1.0690 - val_mean_squared_error: 2.8398
# Epoch 12/75
# 33/33 [==============================] - 0s 15ms/step - loss: 3.1182 - mean_absolute_error: 1.1355 - mean_squared_error: 3.1134 - val_loss: 2.7662 - val_mean_absolute_error: 1.0574 - val_mean_squared_error: 2.7614
# Epoch 13/75
# 33/33 [==============================] - 0s 13ms/step - loss: 3.0086 - mean_absolute_error: 1.1177 - mean_squared_error: 3.0038 - val_loss: 2.7333 - val_mean_absolute_error: 1.0518 - val_mean_squared_error: 2.7286
# Epoch 14/75
# 33/33 [==============================] - 0s 15ms/step - loss: 2.9463 - mean_absolute_error: 1.1062 - mean_squared_error: 2.9416 - val_loss: 2.7179 - val_mean_absolute_error: 1.0487 - val_mean_squared_error: 2.7131
# Epoch 15/75
# 33/33 [==============================] - 0s 14ms/step - loss: 2.9069 - mean_absolute_error: 1.0984 - mean_squared_error: 2.9021 - val_loss: 2.7072 - val_mean_absolute_error: 1.0462 - val_mean_squared_error: 2.7025
# Epoch 16/75
# 33/33 [==============================] - 0s 15ms/step - loss: 2.8782 - mean_absolute_error: 1.0926 - mean_squared_error: 2.8734 - val_loss: 2.6973 - val_mean_absolute_error: 1.0440 - val_mean_squared_error: 2.6925
# Epoch 17/75
# 33/33 [==============================] - 0s 15ms/step - loss: 2.8545 - mean_absolute_error: 1.0879 - mean_squared_error: 2.8498 - val_loss: 2.6861 - val_mean_absolute_error: 1.0418 - val_mean_squared_error: 2.6814
# Epoch 18/75
# 33/33 [==============================] - 1s 15ms/step - loss: 2.8337 - mean_absolute_error: 1.0838 - mean_squared_error: 2.8289 - val_loss: 2.6735 - val_mean_absolute_error: 1.0394 - val_mean_squared_error: 2.6688
# Epoch 19/75
# 33/33 [==============================] - 1s 17ms/step - loss: 2.8144 - mean_absolute_error: 1.0802 - mean_squared_error: 2.8097 - val_loss: 2.6611 - val_mean_absolute_error: 1.0372 - val_mean_squared_error: 2.6564
# Epoch 20/75
# 33/33 [==============================] - 1s 17ms/step - loss: 2.7962 - mean_absolute_error: 1.0768 - mean_squared_error: 2.7914 - val_loss: 2.6477 - val_mean_absolute_error: 1.0348 - val_mean_squared_error: 2.6429
# Epoch 21/75
# 33/33 [==============================] - 1s 17ms/step - loss: 2.7788 - mean_absolute_error: 1.0736 - mean_squared_error: 2.7741 - val_loss: 2.6347 - val_mean_absolute_error: 1.0324 - val_mean_squared_error: 2.6299
# Epoch 22/75
# 33/33 [==============================] - 1s 16ms/step - loss: 2.7622 - mean_absolute_error: 1.0706 - mean_squared_error: 2.7574 - val_loss: 2.6212 - val_mean_absolute_error: 1.0301 - val_mean_squared_error: 2.6164
# Epoch 23/75
# 33/33 [==============================] - 1s 16ms/step - loss: 2.7461 - mean_absolute_error: 1.0677 - mean_squared_error: 2.7414 - val_loss: 2.6073 - val_mean_absolute_error: 1.0276 - val_mean_squared_error: 2.6026
# Epoch 24/75
# 33/33 [==============================] - 0s 13ms/step - loss: 2.7306 - mean_absolute_error: 1.0649 - mean_squared_error: 2.7259 - val_loss: 2.5949 - val_mean_absolute_error: 1.0254 - val_mean_squared_error: 2.5901
# Epoch 25/75
# 33/33 [==============================] - 1s 15ms/step - loss: 2.7156 - mean_absolute_error: 1.0621 - mean_squared_error: 2.7108 - val_loss: 2.5824 - val_mean_absolute_error: 1.0231 - val_mean_squared_error: 2.5777
# Epoch 26/75
# 33/33 [==============================] - 0s 15ms/step - loss: 2.7009 - mean_absolute_error: 1.0593 - mean_squared_error: 2.6961 - val_loss: 2.5699 - val_mean_absolute_error: 1.0209 - val_mean_squared_error: 2.5652
# Epoch 27/75
# 33/33 [==============================] - 0s 14ms/step - loss: 2.6868 - mean_absolute_error: 1.0567 - mean_squared_error: 2.6820 - val_loss: 2.5586 - val_mean_absolute_error: 1.0188 - val_mean_squared_error: 2.5538
# Epoch 28/75
# 33/33 [==============================] - 1s 15ms/step - loss: 2.6729 - mean_absolute_error: 1.0540 - mean_squared_error: 2.6682 - val_loss: 2.5474 - val_mean_absolute_error: 1.0167 - val_mean_squared_error: 2.5426
# Epoch 29/75
# 33/33 [==============================] - 0s 13ms/step - loss: 2.6594 - mean_absolute_error: 1.0514 - mean_squared_error: 2.6546 - val_loss: 2.5366 - val_mean_absolute_error: 1.0146 - val_mean_squared_error: 2.5318
# Epoch 30/75
# 33/33 [==============================] - 0s 14ms/step - loss: 2.6463 - mean_absolute_error: 1.0489 - mean_squared_error: 2.6415 - val_loss: 2.5250 - val_mean_absolute_error: 1.0125 - val_mean_squared_error: 2.5202
# Epoch 31/75
# 33/33 [==============================] - 0s 14ms/step - loss: 2.6336 - mean_absolute_error: 1.0464 - mean_squared_error: 2.6288 - val_loss: 2.5146 - val_mean_absolute_error: 1.0105 - val_mean_squared_error: 2.5098
# Epoch 32/75
# 33/33 [==============================] - 0s 14ms/step - loss: 2.6213 - mean_absolute_error: 1.0441 - mean_squared_error: 2.6165 - val_loss: 2.5043 - val_mean_absolute_error: 1.0085 - val_mean_squared_error: 2.4995
# Epoch 33/75
# 33/33 [==============================] - 1s 16ms/step - loss: 2.6092 - mean_absolute_error: 1.0417 - mean_squared_error: 2.6044 - val_loss: 2.4949 - val_mean_absolute_error: 1.0066 - val_mean_squared_error: 2.4901
# Epoch 34/75
# 33/33 [==============================] - 0s 14ms/step - loss: 2.5974 - mean_absolute_error: 1.0393 - mean_squared_error: 2.5927 - val_loss: 2.4837 - val_mean_absolute_error: 1.0045 - val_mean_squared_error: 2.4789
# Epoch 35/75
# 33/33 [==============================] - 0s 14ms/step - loss: 2.5860 - mean_absolute_error: 1.0371 - mean_squared_error: 2.5812 - val_loss: 2.4748 - val_mean_absolute_error: 1.0026 - val_mean_squared_error: 2.4700
# Epoch 36/75
# 33/33 [==============================] - 0s 13ms/step - loss: 2.5749 - mean_absolute_error: 1.0348 - mean_squared_error: 2.5701 - val_loss: 2.4660 - val_mean_absolute_error: 1.0008 - val_mean_squared_error: 2.4612
# Epoch 37/75
# 33/33 [==============================] - 0s 14ms/step - loss: 2.5640 - mean_absolute_error: 1.0325 - mean_squared_error: 2.5592 - val_loss: 2.4568 - val_mean_absolute_error: 0.9989 - val_mean_squared_error: 2.4520
# Epoch 38/75
# 33/33 [==============================] - 0s 13ms/step - loss: 2.5533 - mean_absolute_error: 1.0303 - mean_squared_error: 2.5486 - val_loss: 2.4486 - val_mean_absolute_error: 0.9971 - val_mean_squared_error: 2.4438
# Epoch 39/75
# 33/33 [==============================] - 1s 15ms/step - loss: 2.5430 - mean_absolute_error: 1.0281 - mean_squared_error: 2.5382 - val_loss: 2.4396 - val_mean_absolute_error: 0.9952 - val_mean_squared_error: 2.4348
# Epoch 40/75
# 33/33 [==============================] - 0s 15ms/step - loss: 2.5328 - mean_absolute_error: 1.0260 - mean_squared_error: 2.5280 - val_loss: 2.4313 - val_mean_absolute_error: 0.9934 - val_mean_squared_error: 2.4266
# Epoch 41/75
# 33/33 [==============================] - 0s 15ms/step - loss: 2.5229 - mean_absolute_error: 1.0239 - mean_squared_error: 2.5182 - val_loss: 2.4224 - val_mean_absolute_error: 0.9915 - val_mean_squared_error: 2.4177
# Epoch 42/75
# 33/33 [==============================] - 0s 13ms/step - loss: 2.5132 - mean_absolute_error: 1.0218 - mean_squared_error: 2.5084 - val_loss: 2.4147 - val_mean_absolute_error: 0.9898 - val_mean_squared_error: 2.4099
# Epoch 43/75
# 33/33 [==============================] - 0s 14ms/step - loss: 2.5037 - mean_absolute_error: 1.0197 - mean_squared_error: 2.4989 - val_loss: 2.4061 - val_mean_absolute_error: 0.9880 - val_mean_squared_error: 2.4013
# Epoch 44/75
# 33/33 [==============================] - 0s 15ms/step - loss: 2.4944 - mean_absolute_error: 1.0178 - mean_squared_error: 2.4896 - val_loss: 2.3991 - val_mean_absolute_error: 0.9864 - val_mean_squared_error: 2.3943
# Epoch 45/75
# 33/33 [==============================] - 0s 13ms/step - loss: 2.4853 - mean_absolute_error: 1.0158 - mean_squared_error: 2.4805 - val_loss: 2.3912 - val_mean_absolute_error: 0.9846 - val_mean_squared_error: 2.3864
# Epoch 46/75
# 33/33 [==============================] - 0s 14ms/step - loss: 2.4762 - mean_absolute_error: 1.0138 - mean_squared_error: 2.4715 - val_loss: 2.3835 - val_mean_absolute_error: 0.9830 - val_mean_squared_error: 2.3787
# Epoch 47/75
# 33/33 [==============================] - 0s 15ms/step - loss: 2.4673 - mean_absolute_error: 1.0119 - mean_squared_error: 2.4626 - val_loss: 2.3758 - val_mean_absolute_error: 0.9813 - val_mean_squared_error: 2.3710
# Epoch 48/75
# 33/33 [==============================] - 0s 15ms/step - loss: 2.4585 - mean_absolute_error: 1.0100 - mean_squared_error: 2.4537 - val_loss: 2.3684 - val_mean_absolute_error: 0.9797 - val_mean_squared_error: 2.3637
# Epoch 49/75
# 33/33 [==============================] - 0s 14ms/step - loss: 2.4496 - mean_absolute_error: 1.0081 - mean_squared_error: 2.4449 - val_loss: 2.3614 - val_mean_absolute_error: 0.9782 - val_mean_squared_error: 2.3566
# Epoch 50/75
# 33/33 [==============================] - 1s 18ms/step - loss: 2.4408 - mean_absolute_error: 1.0062 - mean_squared_error: 2.4360 - val_loss: 2.3540 - val_mean_absolute_error: 0.9766 - val_mean_squared_error: 2.3493
# Epoch 51/75
# 33/33 [==============================] - 1s 16ms/step - loss: 2.4319 - mean_absolute_error: 1.0043 - mean_squared_error: 2.4271 - val_loss: 2.3469 - val_mean_absolute_error: 0.9751 - val_mean_squared_error: 2.3421
# Epoch 52/75
# 33/33 [==============================] - 0s 14ms/step - loss: 2.4233 - mean_absolute_error: 1.0025 - mean_squared_error: 2.4185 - val_loss: 2.3407 - val_mean_absolute_error: 0.9736 - val_mean_squared_error: 2.3359
# Epoch 53/75
# 33/33 [==============================] - 0s 13ms/step - loss: 2.4149 - mean_absolute_error: 1.0006 - mean_squared_error: 2.4102 - val_loss: 2.3340 - val_mean_absolute_error: 0.9721 - val_mean_squared_error: 2.3292
# Epoch 54/75
# 33/33 [==============================] - 0s 13ms/step - loss: 2.4069 - mean_absolute_error: 0.9988 - mean_squared_error: 2.4022 - val_loss: 2.3276 - val_mean_absolute_error: 0.9707 - val_mean_squared_error: 2.3229
# Epoch 55/75
# 33/33 [==============================] - 0s 15ms/step - loss: 2.3991 - mean_absolute_error: 0.9970 - mean_squared_error: 2.3944 - val_loss: 2.3213 - val_mean_absolute_error: 0.9692 - val_mean_squared_error: 2.3166
# Epoch 56/75
# 33/33 [==============================] - 0s 14ms/step - loss: 2.3915 - mean_absolute_error: 0.9952 - mean_squared_error: 2.3867 - val_loss: 2.3159 - val_mean_absolute_error: 0.9678 - val_mean_squared_error: 2.3111
# Epoch 57/75
# 33/33 [==============================] - 0s 15ms/step - loss: 2.3841 - mean_absolute_error: 0.9934 - mean_squared_error: 2.3794 - val_loss: 2.3095 - val_mean_absolute_error: 0.9663 - val_mean_squared_error: 2.3047
# Epoch 58/75
# 33/33 [==============================] - 0s 13ms/step - loss: 2.3769 - mean_absolute_error: 0.9917 - mean_squared_error: 2.3721 - val_loss: 2.3040 - val_mean_absolute_error: 0.9649 - val_mean_squared_error: 2.2993
# Epoch 59/75
# 33/33 [==============================] - 0s 15ms/step - loss: 2.3698 - mean_absolute_error: 0.9900 - mean_squared_error: 2.3650 - val_loss: 2.2984 - val_mean_absolute_error: 0.9635 - val_mean_squared_error: 2.2936
# Epoch 60/75
# 33/33 [==============================] - 0s 14ms/step - loss: 2.3629 - mean_absolute_error: 0.9883 - mean_squared_error: 2.3581 - val_loss: 2.2933 - val_mean_absolute_error: 0.9622 - val_mean_squared_error: 2.2885
# Epoch 61/75
# 33/33 [==============================] - 0s 14ms/step - loss: 2.3561 - mean_absolute_error: 0.9866 - mean_squared_error: 2.3514 - val_loss: 2.2880 - val_mean_absolute_error: 0.9608 - val_mean_squared_error: 2.2832
# Epoch 62/75
# 33/33 [==============================] - 0s 14ms/step - loss: 2.3495 - mean_absolute_error: 0.9849 - mean_squared_error: 2.3447 - val_loss: 2.2822 - val_mean_absolute_error: 0.9595 - val_mean_squared_error: 2.2775
# Epoch 63/75
# 33/33 [==============================] - 0s 12ms/step - loss: 2.3429 - mean_absolute_error: 0.9833 - mean_squared_error: 2.3382 - val_loss: 2.2772 - val_mean_absolute_error: 0.9581 - val_mean_squared_error: 2.2724
# Epoch 64/75
# 33/33 [==============================] - 0s 14ms/step - loss: 2.3366 - mean_absolute_error: 0.9817 - mean_squared_error: 2.3318 - val_loss: 2.2723 - val_mean_absolute_error: 0.9568 - val_mean_squared_error: 2.2675
# Epoch 65/75
# 33/33 [==============================] - 1s 16ms/step - loss: 2.3303 - mean_absolute_error: 0.9801 - mean_squared_error: 2.3256 - val_loss: 2.2676 - val_mean_absolute_error: 0.9556 - val_mean_squared_error: 2.2628
# Epoch 66/75
# 33/33 [==============================] - 0s 15ms/step - loss: 2.3242 - mean_absolute_error: 0.9784 - mean_squared_error: 2.3194 - val_loss: 2.2627 - val_mean_absolute_error: 0.9543 - val_mean_squared_error: 2.2580
# Epoch 67/75
# 33/33 [==============================] - 0s 14ms/step - loss: 2.3181 - mean_absolute_error: 0.9768 - mean_squared_error: 2.3134 - val_loss: 2.2581 - val_mean_absolute_error: 0.9530 - val_mean_squared_error: 2.2534
# Epoch 68/75
# 33/33 [==============================] - 0s 12ms/step - loss: 2.3121 - mean_absolute_error: 0.9752 - mean_squared_error: 2.3073 - val_loss: 2.2536 - val_mean_absolute_error: 0.9518 - val_mean_squared_error: 2.2488
# Epoch 69/75
# 33/33 [==============================] - 0s 14ms/step - loss: 2.3062 - mean_absolute_error: 0.9736 - mean_squared_error: 2.3014 - val_loss: 2.2490 - val_mean_absolute_error: 0.9505 - val_mean_squared_error: 2.2442
# Epoch 70/75
# 33/33 [==============================] - 1s 16ms/step - loss: 2.3004 - mean_absolute_error: 0.9720 - mean_squared_error: 2.2956 - val_loss: 2.2447 - val_mean_absolute_error: 0.9493 - val_mean_squared_error: 2.2399
# Epoch 71/75
# 33/33 [==============================] - 0s 14ms/step - loss: 2.2946 - mean_absolute_error: 0.9704 - mean_squared_error: 2.2898 - val_loss: 2.2401 - val_mean_absolute_error: 0.9480 - val_mean_squared_error: 2.2353
# Epoch 72/75
# 33/33 [==============================] - 0s 14ms/step - loss: 2.2889 - mean_absolute_error: 0.9689 - mean_squared_error: 2.2841 - val_loss: 2.2353 - val_mean_absolute_error: 0.9468 - val_mean_squared_error: 2.2305
# Epoch 73/75
# 33/33 [==============================] - 0s 13ms/step - loss: 2.2833 - mean_absolute_error: 0.9673 - mean_squared_error: 2.2785 - val_loss: 2.2310 - val_mean_absolute_error: 0.9455 - val_mean_squared_error: 2.2263
# Epoch 74/75
# 33/33 [==============================] - 0s 13ms/step - loss: 2.2777 - mean_absolute_error: 0.9658 - mean_squared_error: 2.2729 - val_loss: 2.2264 - val_mean_absolute_error: 0.9443 - val_mean_squared_error: 2.2216
# Epoch 75/75
# 33/33 [==============================] - 0s 13ms/step - loss: 2.2722 - mean_absolute_error: 0.9642 - mean_squared_error: 2.2675 - val_loss: 2.2227 - val_mean_absolute_error: 0.9431 - val_mean_squared_error: 2.2179

# %%
y_pred = model.predict(X_test)
plt.figure(figsize=(16, 4))
plt.subplot(1, 2, 1)
plt.plot([0, len(y_test) - 1], [np.mean(y_pred[:, 0]), np.mean(y_pred[:, 0])], label='Predicted Mean', color='red', linestyle='dashed')
plt.scatter(range(len(y_test)), y_test[:, 0], label='Actual', color='blue', alpha=0.5)
plt.scatter(range(len(y_test)), y_pred[:, 0], label='Predicted', color='orange', alpha=0.5)
plt.title('Comparison of Actual and Predicted Permittivity Real Values')
plt.xlabel('Data Point')
plt.ylabel('Value')
plt.legend()
# Out:
# 126/126 [==============================] - 0s 2ms/step

# %%
plt.figure(figsize=(16, 4))
plt.subplot(1, 2, 1)
plt.plot([0, len(y_test) - 1], [np.mean(y_pred[:, 1]), np.mean(y_pred[:, 1])], label='Predicted Mean', color='red', linestyle='dashed')
plt.scatter(range(len(y_test)), y_test[:, 1], label='Actual', color='blue', alpha=0.5)
plt.scatter(range(len(y_test)), y_pred[:, 1], label='Predicted', color='orange', alpha=0.5)
plt.title('Comparison of Actual and Predicted Permittivity Imaginary Values')
plt.xlabel('Data Point')
plt.ylabel('Value')
plt.legend()

# %%
X_train = training_dataframe[columns].values
y_train = training_dataframe[['Permittivity_Real', 'Permittivity_Imaginary']].values
X = X_train
y = y_train
X_train = X_train.astype(float)
y_train = y_train.astype(float)

# %%
def mae_loss(y_true, y_pred):
    y_true_real, y_true_imag = tf.split(y_true, 2, axis=-1)
    y_pred_real, y_pred_imag = tf.split(y_pred, 2, axis=-1)
    squared_loss_real = tf.losses.mean_squared_error(y_true_real, y_pred_real)
    squared_loss_imag = tf.losses.mean_squared_error(y_true_imag, y_pred_imag)
    return 0.5 * squared_loss_real + 0.5 * squared_loss_imag
model = keras.Sequential([
    keras.layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],),
                       kernel_initializer='he_uniform', kernel_regularizer=tf.keras.regularizers.l2(0.00001)),
    keras.layers.Dense(64, activation='relu', kernel_initializer='he_uniform',
                       kernel_regularizer=tf.keras.regularizers.l2(0.00001)),
    keras.layers.Dense(32, activation='relu', kernel_initializer='he_uniform',
                       kernel_regularizer=tf.keras.regularizers.l2(0.00001)),
    keras.layers.Dense(16, activation='relu', kernel_initializer='he_uniform',
                       kernel_regularizer=tf.keras.regularizers.l2(0.00001)),
    keras.layers.Dense(y_train.shape[1], activation='linear')
])

model.compile(optimizer=tf.optimizers.SGD(learning_rate=0.0001),
              loss=[mae_loss],
              metrics=[tf.metrics.MeanAbsoluteError(), tf.metrics.MeanSquaredError()])
model.summary()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=75, batch_size=10000,shuffle=True)
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['mean_absolute_error'])
plt.title('Mean Absolute Error')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error')
plt.legend(['Train'])
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train'])
plt.tight_layout()
plt.show()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.SGD`.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 128)               1152
#
#  dense_16 (Dense)            (None, 64)                8256
#
#  dense_17 (Dense)            (None, 32)                2080
#
#  dense_18 (Dense)            (None, 16)                528
#
#  dense_19 (Dense)            (None, 2)                 34
#
# =================================================================
# Total params: 12050 (47.07 KB)
# Trainable params: 12050 (47.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/75
# 41/41 [==============================] - 1s 19ms/step - loss: 15.4671 - mean_absolute_error: 2.7008 - mean_squared_error: 15.4622 - val_loss: 12.6460 - val_mean_absolute_error: 2.4166 - val_mean_squared_error: 12.6411
# Epoch 2/75
# 41/41 [==============================] - 1s 14ms/step - loss: 12.3998 - mean_absolute_error: 2.3832 - mean_squared_error: 12.3949 - val_loss: 9.7720 - val_mean_absolute_error: 2.0928 - val_mean_squared_error: 9.7671
# Epoch 3/75
# 41/41 [==============================] - 1s 14ms/step - loss: 9.5067 - mean_absolute_error: 2.0657 - mean_squared_error: 9.5018 - val_loss: 7.1545 - val_mean_absolute_error: 1.7872 - val_mean_squared_error: 7.1496
# Epoch 4/75
# 41/41 [==============================] - 1s 14ms/step - loss: 6.8829 - mean_absolute_error: 1.7660 - mean_squared_error: 6.8780 - val_loss: 4.8877 - val_mean_absolute_error: 1.5063 - val_mean_squared_error: 4.8828
# Epoch 5/75
# 41/41 [==============================] - 1s 18ms/step - loss: 4.8235 - mean_absolute_error: 1.5185 - mean_squared_error: 4.8186 - val_loss: 3.5692 - val_mean_absolute_error: 1.3468 - val_mean_squared_error: 3.5643
# Epoch 6/75
# 41/41 [==============================] - 1s 15ms/step - loss: 3.7429 - mean_absolute_error: 1.3864 - mean_squared_error: 3.7380 - val_loss: 3.0321 - val_mean_absolute_error: 1.2768 - val_mean_squared_error: 3.0272
# Epoch 7/75
# 41/41 [==============================] - 1s 16ms/step - loss: 3.2852 - mean_absolute_error: 1.3196 - mean_squared_error: 3.2803 - val_loss: 2.8410 - val_mean_absolute_error: 1.2420 - val_mean_squared_error: 2.8361
# Epoch 8/75
# 41/41 [==============================] - 1s 16ms/step - loss: 3.0961 - mean_absolute_error: 1.2818 - mean_squared_error: 3.0912 - val_loss: 2.7646 - val_mean_absolute_error: 1.2188 - val_mean_squared_error: 2.7597
# Epoch 9/75
# 41/41 [==============================] - 1s 15ms/step - loss: 3.0025 - mean_absolute_error: 1.2555 - mean_squared_error: 2.9976 - val_loss: 2.7193 - val_mean_absolute_error: 1.1993 - val_mean_squared_error: 2.7144
# Epoch 10/75
# 41/41 [==============================] - 1s 15ms/step - loss: 2.9418 - mean_absolute_error: 1.2341 - mean_squared_error: 2.9369 - val_loss: 2.6809 - val_mean_absolute_error: 1.1812 - val_mean_squared_error: 2.6760
# Epoch 11/75
# 41/41 [==============================] - 1s 16ms/step - loss: 2.8936 - mean_absolute_error: 1.2151 - mean_squared_error: 2.8887 - val_loss: 2.6467 - val_mean_absolute_error: 1.1646 - val_mean_squared_error: 2.6417
# Epoch 12/75
# 41/41 [==============================] - 1s 17ms/step - loss: 2.8527 - mean_absolute_error: 1.1981 - mean_squared_error: 2.8478 - val_loss: 2.6170 - val_mean_absolute_error: 1.1498 - val_mean_squared_error: 2.6121
# Epoch 13/75
# 41/41 [==============================] - 1s 15ms/step - loss: 2.8168 - mean_absolute_error: 1.1830 - mean_squared_error: 2.8119 - val_loss: 2.5901 - val_mean_absolute_error: 1.1363 - val_mean_squared_error: 2.5852
# Epoch 14/75
# 41/41 [==============================] - 1s 19ms/step - loss: 2.7849 - mean_absolute_error: 1.1694 - mean_squared_error: 2.7800 - val_loss: 2.5651 - val_mean_absolute_error: 1.1242 - val_mean_squared_error: 2.5602
# Epoch 15/75
# 41/41 [==============================] - 1s 13ms/step - loss: 2.7562 - mean_absolute_error: 1.1574 - mean_squared_error: 2.7513 - val_loss: 2.5440 - val_mean_absolute_error: 1.1136 - val_mean_squared_error: 2.5391
# Epoch 16/75
# 41/41 [==============================] - 1s 17ms/step - loss: 2.7301 - mean_absolute_error: 1.1465 - mean_squared_error: 2.7252 - val_loss: 2.5242 - val_mean_absolute_error: 1.1037 - val_mean_squared_error: 2.5193
# Epoch 17/75
# 41/41 [==============================] - 1s 16ms/step - loss: 2.7062 - mean_absolute_error: 1.1365 - mean_squared_error: 2.7012 - val_loss: 2.5058 - val_mean_absolute_error: 1.0945 - val_mean_squared_error: 2.5008
# Epoch 18/75
# 41/41 [==============================] - 1s 17ms/step - loss: 2.6839 - mean_absolute_error: 1.1272 - mean_squared_error: 2.6790 - val_loss: 2.4876 - val_mean_absolute_error: 1.0858 - val_mean_squared_error: 2.4827
# Epoch 19/75
# 41/41 [==============================] - 1s 14ms/step - loss: 2.6629 - mean_absolute_error: 1.1185 - mean_squared_error: 2.6580 - val_loss: 2.4719 - val_mean_absolute_error: 1.0777 - val_mean_squared_error: 2.4670
# Epoch 20/75
# 41/41 [==============================] - 1s 16ms/step - loss: 2.6433 - mean_absolute_error: 1.1103 - mean_squared_error: 2.6384 - val_loss: 2.4571 - val_mean_absolute_error: 1.0702 - val_mean_squared_error: 2.4522
# Epoch 21/75
# 41/41 [==============================] - 1s 15ms/step - loss: 2.6249 - mean_absolute_error: 1.1027 - mean_squared_error: 2.6200 - val_loss: 2.4430 - val_mean_absolute_error: 1.0630 - val_mean_squared_error: 2.4381
# Epoch 22/75
# 41/41 [==============================] - 1s 16ms/step - loss: 2.6077 - mean_absolute_error: 1.0955 - mean_squared_error: 2.6028 - val_loss: 2.4297 - val_mean_absolute_error: 1.0562 - val_mean_squared_error: 2.4247
# Epoch 23/75
# 41/41 [==============================] - 1s 16ms/step - loss: 2.5914 - mean_absolute_error: 1.0887 - mean_squared_error: 2.5865 - val_loss: 2.4179 - val_mean_absolute_error: 1.0499 - val_mean_squared_error: 2.4130
# Epoch 24/75
# 41/41 [==============================] - 1s 16ms/step - loss: 2.5759 - mean_absolute_error: 1.0822 - mean_squared_error: 2.5710 - val_loss: 2.4063 - val_mean_absolute_error: 1.0439 - val_mean_squared_error: 2.4013
# Epoch 25/75
# 41/41 [==============================] - 1s 15ms/step - loss: 2.5613 - mean_absolute_error: 1.0761 - mean_squared_error: 2.5564 - val_loss: 2.3954 - val_mean_absolute_error: 1.0381 - val_mean_squared_error: 2.3905
# Epoch 26/75
# 41/41 [==============================] - 1s 13ms/step - loss: 2.5474 - mean_absolute_error: 1.0703 - mean_squared_error: 2.5425 - val_loss: 2.3854 - val_mean_absolute_error: 1.0328 - val_mean_squared_error: 2.3805
# Epoch 27/75
# 41/41 [==============================] - 1s 15ms/step - loss: 2.5339 - mean_absolute_error: 1.0647 - mean_squared_error: 2.5290 - val_loss: 2.3760 - val_mean_absolute_error: 1.0276 - val_mean_squared_error: 2.3711
# Epoch 28/75
# 41/41 [==============================] - 1s 15ms/step - loss: 2.5210 - mean_absolute_error: 1.0594 - mean_squared_error: 2.5161 - val_loss: 2.3662 - val_mean_absolute_error: 1.0227 - val_mean_squared_error: 2.3613
# Epoch 29/75
# 41/41 [==============================] - 1s 16ms/step - loss: 2.5086 - mean_absolute_error: 1.0544 - mean_squared_error: 2.5037 - val_loss: 2.3571 - val_mean_absolute_error: 1.0181 - val_mean_squared_error: 2.3521
# Epoch 30/75
# 41/41 [==============================] - 1s 16ms/step - loss: 2.4967 - mean_absolute_error: 1.0496 - mean_squared_error: 2.4918 - val_loss: 2.3486 - val_mean_absolute_error: 1.0137 - val_mean_squared_error: 2.3437
# Epoch 31/75
# 41/41 [==============================] - 1s 17ms/step - loss: 2.4850 - mean_absolute_error: 1.0450 - mean_squared_error: 2.4801 - val_loss: 2.3404 - val_mean_absolute_error: 1.0096 - val_mean_squared_error: 2.3355
# Epoch 32/75
# 41/41 [==============================] - 1s 16ms/step - loss: 2.4737 - mean_absolute_error: 1.0406 - mean_squared_error: 2.4688 - val_loss: 2.3325 - val_mean_absolute_error: 1.0056 - val_mean_squared_error: 2.3276
# Epoch 33/75
# 41/41 [==============================] - 1s 14ms/step - loss: 2.4627 - mean_absolute_error: 1.0363 - mean_squared_error: 2.4578 - val_loss: 2.3244 - val_mean_absolute_error: 1.0018 - val_mean_squared_error: 2.3195
# Epoch 34/75
# 41/41 [==============================] - 1s 15ms/step - loss: 2.4521 - mean_absolute_error: 1.0324 - mean_squared_error: 2.4472 - val_loss: 2.3164 - val_mean_absolute_error: 0.9982 - val_mean_squared_error: 2.3114
# Epoch 35/75
# 41/41 [==============================] - 1s 16ms/step - loss: 2.4418 - mean_absolute_error: 1.0285 - mean_squared_error: 2.4369 - val_loss: 2.3092 - val_mean_absolute_error: 0.9948 - val_mean_squared_error: 2.3043
# Epoch 36/75
# 41/41 [==============================] - 1s 15ms/step - loss: 2.4318 - mean_absolute_error: 1.0248 - mean_squared_error: 2.4269 - val_loss: 2.3027 - val_mean_absolute_error: 0.9916 - val_mean_squared_error: 2.2978
# Epoch 37/75
# 41/41 [==============================] - 1s 16ms/step - loss: 2.4221 - mean_absolute_error: 1.0212 - mean_squared_error: 2.4172 - val_loss: 2.2958 - val_mean_absolute_error: 0.9886 - val_mean_squared_error: 2.2909
# Epoch 38/75
# 41/41 [==============================] - 1s 17ms/step - loss: 2.4127 - mean_absolute_error: 1.0178 - mean_squared_error: 2.4078 - val_loss: 2.2902 - val_mean_absolute_error: 0.9857 - val_mean_squared_error: 2.2853
# Epoch 39/75
# 41/41 [==============================] - 1s 17ms/step - loss: 2.4035 - mean_absolute_error: 1.0145 - mean_squared_error: 2.3986 - val_loss: 2.2839 - val_mean_absolute_error: 0.9830 - val_mean_squared_error: 2.2790
# Epoch 40/75
# 41/41 [==============================] - 1s 19ms/step - loss: 2.3945 - mean_absolute_error: 1.0114 - mean_squared_error: 2.3896 - val_loss: 2.2780 - val_mean_absolute_error: 0.9804 - val_mean_squared_error: 2.2731
# Epoch 41/75
# 41/41 [==============================] - 1s 17ms/step - loss: 2.3856 - mean_absolute_error: 1.0084 - mean_squared_error: 2.3807 - val_loss: 2.2712 - val_mean_absolute_error: 0.9778 - val_mean_squared_error: 2.2663
# Epoch 42/75
# 41/41 [==============================] - 1s 15ms/step - loss: 2.3769 - mean_absolute_error: 1.0055 - mean_squared_error: 2.3720 - val_loss: 2.2658 - val_mean_absolute_error: 0.9755 - val_mean_squared_error: 2.2609
# Epoch 43/75
# 41/41 [==============================] - 1s 14ms/step - loss: 2.3683 - mean_absolute_error: 1.0026 - mean_squared_error: 2.3634 - val_loss: 2.2600 - val_mean_absolute_error: 0.9731 - val_mean_squared_error: 2.2551
# Epoch 44/75
# 41/41 [==============================] - 1s 14ms/step - loss: 2.3597 - mean_absolute_error: 0.9999 - mean_squared_error: 2.3548 - val_loss: 2.2546 - val_mean_absolute_error: 0.9709 - val_mean_squared_error: 2.2497
# Epoch 45/75
# 41/41 [==============================] - 1s 16ms/step - loss: 2.3512 - mean_absolute_error: 0.9971 - mean_squared_error: 2.3463 - val_loss: 2.2492 - val_mean_absolute_error: 0.9688 - val_mean_squared_error: 2.2443
# Epoch 46/75
# 41/41 [==============================] - 1s 16ms/step - loss: 2.3428 - mean_absolute_error: 0.9945 - mean_squared_error: 2.3379 - val_loss: 2.2437 - val_mean_absolute_error: 0.9667 - val_mean_squared_error: 2.2388
# Epoch 47/75
# 41/41 [==============================] - 1s 15ms/step - loss: 2.3344 - mean_absolute_error: 0.9919 - mean_squared_error: 2.3295 - val_loss: 2.2370 - val_mean_absolute_error: 0.9647 - val_mean_squared_error: 2.2321
# Epoch 48/75
# 41/41 [==============================] - 1s 15ms/step - loss: 2.3262 - mean_absolute_error: 0.9896 - mean_squared_error: 2.3213 - val_loss: 2.2316 - val_mean_absolute_error: 0.9627 - val_mean_squared_error: 2.2267
# Epoch 49/75
# 41/41 [==============================] - 1s 15ms/step - loss: 2.3181 - mean_absolute_error: 0.9871 - mean_squared_error: 2.3132 - val_loss: 2.2261 - val_mean_absolute_error: 0.9608 - val_mean_squared_error: 2.2212
# Epoch 50/75
# 41/41 [==============================] - 1s 15ms/step - loss: 2.3101 - mean_absolute_error: 0.9847 - mean_squared_error: 2.3052 - val_loss: 2.2219 - val_mean_absolute_error: 0.9590 - val_mean_squared_error: 2.2170
# Epoch 51/75
# 41/41 [==============================] - 1s 15ms/step - loss: 2.3021 - mean_absolute_error: 0.9823 - mean_squared_error: 2.2972 - val_loss: 2.2165 - val_mean_absolute_error: 0.9572 - val_mean_squared_error: 2.2116
# Epoch 52/75
# 41/41 [==============================] - 1s 15ms/step - loss: 2.2942 - mean_absolute_error: 0.9800 - mean_squared_error: 2.2893 - val_loss: 2.2112 - val_mean_absolute_error: 0.9554 - val_mean_squared_error: 2.2063
# Epoch 53/75
# 41/41 [==============================] - 1s 15ms/step - loss: 2.2863 - mean_absolute_error: 0.9778 - mean_squared_error: 2.2813 - val_loss: 2.2060 - val_mean_absolute_error: 0.9537 - val_mean_squared_error: 2.2011
# Epoch 54/75
# 41/41 [==============================] - 1s 13ms/step - loss: 2.2783 - mean_absolute_error: 0.9755 - mean_squared_error: 2.2734 - val_loss: 2.2003 - val_mean_absolute_error: 0.9520 - val_mean_squared_error: 2.1954
# Epoch 55/75
# 41/41 [==============================] - 1s 15ms/step - loss: 2.2703 - mean_absolute_error: 0.9733 - mean_squared_error: 2.2654 - val_loss: 2.1952 - val_mean_absolute_error: 0.9504 - val_mean_squared_error: 2.1903
# Epoch 56/75
# 41/41 [==============================] - 1s 16ms/step - loss: 2.2622 - mean_absolute_error: 0.9710 - mean_squared_error: 2.2573 - val_loss: 2.1897 - val_mean_absolute_error: 0.9487 - val_mean_squared_error: 2.1848
# Epoch 57/75
# 41/41 [==============================] - 1s 17ms/step - loss: 2.2541 - mean_absolute_error: 0.9688 - mean_squared_error: 2.2492 - val_loss: 2.1845 - val_mean_absolute_error: 0.9472 - val_mean_squared_error: 2.1796
# Epoch 58/75
# 41/41 [==============================] - 1s 18ms/step - loss: 2.2460 - mean_absolute_error: 0.9667 - mean_squared_error: 2.2411 - val_loss: 2.1786 - val_mean_absolute_error: 0.9456 - val_mean_squared_error: 2.1737
# Epoch 59/75
# 41/41 [==============================] - 1s 17ms/step - loss: 2.2378 - mean_absolute_error: 0.9645 - mean_squared_error: 2.2329 - val_loss: 2.1729 - val_mean_absolute_error: 0.9440 - val_mean_squared_error: 2.1680
# Epoch 60/75
# 41/41 [==============================] - 1s 17ms/step - loss: 2.2297 - mean_absolute_error: 0.9624 - mean_squared_error: 2.2248 - val_loss: 2.1672 - val_mean_absolute_error: 0.9425 - val_mean_squared_error: 2.1623
# Epoch 61/75
# 41/41 [==============================] - 1s 17ms/step - loss: 2.2216 - mean_absolute_error: 0.9603 - mean_squared_error: 2.2167 - val_loss: 2.1617 - val_mean_absolute_error: 0.9410 - val_mean_squared_error: 2.1568
# Epoch 62/75
# 41/41 [==============================] - 1s 16ms/step - loss: 2.2136 - mean_absolute_error: 0.9583 - mean_squared_error: 2.2087 - val_loss: 2.1557 - val_mean_absolute_error: 0.9395 - val_mean_squared_error: 2.1508
# Epoch 63/75
# 41/41 [==============================] - 1s 15ms/step - loss: 2.2057 - mean_absolute_error: 0.9563 - mean_squared_error: 2.2008 - val_loss: 2.1510 - val_mean_absolute_error: 0.9380 - val_mean_squared_error: 2.1461
# Epoch 64/75
# 41/41 [==============================] - 1s 16ms/step - loss: 2.1979 - mean_absolute_error: 0.9541 - mean_squared_error: 2.1930 - val_loss: 2.1455 - val_mean_absolute_error: 0.9366 - val_mean_squared_error: 2.1406
# Epoch 65/75
# 41/41 [==============================] - 1s 15ms/step - loss: 2.1901 - mean_absolute_error: 0.9521 - mean_squared_error: 2.1852 - val_loss: 2.1398 - val_mean_absolute_error: 0.9351 - val_mean_squared_error: 2.1348
# Epoch 66/75
# 41/41 [==============================] - 1s 15ms/step - loss: 2.1823 - mean_absolute_error: 0.9502 - mean_squared_error: 2.1773 - val_loss: 2.1337 - val_mean_absolute_error: 0.9336 - val_mean_squared_error: 2.1288
# Epoch 67/75
# 41/41 [==============================] - 1s 17ms/step - loss: 2.1744 - mean_absolute_error: 0.9482 - mean_squared_error: 2.1695 - val_loss: 2.1283 - val_mean_absolute_error: 0.9322 - val_mean_squared_error: 2.1234
# Epoch 68/75
# 41/41 [==============================] - 1s 14ms/step - loss: 2.1666 - mean_absolute_error: 0.9461 - mean_squared_error: 2.1616 - val_loss: 2.1237 - val_mean_absolute_error: 0.9309 - val_mean_squared_error: 2.1188
# Epoch 69/75
# 41/41 [==============================] - 1s 14ms/step - loss: 2.1587 - mean_absolute_error: 0.9440 - mean_squared_error: 2.1538 - val_loss: 2.1191 - val_mean_absolute_error: 0.9296 - val_mean_squared_error: 2.1142
# Epoch 70/75
# 41/41 [==============================] - 1s 17ms/step - loss: 2.1510 - mean_absolute_error: 0.9419 - mean_squared_error: 2.1461 - val_loss: 2.1142 - val_mean_absolute_error: 0.9283 - val_mean_squared_error: 2.1093
# Epoch 71/75
# 41/41 [==============================] - 1s 18ms/step - loss: 2.1435 - mean_absolute_error: 0.9399 - mean_squared_error: 2.1386 - val_loss: 2.1090 - val_mean_absolute_error: 0.9270 - val_mean_squared_error: 2.1041
# Epoch 72/75
# 41/41 [==============================] - 1s 18ms/step - loss: 2.1362 - mean_absolute_error: 0.9380 - mean_squared_error: 2.1313 - val_loss: 2.1038 - val_mean_absolute_error: 0.9257 - val_mean_squared_error: 2.0989
# Epoch 73/75
# 41/41 [==============================] - 1s 15ms/step - loss: 2.1290 - mean_absolute_error: 0.9361 - mean_squared_error: 2.1241 - val_loss: 2.0992 - val_mean_absolute_error: 0.9244 - val_mean_squared_error: 2.0943
# Epoch 74/75
# 41/41 [==============================] - 1s 17ms/step - loss: 2.1219 - mean_absolute_error: 0.9342 - mean_squared_error: 2.1170 - val_loss: 2.0953 - val_mean_absolute_error: 0.9231 - val_mean_squared_error: 2.0904
# Epoch 75/75
# 41/41 [==============================] - 1s 18ms/step - loss: 2.1149 - mean_absolute_error: 0.9322 - mean_squared_error: 2.1100 - val_loss: 2.0904 - val_mean_absolute_error: 0.9218 - val_mean_squared_error: 2.0855

# %%
y_pred = model.predict(X_test)
plt.figure(figsize=(16, 4))
plt.subplot(1, 2, 1)
plt.plot([0, len(y_test) - 1], [np.mean(y_pred[:, 0]), np.mean(y_pred[:, 0])], label='Predicted Mean', color='red', linestyle='dashed')
plt.scatter(range(len(y_test)), y_test[:, 0], label='Actual', color='blue', alpha=0.5)
plt.scatter(range(len(y_test)), y_pred[:, 0], label='Predicted', color='orange', alpha=0.5)
plt.title('Comparison of Actual and Predicted Permittivity Real Values')
plt.xlabel('Data Point')
plt.ylabel('Value')
plt.legend()
# Out:
# 126/126 [==============================] - 0s 2ms/step

# %%
plt.figure(figsize=(16, 4))
plt.subplot(1, 2, 1)
plt.plot([0, len(y_test) - 1], [np.mean(y_pred[:, 1]), np.mean(y_pred[:, 1])], label='Predicted Mean', color='red', linestyle='dashed')
plt.scatter(range(len(y_test)), y_test[:, 1], label='Actual', color='blue', alpha=0.5)
plt.scatter(range(len(y_test)), y_pred[:, 1], label='Predicted', color='orange', alpha=0.5)
plt.title('Comparison of Actual and Predicted Permittivity Imaginary Values')
plt.xlabel('Data Point')
plt.ylabel('Value')
plt.legend()
